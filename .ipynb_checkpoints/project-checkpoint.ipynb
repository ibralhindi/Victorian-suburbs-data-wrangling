# %% [markdown]
# # FIT5196 Assessment 3
#
# #### Student Name: Ibrahim Al-Hindi
# #### Date Created: 10/10/2021
# #### Date Last Edited: 1/11/2021
#
# #### Environment Details:
# - Python: 3.8.10
# - Anaconda: 4.10.3
#
# #### Libraries Used:
# - numpy
# - pandas
# - re
# - shapefile
# - matplotlib
# - ast
# - haversine
# - datetime
# - urllib
# - bs4
# - sklearn
# - statsmodels
# - math
# - scipy
#
# ## Table of Contents:
# 1. Introduction
# 2. Load and Parse Data Files
# 3. Integrate Column Values
#     - 3.1 Suburb
#     - 3.2 LGA
#     - 3.3 closest_train_station_id and distance_closest_train_station
#     - 3.4 travel_min_to_MC
#     - 3.5 direct_journey_flag
#     - 3.6 COVID Cases
# 4. Data Reshaping
#     - 4.1 Data Cleaning and Exploration
#     - 4.2 Initial Model
#     - 4.3 Normalisation
#         - 4.3.1 Standardisation
#         - 4.3.2 Minmax Normalisation
#     - 4.4 Transformation
#         - 4.4.1 Root Transformation
#         - 4.4.2 Square Power Transformation
#         - 4.4.3 Log Transformation
#         - 4.4.4 Box Cox Transformation
#     - 4.5 Final Model
# 5. Conclusion
# 6. References
#
# ## 1. Introduction
#
# This assignment is concerned with techniques used to integrate several datasets of varying forms into a single schema. The final schema will include a list of unique residential properties and their attributes, such as their suburb, LGA, closest train station, and others. It will also include COVID-19 figures that will be retrieved through webscraping. The second part of the assignment will explore several normalisation and transformation methods in an attempt to produce the best linear model in relation to the COVID-19 columns.
#
# ## 2. Load and Parse Data Files
#
# The property data is contained in two files: a json file and an xml file. We will read both of them in and then concatenate the two dataframes

# %%
import numpy as np
import pandas as pd
import re
import shapefile
from matplotlib.patches import Polygon
from ast import literal_eval
from haversine import haversine, Unit
import datetime as dt
from urllib.request import urlopen
from bs4 import BeautifulSoup
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import preprocessing
import math
from scipy import stats

# %%
# load json file
json_df = pd.read_json("data/jsonfile.json")
json_df.head()
# Out:
#    property_id        lat         lng          addr_street
# 0         2645 -37.815113  144.891492   10 Goulburn Street
# 1        51985 -37.799076  145.174236      7 Belmont Court
# 2        76137 -37.909505  145.094192     38 Andrew Street
# 3        96049 -37.912178  145.051455  6 Shanahan Crescent
# 4        47173 -37.719559  145.160461  40 Malabar Crescent

# %%
# load xml file
with open('data/xmlfile.xml','r') as infile:
    xml_text = infile.read()
    
xml_text.split("\n")[:30]
# Out:
# ['<property>',
#  '  <property_id>16547</property_id>',
#  '  <lat>-37.704682</lat>',
#  '  <lng>144.909869</lng>',
#  '  <addr_street>14 York Street</addr_street>',
#  '</property>',
#  '<property>',
#  '  <property_id>64519</property_id>',
#  '  <lat>-37.799871</lat>',
#  '  <lng>145.265763</lng>',
#  '  <addr_street>45 Mt Dandenong Road</addr_street>',
#  '</property>',
#  '<property>',
#  '  <property_id>19887</property_id>',
#  '  <lat>-37.794644</lat>',
#  '  <lng>144.954979</lng>',
#  '  <addr_street>133 Park Drive</addr_street>',
#  '</property>',
#  '<property>',
#  '  <property_id>56939</property_id>',
#  '  <lat>-37.85438156</lat>',
#  '  <lng>145.120163</lng>',
#  '  <addr_street>9 Leonard Street</addr_street>',
#  '</property>',
#  '<property>',
#  '  <property_id>48450</property_id>',
#  '  <lat>-37.808992</lat>',
#  '  <lng>145.044577</lng>',
#  '  <addr_street>43 Atkins Street</addr_street>',
#  '</property>']

# %% [markdown]
# Looking at the first few properties of the xml file, we can see that each property has a root `<property>` tag, followed by `<property>`, `<lat>`, `<lng>`, and `<addr_street>` tags

# %% [markdown]
# To ascertain the total number of properties in the file, regex will be used to count the number of times `<property>` appears in the file

# %%
len(re.findall(r"<property>", xml_text))
# Out:
# 1024

# %% [markdown]
# We have 1,024 properties in the file.
#
# For each of the tags in the file, a list will be created that holds all the values corresponding to each tag. This will be done using regex where for each tag, all the characters between the opening and closing tags will be matched as so:
#
# `<tag>(.*)?</tag>`
#
# The list corresponding to each tag will then be used to build a dataframe

# %%
# create regex patterns
id_pattern = r"<property_id>(.*?)</property_id>"
lat_pattern = r"<lat>(.*?)</lat>"
lng_pattern = r"<lng>(.*?)</lng>"
addr_pattern = r"<addr_street>(.*?)</addr_street>"

# build dataframe
xml_df = pd.DataFrame({"property_id": [prop_id for prop_id in re.findall(id_pattern, xml_text)],
                       "lat": [lat for lat in re.findall(lat_pattern, xml_text)],
                       "lng": [lng for lng in re.findall(lng_pattern, xml_text)],
                       "addr_street": [addr for addr in re.findall(addr_pattern, xml_text)]})

xml_df.head()
# Out:
#   property_id           lat         lng           addr_street
# 0       16547    -37.704682  144.909869        14 York Street
# 1       64519    -37.799871  145.265763  45 Mt Dandenong Road
# 2       19887    -37.794644  144.954979        133 Park Drive
# 3       56939  -37.85438156  145.120163      9 Leonard Street
# 4       48450    -37.808992  145.044577      43 Atkins Street

# %% [markdown]
# The process of concatenating the two dataframes will now be undertaken. First we need to ensure the column types for both dataframes are the same

# %%
print("json_df:")
json_df.info()
print("\n")
print("xml_df:")
xml_df.info()
# Out:
# json_df:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   property_id  1028 non-null   int64
#  1   lat          1028 non-null   float64
#  2   lng          1028 non-null   float64
#  3   addr_street  1028 non-null   object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 32.2+ KB
#
#
# xml_df:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   property_id  1024 non-null   object
#  1   lat          1024 non-null   object
#  2   lng          1024 non-null   object
#  3   addr_street  1024 non-null   object
# dtypes: object(4)
# memory usage: 32.1+ KB

# %% [markdown]
# The two dataframes have different data types. We will convert `xml_df` to be the same as `json_df`

# %%
xml_df = xml_df.astype({"property_id": "int64", "lat": "float64", "lng": "float64"})

xml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   property_id  1024 non-null   int64
#  1   lat          1024 non-null   float64
#  2   lng          1024 non-null   float64
#  3   addr_street  1024 non-null   object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 32.1+ KB

# %% [markdown]
# We will now concatenate the two dataframes along the rows, we will also set `ignore_index` to **True** so that the indexes are not repeated from both dataframes. We will also change the type of `property_id` to object, as well as round the `lat` and `lng` values to seven decimal places to avoid rounding discrepancies

# %%
prop_df = pd.concat([json_df, xml_df], ignore_index = True)
prop_df["property_id"] = prop_df["property_id"].astype("object")
prop_df["lat"] = prop_df["lat"].round(7)
prop_df["lng"] = prop_df["lng"].round(7)
prop_df.head()
# Out:
#   property_id        lat         lng          addr_street
# 0        2645 -37.815113  144.891492   10 Goulburn Street
# 1       51985 -37.799076  145.174236      7 Belmont Court
# 2       76137 -37.909505  145.094192     38 Andrew Street
# 3       96049 -37.912178  145.051455  6 Shanahan Crescent
# 4       47173 -37.719559  145.160461  40 Malabar Crescent

# %% [markdown]
# Let's take a look at the summary statistics of the data

# %%
prop_df.describe(include = "all")
# Out:
#         property_id          lat          lng         addr_street
# count        2052.0  2052.000000  2052.000000                2052
# unique       2030.0          NaN          NaN                2026
# top          2645.0          NaN          NaN  10 Goulburn Street
# freq            3.0          NaN          NaN                   3
# mean            NaN   -37.808550   145.045116                 NaN
# std             NaN     0.097931     0.132252                 NaN
# min             NaN   -38.079724   144.633059                 NaN
# 25%             NaN   -37.868544   144.960396                 NaN
# 50%             NaN   -37.805102   145.036626                 NaN
# 75%             NaN   -37.740129   145.125605                 NaN
# max             NaN   -37.570955   145.368031                 NaN

# %% [markdown]
# We can see there are duplicates in `property_id` and `addr_street`. Let's dive deeper into these duplicates. First we'll extract the rows where all the values are the same

# %%
prop_df[prop_df.duplicated(keep = False)].sort_values("addr_street")
# Out:
#      property_id        lat         lng             addr_street
# 1158        1577 -37.822044  144.841949     1/16 Conifer Avenue
# 959         1577 -37.822044  144.841949     1/16 Conifer Avenue
# 2047        2645 -37.815113  144.891492      10 Goulburn Street
# 517         2645 -37.815113  144.891492      10 Goulburn Street
# 0           2645 -37.815113  144.891492      10 Goulburn Street
# 1141       82581 -37.902664  145.274865        15 Jubilee Drive
# 869        82581 -37.902664  145.274865        15 Jubilee Drive
# 1587       77722 -37.937527  145.204453             21 Ling Crt
# 962        77722 -37.937527  145.204453             21 Ling Crt
# 1923       95170 -37.905012  145.028794       21 Stewart Street
# 1525       95170 -37.905012  145.028794       21 Stewart Street
# 254        89352 -37.959307  145.023963     22-24  Green Parade
# 260        89352 -37.959307  145.023963     22-24  Green Parade
# 1243       79976 -37.984326  145.167437       25 Coolibah Place
# 585        79976 -37.984326  145.167437       25 Coolibah Place
# 1368       26130 -37.590841  144.907879     25 Grosvenor Square
# 15         26130 -37.590841  144.907879     25 Grosvenor Square
# 1697       54317 -37.820316  145.040523       25 William Street
# 1344       54317 -37.820316  145.040523       25 William Street
# 760         5111 -37.867357  144.825909         29 David Street
# 515         5111 -37.867357  144.825909         29 David Street
# 2          76137 -37.909505  145.094192        38 Andrew Street
# 2049       76137 -37.909505  145.094192        38 Andrew Street
# 1826       55616 -37.847012  145.089371        4 Bethela Street
# 1252       55616 -37.847012  145.089371        4 Bethela Street
# 1956       46063 -37.724917  145.130756       4 Mitchell Avenue
# 363        46063 -37.724917  145.130756       4 Mitchell Avenue
# 2051       47173 -37.719559  145.160461     40 Malabar Crescent
# 4          47173 -37.719559  145.160461     40 Malabar Crescent
# 1674       90693 -37.961633  145.043243       41 Olympic Avenue
# 1959       90693 -37.961633  145.043243       41 Olympic Avenue
# 862        45141 -37.707315  145.088787  478 Greensborough Road
# 309        45141 -37.707315  145.088787  478 Greensborough Road
# 1234       38329 -37.771581  145.032229       48 Bennett Street
# 1488       38329 -37.771581  145.032229       48 Bennett Street
# 1680       10614 -37.790342  144.930268      49 Eastwood Street
# 54         10614 -37.790342  144.930268      49 Eastwood Street
# 2050       96049 -37.912178  145.051455     6 Shanahan Crescent
# 3          96049 -37.912178  145.051455     6 Shanahan Crescent
# 1682        1343 -37.806872  144.886402          7 Bayview Road
# 530         1343 -37.806872  144.886402          7 Bayview Road
# 1          51985 -37.799076  145.174236         7 Belmont Court
# 2048       51985 -37.799076  145.174236         7 Belmont Court

# %% [markdown]
# We will drop these duplicates

# %%
prop_df.drop_duplicates(inplace = True)
prop_df.describe(include = "O")
# Out:
#         property_id       addr_street
# count          2030              2030
# unique         2030              2026
# top            2645  20 Hughes Street
# freq              1                 2

# %% [markdown]
# We still have duplicates in `addr_street`

# %%
prop_df[prop_df.duplicated("addr_street", keep = False)].sort_values("addr_street")
# Out:
#      property_id        lat         lng         addr_street
# 1103       83035 -37.890453  145.243796      14 Graham Road
# 1255       88475 -37.954433  145.042709      14 Graham Road
# 25         88135 -37.941985  145.048707     2 Rodney Street
# 1603       72152 -37.845580  145.250923     2 Rodney Street
# 915         5617 -37.792069  144.852558    20 Hughes Street
# 1633        3070 -37.822670  144.889923    20 Hughes Street
# 1346       95558 -37.918822  145.032497  33 Campbell Street
# 2037       86596 -37.898903  144.993150  33 Campbell Street

# %% [markdown]
# Searching online indicates that identical street names do exist in different suburbs, which is also indicated by the different `lat` and `lng` for each duplicated address, therefore the "duplicates" are acceptable

# %% [markdown]
# Our final dataframe contains the following statistics

# %%
prop_df.describe(include = "all")
# Out:
#         property_id          lat          lng       addr_street
# count        2030.0  2030.000000  2030.000000              2030
# unique       2030.0          NaN          NaN              2026
# top          2645.0          NaN          NaN  20 Hughes Street
# freq            1.0          NaN          NaN                 2
# mean            NaN   -37.808263   145.045220               NaN
# std             NaN     0.097927     0.132351               NaN
# min             NaN   -38.079724   144.633059               NaN
# 25%             NaN   -37.867892   144.960576               NaN
# 50%             NaN   -37.804890   145.036519               NaN
# 75%             NaN   -37.739818   145.125538               NaN
# max             NaN   -37.570955   145.368031               NaN

# %% [markdown]
# ## 3. Integrate Column Values
#
# In this section we will integrate data from multiple sources into our dataframe.
#
# ### 3.1 Suburb
#
# The first column we will integrate is the `suburb` column which will hold the suburb name of each property. To determine the suburb of each property in `prop_df`, a shapefile of the suburb boundaries will be loaded. Then, for each property in `prop_df`,
# the suburb name from the loaded shapefile will be returned where the `lat` and `lng` from `prop_df` are inside the boundary coordinates of the suburb in the shapefile. Reading and utlising the shapefile will be done using the `shapefile` package and the `Polygon` module from the `matplotlib.patches` package.

# %%
# load shapefile
sf = shapefile.Reader("data/vic_suburb_bounadry/VIC_LOCALITY_POLYGON_shp")
# read records and shapes
shaperecs = sf.shapeRecords()

# %% [markdown]
# For each record-shape combination in `shaperecs`, the records are generated using the `record` attribue while the shape is accessed using the `shape` attribute. The suburb is the 7th element in each record. This is illustrated below

# %%
print(shaperecs[0].record, "\n")
print("suburb:", shaperecs[0].record[6])
# Out:
# Record #-1: ['6670', datetime.date(2011, 8, 31), None, 'VIC2615', datetime.date(2012, 4, 27), None, 'UNDERBOOL', '', '', 'G', None, '2']
#
# suburb: UNDERBOOL

# %% [markdown]
# A dictionary `subs_bounds` will be created where keys are the suburb names and the values are the polygons for each suburb

# %%
subs_bounds = {}

for rs in shaperecs:
    sub = rs.record[6]
    shape = rs.shape
    ptchs = []
    pts = np.array(shape.points)
    prt = shape.parts
    par = list(prt) + [pts.shape[0]]
    
    for pij in range(len(prt)):
         ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
            
    subs_bounds[sub] = ptchs[0]
    
subs_bounds
# Out:
# {'UNDERBOOL': <matplotlib.patches.Polygon at 0x271f6fd2ac0>,
#  'NURRAN': <matplotlib.patches.Polygon at 0x271f6fd2a90>,
#  'WOORNDOO': <matplotlib.patches.Polygon at 0x271f6fd2b80>,
#  'DEPTFORD': <matplotlib.patches.Polygon at 0x271f6fd2be0>,
#  'YANAC': <matplotlib.patches.Polygon at 0x271f6fd2c40>,
#  'MINIMAY': <matplotlib.patches.Polygon at 0x271f6fd2ca0>,
#  'GLEN FORBES': <matplotlib.patches.Polygon at 0x271f6fd2d00>,
#  'ADAMS ESTATE': <matplotlib.patches.Polygon at 0x271f6fd2400>,
#  'DIMBOOLA': <matplotlib.patches.Polygon at 0x271f6fd2df0>,
#  'CANNUM': <matplotlib.patches.Polygon at 0x271f6fd2e50>,
#  'WALLUP': <matplotlib.patches.Polygon at 0x271f6fd2eb0>,
#  'MURRA WARRA': <matplotlib.patches.Polygon at 0x271f6fd2f10>,
#  'KALKEE': <matplotlib.patches.Polygon at 0x271f6fd2f70>,
#  'WAIL': <matplotlib.patches.Polygon at 0x271f6fd2fd0>,
#  'PIMPINIO': <matplotlib.patches.Polygon at 0x271f6fd2d60>,
#  'DOOEN': <matplotlib.patches.Polygon at 0x271f6fe7070>,
#  'VECTIS': <matplotlib.patches.Polygon at 0x271f6fe70d0>,
#  'QUANTONG': <matplotlib.patches.Polygon at 0x271e5eb86a0>,
#  'CARWARP': <matplotlib.patches.Polygon at 0x271e5e8d7f0>,
#  'OMEO': <matplotlib.patches.Polygon at 0x271f6fe7130>,
#  'YAPEEN': <matplotlib.patches.Polygon at 0x271f6fe7190>,
#  'LOGAN': <matplotlib.patches.Polygon at 0x271f6fe71f0>,
#  'TOM GROGGIN': <matplotlib.patches.Polygon at 0x271f6fe7250>,
#  'TAMBOON': <matplotlib.patches.Polygon at 0x271f6fe72b0>,
#  'WONGUNGARRA': <matplotlib.patches.Polygon at 0x271f6fe7340>,
#  'WILSONS PROMONTORY': <matplotlib.patches.Polygon at 0x271f6fe73a0>,
#  'GUILDFORD': <matplotlib.patches.Polygon at 0x271f6fe7400>,
#  'WILLAURA': <matplotlib.patches.Polygon at 0x271f6fe7460>,
#  'COBBERAS': <matplotlib.patches.Polygon at 0x271f6fe74c0>,
#  'MACLEOD': <matplotlib.patches.Polygon at 0x271f6fe7520>,
#  'BUNDOORA': <matplotlib.patches.Polygon at 0x271f6fe7580>,
#  'HEIDELBERG WEST': <matplotlib.patches.Polygon at 0x271f6fe75e0>,
#  'MONEGEETTA': <matplotlib.patches.Polygon at 0x271f6fe7640>,
#  'PERONNE': <matplotlib.patches.Polygon at 0x271f6fe76a0>,
#  'TUTYE': <matplotlib.patches.Polygon at 0x271f6fe7700>,
#  'MOORALLA': <matplotlib.patches.Polygon at 0x271f6fe7760>,
#  'DUNKELD': <matplotlib.patches.Polygon at 0x271f6fe77c0>,
#  'SUGGAN BUGGAN': <matplotlib.patches.Polygon at 0x271f6fe7820>,
#  'BAW BAW': <matplotlib.patches.Polygon at 0x271f6fe7880>,
#  'CABBAGE TREE CREEK': <matplotlib.patches.Polygon at 0x271f6fe78e0>,
#  'WAHRING': <matplotlib.patches.Polygon at 0x271f6fe7940>,
#  'NAMBROK': <matplotlib.patches.Polygon at 0x271f6fe79a0>,
#  'KILMANY': <matplotlib.patches.Polygon at 0x271f6fe7a00>,
#  'DEEPDENE': <matplotlib.patches.Polygon at 0x271f6fe7a60>,
#  'MURRAYVILLE': <matplotlib.patches.Polygon at 0x271f6fe7ac0>,
#  'EDENHOPE': <matplotlib.patches.Polygon at 0x271f6fe7b20>,
#  'WARRACKNABEAL': <matplotlib.patches.Polygon at 0x271f6fe7b80>,
#  'DARTMOOR': <matplotlib.patches.Polygon at 0x271f6fe7be0>,
#  'DANDONGADALE': <matplotlib.patches.Polygon at 0x271f6fe7c40>,
#  'GELANTIPY': <matplotlib.patches.Polygon at 0x271f6fe7ca0>,
#  'MANSFIELD': <matplotlib.patches.Polygon at 0x271f6fe7d00>,
#  'LINGA': <matplotlib.patches.Polygon at 0x271f6fe7d60>,
#  'BOINKA': <matplotlib.patches.Polygon at 0x271f6fe7dc0>,
#  'TENBY POINT': <matplotlib.patches.Polygon at 0x271f6fe7e20>,
#  'CORONET BAY': <matplotlib.patches.Polygon at 0x271f6fe7e80>,
#  'CORINELLA': <matplotlib.patches.Polygon at 0x271f6fe7ee0>,
#  'CROYDON SOUTH': <matplotlib.patches.Polygon at 0x271f6fe7f40>,
#  'BANKSIA PENINSULA': <matplotlib.patches.Polygon at 0x271f6fe7fa0>,
#  'GEORGES CREEK': <matplotlib.patches.Polygon at 0x271f6fe3040>,
#  'COBURG NORTH': <matplotlib.patches.Polygon at 0x271f6fe30a0>,
#  'PASCOE VALE': <matplotlib.patches.Polygon at 0x271f6fe3100>,
#  'KULWIN': <matplotlib.patches.Polygon at 0x271f6fe3160>,
#  'WALPEUP': <matplotlib.patches.Polygon at 0x271f6fe31c0>,
#  'WYCHEPROOF': <matplotlib.patches.Polygon at 0x271f6fe3220>,
#  'MARENGO': <matplotlib.patches.Polygon at 0x271f6fe3280>,
#  'CAPE OTWAY': <matplotlib.patches.Polygon at 0x271f6fe32e0>,
#  'MOUNT BULLER': <matplotlib.patches.Polygon at 0x271f6fe3340>,
#  'CHETWYND': <matplotlib.patches.Polygon at 0x271f6fe33a0>,
#  'WATTLE HILL': <matplotlib.patches.Polygon at 0x271f6fe3460>,
#  'GELLIBRAND LOWER': <matplotlib.patches.Polygon at 0x271f6fe34c0>,
#  'PRINCETOWN': <matplotlib.patches.Polygon at 0x271f6fe3520>,
#  'PETERBOROUGH': <matplotlib.patches.Polygon at 0x271f6fe3580>,
#  'RUNNYMEDE': <matplotlib.patches.Polygon at 0x271f6fe35e0>,
#  'SCOTSBURN': <matplotlib.patches.Polygon at 0x271f6fe3430>,
#  'REEDY CREEK': <matplotlib.patches.Polygon at 0x271f6fe3640>,
#  'STRATH CREEK': <matplotlib.patches.Polygon at 0x271f6fe36a0>,
#  'JUNGABURRA': <matplotlib.patches.Polygon at 0x271f6fe3700>,
#  'TERRICK TERRICK': <matplotlib.patches.Polygon at 0x271f6fe3760>,
#  'BARJARG': <matplotlib.patches.Polygon at 0x271f6fe37c0>,
#  'MAINDAMPLE': <matplotlib.patches.Polygon at 0x271f6fe3820>,
#  'KEYSBOROUGH': <matplotlib.patches.Polygon at 0x271f6fe3880>,
#  'FUMINA': <matplotlib.patches.Polygon at 0x271f6fe38e0>,
#  'SURREY HILLS': <matplotlib.patches.Polygon at 0x271f6fe3940>,
#  'LAHARUM': <matplotlib.patches.Polygon at 0x271f6fe39a0>,
#  'WATCHUPGA': <matplotlib.patches.Polygon at 0x271f6fe3a00>,
#  'NAREEN': <matplotlib.patches.Polygon at 0x271f6fe3a60>,
#  'HOTSPUR': <matplotlib.patches.Polygon at 0x271f6fe3ac0>,
#  'PIONEER BAY': <matplotlib.patches.Polygon at 0x271f6fe3b20>,
#  'LANG LANG': <matplotlib.patches.Polygon at 0x271f6fe3b80>,
#  'ANDERSON': <matplotlib.patches.Polygon at 0x271f6fe3be0>,
#  'BASS': <matplotlib.patches.Polygon at 0x271f6fe3c40>,
#  'BANGHOLME': <matplotlib.patches.Polygon at 0x271f6fe3ca0>,
#  'TANJIL BREN': <matplotlib.patches.Polygon at 0x271f6fe3d00>,
#  'DUVERNEY': <matplotlib.patches.Polygon at 0x271f6fe3d60>,
#  'LASCELLES': <matplotlib.patches.Polygon at 0x271f6fe3dc0>,
#  'GRAMPIANS': <matplotlib.patches.Polygon at 0x271f6fe3e20>,
#  'MARYSVILLE': <matplotlib.patches.Polygon at 0x271f6fe3e80>,
#  'BENALLA': <matplotlib.patches.Polygon at 0x271f6fe3ee0>,
#  'LONGFORD': <matplotlib.patches.Polygon at 0x271f6fe3f40>,
#  'HEXHAM': <matplotlib.patches.Polygon at 0x271f6fe3fa0>,
#  'PENSHURST': <matplotlib.patches.Polygon at 0x271f7005040>,
#  'GLENTHOMPSON': <matplotlib.patches.Polygon at 0x271f70050a0>,
#  'BURNLEY': <matplotlib.patches.Polygon at 0x271f7005100>,
#  'WINDSOR': <matplotlib.patches.Polygon at 0x271f7005160>,
#  'ESSENDON WEST': <matplotlib.patches.Polygon at 0x271f70051c0>,
#  'TETOORA ROAD': <matplotlib.patches.Polygon at 0x271f7005220>,
#  'GLENDONALD': <matplotlib.patches.Polygon at 0x271f7005280>,
#  'BALMATTUM': <matplotlib.patches.Polygon at 0x271f70052e0>,
#  'WOOMELANG': <matplotlib.patches.Polygon at 0x271f7005340>,
#  'OUYEN': <matplotlib.patches.Polygon at 0x271f70053a0>,
#  'PATCHEWOLLOCK': <matplotlib.patches.Polygon at 0x271f7005400>,
#  'KANIVA': <matplotlib.patches.Polygon at 0x271f7005460>,
#  'KOOREH': <matplotlib.patches.Polygon at 0x271f70054c0>,
#  'NHILL': <matplotlib.patches.Polygon at 0x271f7005520>,
#  'DARTMOUTH': <matplotlib.patches.Polygon at 0x271f7005580>,
#  'TELOPEA DOWNS': <matplotlib.patches.Polygon at 0x271f70055e0>,
#  'DIGGORA': <matplotlib.patches.Polygon at 0x271f7005640>,
#  'GLENISLA': <matplotlib.patches.Polygon at 0x271f70056a0>,
#  'LILLIMUR': <matplotlib.patches.Polygon at 0x271f7005700>,
#  'WULGULMERANG WEST': <matplotlib.patches.Polygon at 0x271f7005760>,
#  'SWAN ISLAND': <matplotlib.patches.Polygon at 0x271f70057c0>,
#  'KYVALLEY': <matplotlib.patches.Polygon at 0x271f7005820>,
#  'BRANXHOLME': <matplotlib.patches.Polygon at 0x271f7005880>,
#  'BORNES HILL': <matplotlib.patches.Polygon at 0x271f70058e0>,
#  'TANJIL': <matplotlib.patches.Polygon at 0x271f7005940>,
#  'GLEN VALLEY': <matplotlib.patches.Polygon at 0x271f70059a0>,
#  'SWIFTS CREEK': <matplotlib.patches.Polygon at 0x271f7005a00>,
#  'MURRINDINDI': <matplotlib.patches.Polygon at 0x271f7005a60>,
#  'ROCKLANDS': <matplotlib.patches.Polygon at 0x271f7005ac0>,
#  'WOOLSTHORPE': <matplotlib.patches.Polygon at 0x271f7005b20>,
#  'ZUMSTEINS': <matplotlib.patches.Polygon at 0x271f7005b80>,
#  'HALLORA': <matplotlib.patches.Polygon at 0x271f7005be0>,
#  'MORNINGTON': <matplotlib.patches.Polygon at 0x271f7005c40>,
#  'WAITCHIE': <matplotlib.patches.Polygon at 0x271f6fbfc10>,
#  'FERNSHAW': <matplotlib.patches.Polygon at 0x271f7005ca0>,
#  'DOUGLAS': <matplotlib.patches.Polygon at 0x271f7005d00>,
#  'LANGKOOP': <matplotlib.patches.Polygon at 0x271f7005d60>,
#  'WENSLEYDALE': <matplotlib.patches.Polygon at 0x271f7005dc0>,
#  'SERVICETON': <matplotlib.patches.Polygon at 0x271f7005e20>,
#  'RUPANYUP': <matplotlib.patches.Polygon at 0x271f7005e80>,
#  'BUCHAN SOUTH': <matplotlib.patches.Polygon at 0x271f7005ee0>,
#  'NETHERBY': <matplotlib.patches.Polygon at 0x271f7005f40>,
#  'ALLAMBEE': <matplotlib.patches.Polygon at 0x271f7005fa0>,
#  'MACARTHUR': <matplotlib.patches.Polygon at 0x271f7018040>,
#  'MARRAWEENEY': <matplotlib.patches.Polygon at 0x271f70180a0>,
#  'RUBICON': <matplotlib.patches.Polygon at 0x271f7018100>,
#  'CARAMUT': <matplotlib.patches.Polygon at 0x271f7018160>,
#  'LISMORE': <matplotlib.patches.Polygon at 0x271f70181c0>,
#  'LICOLA': <matplotlib.patches.Polygon at 0x271f7018220>,
#  'YAAPEET': <matplotlib.patches.Polygon at 0x271f7018280>,
#  'COWANGIE': <matplotlib.patches.Polygon at 0x271f70182e0>,
#  'NARBETHONG': <matplotlib.patches.Polygon at 0x271f7018340>,
#  'BOLWARRAH': <matplotlib.patches.Polygon at 0x271f70183a0>,
#  'SKENES CREEK': <matplotlib.patches.Polygon at 0x271f7018400>,
#  'MAFEKING': <matplotlib.patches.Polygon at 0x271f7018460>,
#  'TERRICK TERRICK EAST': <matplotlib.patches.Polygon at 0x271f70184c0>,
#  'CHURCHILL ISLAND': <matplotlib.patches.Polygon at 0x271f7018520>,
#  'ST KILDA WEST': <matplotlib.patches.Polygon at 0x271f7018580>,
#  'MASSEY': <matplotlib.patches.Polygon at 0x271f70185e0>,
#  'PRINCES HILL': <matplotlib.patches.Polygon at 0x271f7018640>,
#  'SUNSET STRIP': <matplotlib.patches.Polygon at 0x271f70186a0>,
#  'EUREKA': <matplotlib.patches.Polygon at 0x271f7018700>,
#  'WIMBLEDON HEIGHTS': <matplotlib.patches.Polygon at 0x271f7018760>,
#  'RIPPONLEA': <matplotlib.patches.Polygon at 0x271f70187c0>,
#  'GARDENVALE': <matplotlib.patches.Polygon at 0x271f7018820>,
#  'EGANSTOWN': <matplotlib.patches.Polygon at 0x271f7018880>,
#  'WIRRATE': <matplotlib.patches.Polygon at 0x271f70188e0>,
#  'BLACKHEATH': <matplotlib.patches.Polygon at 0x271f7018940>,
#  'DAYLESFORD': <matplotlib.patches.Polygon at 0x271f70189a0>,
#  'NATIMUK': <matplotlib.patches.Polygon at 0x271f7018a00>,
#  'DUCHEMBEGARRA': <matplotlib.patches.Polygon at 0x271f7018a60>,
#  'CLYDE': <matplotlib.patches.Polygon at 0x271f7018ac0>,
#  'LALOR': <matplotlib.patches.Polygon at 0x271f7018b20>,
#  'KERGUNYAH SOUTH': <matplotlib.patches.Polygon at 0x271f7018b80>,
#  'DEDERANG': <matplotlib.patches.Polygon at 0x271f7018be0>,
#  'UPPER GUNDOWRING': <matplotlib.patches.Polygon at 0x271f7018c40>,
#  'NAYOOK': <matplotlib.patches.Polygon at 0x271f7018ca0>,
#  'GENTLE ANNIE': <matplotlib.patches.Polygon at 0x271f7018d00>,
#  'BOOROOL': <matplotlib.patches.Polygon at 0x271f7018d60>,
#  'BERRYS CREEK': <matplotlib.patches.Polygon at 0x271f7018dc0>,
#  'CURLEWIS': <matplotlib.patches.Polygon at 0x271f7018e20>,
#  'WANDANA HEIGHTS': <matplotlib.patches.Polygon at 0x271f7018e80>,
#  'WARANGA SHORES': <matplotlib.patches.Polygon at 0x271f7018ee0>,
#  'WATERFORD PARK': <matplotlib.patches.Polygon at 0x271f7018f40>,
#  'SANDHURST': <matplotlib.patches.Polygon at 0x271f7018fa0>,
#  'CASTERTON': <matplotlib.patches.Polygon at 0x271f6ffc040>,
#  'NELSON': <matplotlib.patches.Polygon at 0x271f6ffc0a0>,
#  'LAKE MUNDI': <matplotlib.patches.Polygon at 0x271f6ffc100>,
#  'BALLAPUR': <matplotlib.patches.Polygon at 0x271f6ffc160>,
#  'CHANDLERS CREEK': <matplotlib.patches.Polygon at 0x271f6ffc1c0>,
#  'HARROW': <matplotlib.patches.Polygon at 0x271f6ffc220>,
#  'REYNARD': <matplotlib.patches.Polygon at 0x271f6ffc280>,
#  'GENOA': <matplotlib.patches.Polygon at 0x271f6ffc2e0>,
#  'HOTHAM HEIGHTS': <matplotlib.patches.Polygon at 0x271f6ffc340>,
#  'SELWYN': <matplotlib.patches.Polygon at 0x271f6ffc3a0>,
#  'HEATH HILL': <matplotlib.patches.Polygon at 0x271f6ffc400>,
#  'ATHLONE': <matplotlib.patches.Polygon at 0x271f6ffc460>,
#  'DRUMBORG': <matplotlib.patches.Polygon at 0x271f6ffc4c0>,
#  'HOPETOUN': <matplotlib.patches.Polygon at 0x271f6ffc520>,
#  'CALLIGNEE SOUTH': <matplotlib.patches.Polygon at 0x271f6ffc580>,
#  'CHINKAPOOK': <matplotlib.patches.Polygon at 0x271f6ffc5e0>,
#  'WHITTINGTON': <matplotlib.patches.Polygon at 0x271f6ffc640>,
#  'JUNCTION VILLAGE': <matplotlib.patches.Polygon at 0x271f6ffc6a0>,
#  'WINCHELSEA SOUTH': <matplotlib.patches.Polygon at 0x271f6ffc700>,
#  'TUNGAMAH': <matplotlib.patches.Polygon at 0x271f6ffc760>,
#  'WOODGLEN': <matplotlib.patches.Polygon at 0x271f6ffc7c0>,
#  'EAGLE POINT': <matplotlib.patches.Polygon at 0x271f6ffc820>,
#  'JOHNSONVILLE': <matplotlib.patches.Polygon at 0x271f6ffc880>,
#  'NEWCOMB': <matplotlib.patches.Polygon at 0x271f6ffc8e0>,
#  'YANAKIE': <matplotlib.patches.Polygon at 0x271f6ffc940>,
#  'GHERANG': <matplotlib.patches.Polygon at 0x271f6ffc9a0>,
#  'POREPUNKAH': <matplotlib.patches.Polygon at 0x271f6ffca00>,
#  'ALBACUTYA': <matplotlib.patches.Polygon at 0x271f6ffca60>,
#  'SOUTH DUDLEY': <matplotlib.patches.Polygon at 0x271f6ffcac0>,
#  'DALYSTON': <matplotlib.patches.Polygon at 0x271f6ffcb20>,
#  'WEST CREEK': <matplotlib.patches.Polygon at 0x271f6ffcb80>,
#  'SAN REMO': <matplotlib.patches.Polygon at 0x271f6ffcbe0>,
#  'ROSEBROOK': <matplotlib.patches.Polygon at 0x271f6ffcc40>,
#  'WEDDERBURN': <matplotlib.patches.Polygon at 0x271f6ffcca0>,
#  'NELSE': <matplotlib.patches.Polygon at 0x271f6ffcd00>,
#  'BULDAH': <matplotlib.patches.Polygon at 0x271f6ffcd60>,
#  'TORRITA': <matplotlib.patches.Polygon at 0x271f6ffcdc0>,
#  'NEUARPURR': <matplotlib.patches.Polygon at 0x271f6ffce20>,
#  'BOORT': <matplotlib.patches.Polygon at 0x271f6ffce80>,
#  'BEAUCHAMP': <matplotlib.patches.Polygon at 0x271f6ffcee0>,
#  'ARCHIES CREEK': <matplotlib.patches.Polygon at 0x271f6ffcf40>,
#  'TANYBRYN': <matplotlib.patches.Polygon at 0x271f6ffcfa0>,
#  'HAWKESDALE': <matplotlib.patches.Polygon at 0x271f6ffa040>,
#  'ANNUELLO': <matplotlib.patches.Polygon at 0x271f6ffa0a0>,
#  'BIG DESERT': <matplotlib.patches.Polygon at 0x271f6ffa100>,
#  'MERRINEE': <matplotlib.patches.Polygon at 0x271f6ffa160>,
#  'BENAMBRA': <matplotlib.patches.Polygon at 0x271f6ffa1c0>,
#  'MERINGUR': <matplotlib.patches.Polygon at 0x271f6ffa220>,
#  'WOODSTOCK': <matplotlib.patches.Polygon at 0x271f6ffa280>,
#  'BELLBRAE': <matplotlib.patches.Polygon at 0x271f6ffa2e0>,
#  'KENMARE': <matplotlib.patches.Polygon at 0x271f6ffa340>,
#  'WILLENABRINA': <matplotlib.patches.Polygon at 0x271f6ffa3a0>,
#  'FISKVILLE': <matplotlib.patches.Polygon at 0x271f6ffa400>,
#  'CRYMELON': <matplotlib.patches.Polygon at 0x271f6ffa460>,
#  'AUBREY': <matplotlib.patches.Polygon at 0x271f6ffa4c0>,
#  'BLACKWOOD': <matplotlib.patches.Polygon at 0x271f6ffa520>,
#  'NULLA VALE': <matplotlib.patches.Polygon at 0x271f6ffa580>,
#  'INGLISTON': <matplotlib.patches.Polygon at 0x271f6ffa5e0>,
#  'WOOLAMAI': <matplotlib.patches.Polygon at 0x271f6ffa640>,
#  'ALMURTA': <matplotlib.patches.Polygon at 0x271f6ffa6a0>,
#  'CAPE PATERSON': <matplotlib.patches.Polygon at 0x271f6ffa700>,
#  'KILCUNDA': <matplotlib.patches.Polygon at 0x271f6ffa760>,
#  'WERRIMULL': <matplotlib.patches.Polygon at 0x271f6ffa7c0>,
#  'WINGAN RIVER': <matplotlib.patches.Polygon at 0x271f6ffa820>,
#  'PYRAMID HILL': <matplotlib.patches.Polygon at 0x271f6ffa880>,
#  'COMBIENBAR': <matplotlib.patches.Polygon at 0x271f6ffa8e0>,
#  'MOUNT RICHMOND': <matplotlib.patches.Polygon at 0x271f6ffa940>,
#  'LAKE MARMAL': <matplotlib.patches.Polygon at 0x271f6ffa9a0>,
#  'NEWBURY': <matplotlib.patches.Polygon at 0x271f6ffaa00>,
#  'WARRAGUL SOUTH': <matplotlib.patches.Polygon at 0x271f6ffaa60>,
#  'HORDERN VALE': <matplotlib.patches.Polygon at 0x271f6ffaac0>,
#  'BUNGEET WEST': <matplotlib.patches.Polygon at 0x271f6ffab20>,
#  'DEAN': <matplotlib.patches.Polygon at 0x271f6ffab80>,
#  'WATTLE BANK': <matplotlib.patches.Polygon at 0x271f6ffabe0>,
#  'ST CLAIR': <matplotlib.patches.Polygon at 0x271f6ffac40>,
#  'HORSHAM': <matplotlib.patches.Polygon at 0x271f6ffaca0>,
#  'LONGERENONG': <matplotlib.patches.Polygon at 0x271f6ffad00>,
#  'TATYOON': <matplotlib.patches.Polygon at 0x271f6ffad60>,
#  'BARKERS CREEK': <matplotlib.patches.Polygon at 0x271f6ffadc0>,
#  'WONTHAGGI': <matplotlib.patches.Polygon at 0x271f6ffae20>,
#  'KNOXFIELD': <matplotlib.patches.Polygon at 0x271f6ffae80>,
#  'MARTHAVALE': <matplotlib.patches.Polygon at 0x271f6ffaee0>,
#  'DORODONG': <matplotlib.patches.Polygon at 0x271f6ffaf40>,
#  'NOORINBEE NORTH': <matplotlib.patches.Polygon at 0x271f6ffafa0>,
#  'TOOMBON': <matplotlib.patches.Polygon at 0x271f702d040>,
#  'LAKE BOLAC': <matplotlib.patches.Polygon at 0x271f702d0a0>,
#  'ULTIMA': <matplotlib.patches.Polygon at 0x271f702d100>,
#  'BUMBERRAH': <matplotlib.patches.Polygon at 0x271f702d160>,
#  'SKENES CREEK NORTH': <matplotlib.patches.Polygon at 0x271f702d1c0>,
#  'WYE RIVER': <matplotlib.patches.Polygon at 0x271f702d220>,
#  'CAPE BRIDGEWATER': <matplotlib.patches.Polygon at 0x271f702d280>,
#  'KENNETT RIVER': <matplotlib.patches.Polygon at 0x271f702d2e0>,
#  'GREY RIVER': <matplotlib.patches.Polygon at 0x271f702d340>,
#  'PETTICOAT CREEK': <matplotlib.patches.Polygon at 0x271f702d3a0>,
#  'HARMERS HAVEN': <matplotlib.patches.Polygon at 0x271f702d400>,
#  'NORTH WONTHAGGI': <matplotlib.patches.Polygon at 0x271f702d460>,
#  'DANDENONG SOUTH': <matplotlib.patches.Polygon at 0x271f702d4c0>,
#  'DANDENONG': <matplotlib.patches.Polygon at 0x271f702d520>,
#  'LYNDHURST': <matplotlib.patches.Polygon at 0x271f702d580>,
#  'LYNBROOK': <matplotlib.patches.Polygon at 0x271f702d5e0>,
#  'JAM JERRUP': <matplotlib.patches.Polygon at 0x271f702d640>,
#  'WULGULMERANG': <matplotlib.patches.Polygon at 0x271f702d6a0>,
#  'WULGULMERANG EAST': <matplotlib.patches.Polygon at 0x271f702d700>,
#  'BRUMBY': <matplotlib.patches.Polygon at 0x271f702d760>,
#  'SWAN REACH': <matplotlib.patches.Polygon at 0x271f702d7c0>,
#  'FERNY CREEK': <matplotlib.patches.Polygon at 0x271f702d820>,
#  'CAIRNLEA': <matplotlib.patches.Polygon at 0x271f702d880>,
#  'TYRRELL': <matplotlib.patches.Polygon at 0x271f702d8e0>,
#  'DALES CREEK': <matplotlib.patches.Polygon at 0x271f702d940>,
#  'BAMBRA': <matplotlib.patches.Polygon at 0x271f702d9a0>,
#  'MAIN LEAD': <matplotlib.patches.Polygon at 0x271f702da00>,
#  'WESTMEADOWS': <matplotlib.patches.Polygon at 0x271f702da60>,
#  'PATTERSON LAKES': <matplotlib.patches.Polygon at 0x271f702dac0>,
#  'BURWOOD EAST': <matplotlib.patches.Polygon at 0x271f702db20>,
#  'NOORINBEE': <matplotlib.patches.Polygon at 0x271f702db80>,
#  'AIRPORT WEST': <matplotlib.patches.Polygon at 0x271f702dbe0>,
#  'PATYAH': <matplotlib.patches.Polygon at 0x271f702dc40>,
#  'MORTLAKE': <matplotlib.patches.Polygon at 0x271f702dca0>,
#  'QUAMBATOOK': <matplotlib.patches.Polygon at 0x271f702dd00>,
#  'TYNTYNDER SOUTH': <matplotlib.patches.Polygon at 0x271f702dd60>,
#  'ASHWOOD': <matplotlib.patches.Polygon at 0x271f702ddc0>,
#  'DRUMMOND': <matplotlib.patches.Polygon at 0x271f702de20>,
#  'PENTLAND HILLS': <matplotlib.patches.Polygon at 0x271f702de80>,
#  'SEAFORD': <matplotlib.patches.Polygon at 0x271f702dee0>,
#  'BEULAH': <matplotlib.patches.Polygon at 0x271f702df40>,
#  'KINNABULLA': <matplotlib.patches.Polygon at 0x271f702dfa0>,
#  'NANGANA': <matplotlib.patches.Polygon at 0x271f700f040>,
#  'NEILBOROUGH': <matplotlib.patches.Polygon at 0x271f700f0a0>,
#  'MARYKNOLL': <matplotlib.patches.Polygon at 0x271f700f100>,
#  'WHIPSTICK': <matplotlib.patches.Polygon at 0x271f700f160>,
#  'AIRLY': <matplotlib.patches.Polygon at 0x271f700f1c0>,
#  'LAMPLOUGH': <matplotlib.patches.Polygon at 0x271f700f220>,
#  'BELLBIRD CREEK': <matplotlib.patches.Polygon at 0x271f700f280>,
#  'GOUGHS BAY': <matplotlib.patches.Polygon at 0x271f700f2e0>,
#  'MYRTLEFORD': <matplotlib.patches.Polygon at 0x271f700f340>,
#  'BUCKLAND': <matplotlib.patches.Polygon at 0x271f700f3a0>,
#  'MOUNT BUFFALO': <matplotlib.patches.Polygon at 0x271f700f400>,
#  'MALLACOOTA': <matplotlib.patches.Polygon at 0x271f700f460>,
#  'BARWON DOWNS': <matplotlib.patches.Polygon at 0x271f700f4c0>,
#  'LALBERT': <matplotlib.patches.Polygon at 0x271f700f520>,
#  'APSLEY': <matplotlib.patches.Polygon at 0x271f700f580>,
#  'WHIRILY': <matplotlib.patches.Polygon at 0x271f700f5e0>,
#  'BILLABONG': <matplotlib.patches.Polygon at 0x271f700f640>,
#  'HOWITT PLAINS': <matplotlib.patches.Polygon at 0x271f700f6a0>,
#  'CALIFORNIA GULLY': <matplotlib.patches.Polygon at 0x271f700f700>,
#  'HIGHETT': <matplotlib.patches.Polygon at 0x271f700f760>,
#  'CLARINDA': <matplotlib.patches.Polygon at 0x271f700f7c0>,
#  'INVERMAY PARK': <matplotlib.patches.Polygon at 0x271f700f820>,
#  'CORACK EAST': <matplotlib.patches.Polygon at 0x271f700f880>,
#  'CADELLO': <matplotlib.patches.Polygon at 0x271f700f8e0>,
#  'RINGWOOD NORTH': <matplotlib.patches.Polygon at 0x271f700f940>,
#  'MONTGOMERY': <matplotlib.patches.Polygon at 0x271f700f9a0>,
#  'MARIBYRNONG': <matplotlib.patches.Polygon at 0x271f700fa00>,
#  'CAMPBELLFIELD': <matplotlib.patches.Polygon at 0x271f700fa60>,
#  'DOCKLANDS': <matplotlib.patches.Polygon at 0x271f700fac0>,
#  'HOPETOUN PARK': <matplotlib.patches.Polygon at 0x271f700fb20>,
#  'ROCKY POINT': <matplotlib.patches.Polygon at 0x271f700fb80>,
#  'NUTFIELD': <matplotlib.patches.Polygon at 0x271f700fbe0>,
#  'PAYNESVILLE': <matplotlib.patches.Polygon at 0x271f700fc40>,
#  'ANGLESEA': <matplotlib.patches.Polygon at 0x271f700fca0>,
#  'BONNIE DOON': <matplotlib.patches.Polygon at 0x271f700fd00>,
#  'MIGA LAKE': <matplotlib.patches.Polygon at 0x271f700fd60>,
#  'NORADJUHA': <matplotlib.patches.Polygon at 0x271f700fdc0>,
#  'TALLAROOK': <matplotlib.patches.Polygon at 0x271f700fe20>,
#  'YEA': <matplotlib.patches.Polygon at 0x271f700fe80>,
#  'GLENORCHY': <matplotlib.patches.Polygon at 0x271f700fee0>,
#  'SAILORS HILL': <matplotlib.patches.Polygon at 0x271f700ff40>,
#  'MONT ALBERT': <matplotlib.patches.Polygon at 0x271f700ffa0>,
#  'CLIFTON HILL': <matplotlib.patches.Polygon at 0x271f7011040>,
#  'RIPPLESIDE': <matplotlib.patches.Polygon at 0x271f70110a0>,
#  'NOBLE PARK NORTH': <matplotlib.patches.Polygon at 0x271f7011100>,
#  'GEELONG': <matplotlib.patches.Polygon at 0x271f7011160>,
#  'CAULFIELD SOUTH': <matplotlib.patches.Polygon at 0x271f70111c0>,
#  'RICHMOND': <matplotlib.patches.Polygon at 0x271f7011220>,
#  'TORWOOD': <matplotlib.patches.Polygon at 0x271f7011280>,
#  'MORDIALLOC': <matplotlib.patches.Polygon at 0x271f70112e0>,
#  'PANTON HILL': <matplotlib.patches.Polygon at 0x271f7011340>,
#  'CORAL BANK': <matplotlib.patches.Polygon at 0x271f70113a0>,
#  'BARNADOWN': <matplotlib.patches.Polygon at 0x271f7011400>,
#  'MARIONVALE': <matplotlib.patches.Polygon at 0x271f7011460>,
#  'COLBROOK': <matplotlib.patches.Polygon at 0x271f70114c0>,
#  'KILLARA': <matplotlib.patches.Polygon at 0x271f7050d60>,
#  'NOTTING HILL': <matplotlib.patches.Polygon at 0x271f7011580>,
#  'YANGOURA': <matplotlib.patches.Polygon at 0x271f70115e0>,
#  'CHILTERN': <matplotlib.patches.Polygon at 0x271f7011640>,
#  'GOLDEN GULLY': <matplotlib.patches.Polygon at 0x271f70116a0>,
#  'ST KILDA': <matplotlib.patches.Polygon at 0x271f7011700>,
#  'WARRAGUL WEST': <matplotlib.patches.Polygon at 0x271f7011760>,
#  'MOGGS CREEK': <matplotlib.patches.Polygon at 0x271f70117c0>,
#  'PARADISE BEACH': <matplotlib.patches.Polygon at 0x271f7011820>,
#  'BLACK ROCK': <matplotlib.patches.Polygon at 0x271f7011880>,
#  'NORTH GEELONG': <matplotlib.patches.Polygon at 0x271f70118e0>,
#  'FAIRHAVEN': <matplotlib.patches.Polygon at 0x271f7011940>,
#  'EASTERN VIEW': <matplotlib.patches.Polygon at 0x271f70119a0>,
#  'BRAYBROOK': <matplotlib.patches.Polygon at 0x271f7011a00>,
#  'WARRANDYTE SOUTH': <matplotlib.patches.Polygon at 0x271f7011a60>,
#  'LEIGH CREEK': <matplotlib.patches.Polygon at 0x271f7011ac0>,
#  'GERMANTOWN': <matplotlib.patches.Polygon at 0x271f7011b20>,
#  'EMU CREEK': <matplotlib.patches.Polygon at 0x271f7011b80>,
#  'MONOMEITH': <matplotlib.patches.Polygon at 0x271f7011be0>,
#  'VERVALE': <matplotlib.patches.Polygon at 0x271f7011c40>,
#  'THORPDALE': <matplotlib.patches.Polygon at 0x271f7011ca0>,
#  'ABERFELDY': <matplotlib.patches.Polygon at 0x271f7011d00>,
#  'NAREEWILLOCK': <matplotlib.patches.Polygon at 0x271f7011d60>,
#  'DRYSDALE': <matplotlib.patches.Polygon at 0x271f7011dc0>,
#  'ST KILDA EAST': <matplotlib.patches.Polygon at 0x271f7011e20>,
#  'TENNYSON': <matplotlib.patches.Polygon at 0x271f7011e80>,
#  'THE PATCH': <matplotlib.patches.Polygon at 0x271f7011ee0>,
#  'GLADSTONE PARK': <matplotlib.patches.Polygon at 0x271f7011f40>,
#  'MAIDSTONE': <matplotlib.patches.Polygon at 0x271f7011fa0>,
#  'BREAKWATER': <matplotlib.patches.Polygon at 0x271f7032040>,
#  'ST ALBANS PARK': <matplotlib.patches.Polygon at 0x271f70320a0>,
#  'NEWLANDS ARM': <matplotlib.patches.Polygon at 0x271f7032100>,
#  'BELGRAVE': <matplotlib.patches.Polygon at 0x271f7032160>,
#  'CAULFIELD NORTH': <matplotlib.patches.Polygon at 0x271f70321c0>,
#  'DOVETON': <matplotlib.patches.Polygon at 0x271f7032220>,
#  'CREEK JUNCTION': <matplotlib.patches.Polygon at 0x271f7032280>,
#  'LINDENOW': <matplotlib.patches.Polygon at 0x271f70322e0>,
#  'PAARATTE': <matplotlib.patches.Polygon at 0x271f7032340>,
#  'EXFORD': <matplotlib.patches.Polygon at 0x271f70323a0>,
#  'GOORAM': <matplotlib.patches.Polygon at 0x271f7032400>,
#  'SMITHS BEACH': <matplotlib.patches.Polygon at 0x271f7032460>,
#  'TANTARABOO': <matplotlib.patches.Polygon at 0x271f70324c0>,
#  'ABERFELDIE': <matplotlib.patches.Polygon at 0x271f7032520>,
#  'BAROMI': <matplotlib.patches.Polygon at 0x271f7032580>,
#  'BAKERY HILL': <matplotlib.patches.Polygon at 0x271f70325e0>,
#  'CHADSTONE': <matplotlib.patches.Polygon at 0x271f7032640>,
#  'AIREYS INLET': <matplotlib.patches.Polygon at 0x271f70326a0>,
#  'BRIDGEWATER ON LODDON': <matplotlib.patches.Polygon at 0x271f7032700>,
#  'MOUNT PLEASANT': <matplotlib.patches.Polygon at 0x271f7032760>,
#  'NORTH BENDIGO': <matplotlib.patches.Polygon at 0x271f70327c0>,
#  'NILMA': <matplotlib.patches.Polygon at 0x271f7032820>,
#  'LONGLEA': <matplotlib.patches.Polygon at 0x271f7032880>,
#  'FOREST HILL': <matplotlib.patches.Polygon at 0x271f70328e0>,
#  'RYTHDALE': <matplotlib.patches.Polygon at 0x271f7032940>,
#  'BURNEWANG': <matplotlib.patches.Polygon at 0x271f70329a0>,
#  'ESSENDON FIELDS': <matplotlib.patches.Polygon at 0x271f7032a00>,
#  'WEEAPROINAH': <matplotlib.patches.Polygon at 0x271f7032a60>,
#  'BALD HILLS': <matplotlib.patches.Polygon at 0x271f7032ac0>,
#  'BUFFALO': <matplotlib.patches.Polygon at 0x271f7032b20>,
#  'ROSANNA': <matplotlib.patches.Polygon at 0x271f7032b80>,
#  'MOE': <matplotlib.patches.Polygon at 0x271f7032be0>,
#  'SALISBURY WEST': <matplotlib.patches.Polygon at 0x271f7032c40>,
#  'BRIDGEWATER NORTH': <matplotlib.patches.Polygon at 0x271f7032ca0>,
#  'MOUNT ECCLES': <matplotlib.patches.Polygon at 0x271f7032d00>,
#  'LEONGATHA NORTH': <matplotlib.patches.Polygon at 0x271f7032d60>,
#  'TARNEIT': <matplotlib.patches.Polygon at 0x271f7032dc0>,
#  'TRAFALGAR SOUTH': <matplotlib.patches.Polygon at 0x271f7032e20>,
#  'THOMSON': <matplotlib.patches.Polygon at 0x271f8136f70>,
#  'PARWAN': <matplotlib.patches.Polygon at 0x271f7032ee0>,
#  'ARMSTRONG': <matplotlib.patches.Polygon at 0x271f7032f40>,
#  'MURRAWEE': <matplotlib.patches.Polygon at 0x271f7032fa0>,
#  'REDAN': <matplotlib.patches.Polygon at 0x271f7050040>,
#  'KENSINGTON': <matplotlib.patches.Polygon at 0x271f70500a0>,
#  'OAKLEIGH EAST': <matplotlib.patches.Polygon at 0x271f7050100>,
#  'EDITHVALE': <matplotlib.patches.Polygon at 0x271f7050160>,
#  'SCOTCHMANS LEAD': <matplotlib.patches.Polygon at 0x271f70501c0>,
#  'BAW BAW VILLAGE': <matplotlib.patches.Polygon at 0x271f7050220>,
#  'HEATHMONT': <matplotlib.patches.Polygon at 0x271f7050280>,
#  'SHAYS FLAT': <matplotlib.patches.Polygon at 0x271f70502e0>,
#  'NUNGURNER': <matplotlib.patches.Polygon at 0x271f7050340>,
#  'ILLOWA': <matplotlib.patches.Polygon at 0x271f70503a0>,
#  'DAWSON': <matplotlib.patches.Polygon at 0x271f7050400>,
#  'SEAVIEW': <matplotlib.patches.Polygon at 0x271f7050460>,
#  'BARRAKEE': <matplotlib.patches.Polygon at 0x271f70504c0>,
#  'ALMA': <matplotlib.patches.Polygon at 0x271f7050520>,
#  'CHINTIN': <matplotlib.patches.Polygon at 0x271f7050580>,
#  'LAKES ENTRANCE': <matplotlib.patches.Polygon at 0x271f70505e0>,
#  'HAVELOCK': <matplotlib.patches.Polygon at 0x271f7050640>,
#  'CHARLEMONT': <matplotlib.patches.Polygon at 0x271f70506a0>,
#  'CORNELLA': <matplotlib.patches.Polygon at 0x271f7050700>,
#  'YALMY': <matplotlib.patches.Polygon at 0x271f7050760>,
#  'BUCHAN': <matplotlib.patches.Polygon at 0x271f70507c0>,
#  'SEAHOLME': <matplotlib.patches.Polygon at 0x271f7050820>,
#  'IRONBARK': <matplotlib.patches.Polygon at 0x271f7050880>,
#  'HUGHESDALE': <matplotlib.patches.Polygon at 0x271f70508e0>,
#  'LAKE BUNGA': <matplotlib.patches.Polygon at 0x271f7050940>,
#  'FOOTSCRAY': <matplotlib.patches.Polygon at 0x271f70509a0>,
#  'IRISHTOWN': <matplotlib.patches.Polygon at 0x271f7050a00>,
#  'QUARRY HILL': <matplotlib.patches.Polygon at 0x271f7050a60>,
#  'NORTH MELBOURNE': <matplotlib.patches.Polygon at 0x271f7050ac0>,
#  'ARDEER': <matplotlib.patches.Polygon at 0x271f7050b20>,
#  'LONG GULLY': <matplotlib.patches.Polygon at 0x271f7050b80>,
#  'ELEVATED PLAINS': <matplotlib.patches.Polygon at 0x271f7050be0>,
#  'MOONLIGHT FLAT': <matplotlib.patches.Polygon at 0x271f709f910>,
#  'NATHALIA': <matplotlib.patches.Polygon at 0x271f7050ca0>,
#  'STIRLING': <matplotlib.patches.Polygon at 0x271f7050d00>,
#  'STRADBROKE': <matplotlib.patches.Polygon at 0x271f7011520>,
#  'HAMPTON EAST': <matplotlib.patches.Polygon at 0x271f7050dc0>,
#  'FITZROY': <matplotlib.patches.Polygon at 0x271f7050e20>,
#  'GOLDEN POINT': <matplotlib.patches.Polygon at 0x271f708da90>,
#  'GOWANBRAE': <matplotlib.patches.Polygon at 0x271f7050ee0>,
#  'COLLINGWOOD': <matplotlib.patches.Polygon at 0x271f7050f40>,
#  'NEWINGTON': <matplotlib.patches.Polygon at 0x271f7050fa0>,
#  'CARNEGIE': <matplotlib.patches.Polygon at 0x271f7062040>,
#  'WEST BENDIGO': <matplotlib.patches.Polygon at 0x271f70620a0>,
#  'MCCRAE': <matplotlib.patches.Polygon at 0x271f7062100>,
#  'HEATHERTON': <matplotlib.patches.Polygon at 0x271f7062160>,
#  'EAGLEHAWK': <matplotlib.patches.Polygon at 0x271f70621c0>,
#  'LAVERTON': <matplotlib.patches.Polygon at 0x271f7062220>,
#  'BANGERANG': <matplotlib.patches.Polygon at 0x271f7062280>,
#  'BROOKVILLE': <matplotlib.patches.Polygon at 0x271f70622e0>,
#  'JACANA': <matplotlib.patches.Polygon at 0x271f7062340>,
#  'TYLDEN SOUTH': <matplotlib.patches.Polygon at 0x271f70623a0>,
#  'MOUNT ECCLES SOUTH': <matplotlib.patches.Polygon at 0x271f7062400>,
#  'KINGSBURY': <matplotlib.patches.Polygon at 0x271f7062460>,
#  'THALLOO': <matplotlib.patches.Polygon at 0x271f70624c0>,
#  'CAULFIELD EAST': <matplotlib.patches.Polygon at 0x271f7062520>,
#  'SUNDERLAND BAY': <matplotlib.patches.Polygon at 0x271f7062580>,
#  'CAMPERDOWN': <matplotlib.patches.Polygon at 0x271f70625e0>,
#  'WEST FOOTSCRAY': <matplotlib.patches.Polygon at 0x271f7062640>,
#  'ALBANVALE': <matplotlib.patches.Polygon at 0x271f7050e80>,
#  'NORTH SHORE': <matplotlib.patches.Polygon at 0x271f7062700>,
#  'THALIA': <matplotlib.patches.Polygon at 0x271f7062760>,
#  'BALLARAT CENTRAL': <matplotlib.patches.Polygon at 0x271f70627c0>,
#  'RAWSON': <matplotlib.patches.Polygon at 0x271f7062820>,
#  'DEWHURST': <matplotlib.patches.Polygon at 0x271f7062880>,
#  'MCKINNON': <matplotlib.patches.Polygon at 0x271f70628e0>,
#  'TOTTENHAM': <matplotlib.patches.Polygon at 0x271f7062940>,
#  'SOLDIERS HILL': <matplotlib.patches.Polygon at 0x271f70629a0>,
#  'CHEWTON BUSHLANDS': <matplotlib.patches.Polygon at 0x271f7062a00>,
#  'CAULFIELD': <matplotlib.patches.Polygon at 0x271f7062a90>,
#  'EUMEMMERRING': <matplotlib.patches.Polygon at 0x271e681d3d0>,
#  'ELLIMINYT': <matplotlib.patches.Polygon at 0x271f7062af0>,
#  'MODEWARRE': <matplotlib.patches.Polygon at 0x271f7062b80>,
#  'TIDAL RIVER': <matplotlib.patches.Polygon at 0x271f7062c10>,
#  'MORIAC': <matplotlib.patches.Polygon at 0x271f7062c70>,
#  'AVALON': <matplotlib.patches.Polygon at 0x271f7062cd0>,
#  'YARRAVILLE': <matplotlib.patches.Polygon at 0x271f7062d30>,
#  'MELBOURNE': <matplotlib.patches.Polygon at 0x271f7062d90>,
#  'MOONEE PONDS': <matplotlib.patches.Polygon at 0x271f7062df0>,
#  'GLENROY': <matplotlib.patches.Polygon at 0x271f7062e50>,
#  'MAIDEN GULLY': <matplotlib.patches.Polygon at 0x271f7062eb0>,
#  'MELWOOD': <matplotlib.patches.Polygon at 0x271f7062f10>,
#  'ELLINBANK': <matplotlib.patches.Polygon at 0x271f7062f70>,
#  'BAYSWATER': <matplotlib.patches.Polygon at 0x271f7062fd0>,
#  'MURCHISON': <matplotlib.patches.Polygon at 0x271f7055070>,
#  'BALLARAT EAST': <matplotlib.patches.Polygon at 0x271f70550d0>,
#  'DROUIN EAST': <matplotlib.patches.Polygon at 0x271f7055130>,
#  'BEND OF ISLANDS': <matplotlib.patches.Polygon at 0x271f7055190>,
#  'WOODSIDE BEACH': <matplotlib.patches.Polygon at 0x271f70551f0>,
#  'UPWEY': <matplotlib.patches.Polygon at 0x271f7055250>,
#  'BASALT': <matplotlib.patches.Polygon at 0x271f70552b0>,
#  'VERMONT SOUTH': <matplotlib.patches.Polygon at 0x271f7055310>,
#  'JAN JUC': <matplotlib.patches.Polygon at 0x271f7055370>,
#  'EAGLEHAWK NORTH': <matplotlib.patches.Polygon at 0x271f70553d0>,
#  'KATANDRA': <matplotlib.patches.Polygon at 0x271f7055430>,
#  'MANANGATANG': <matplotlib.patches.Polygon at 0x271f7055490>,
#  'WAGGARANDALL': <matplotlib.patches.Polygon at 0x271f70554f0>,
#  'YABBA NORTH': <matplotlib.patches.Polygon at 0x271f7055550>,
#  'BOORHAMAN EAST': <matplotlib.patches.Polygon at 0x271f70555b0>,
#  'MCKENZIE HILL': <matplotlib.patches.Polygon at 0x271f7055610>,
#  'BLACKBURN SOUTH': <matplotlib.patches.Polygon at 0x271f7055670>,
#  'BOX HILL SOUTH': <matplotlib.patches.Polygon at 0x271f70556d0>,
#  'OAKLEIGH': <matplotlib.patches.Polygon at 0x271f7055730>,
#  'CHELSEA HEIGHTS': <matplotlib.patches.Polygon at 0x271f7055790>,
#  'BLIND BIGHT': <matplotlib.patches.Polygon at 0x271f70557f0>,
#  'YORK PLAINS': <matplotlib.patches.Polygon at 0x271f7055850>,
#  'SAFETY BEACH': <matplotlib.patches.Polygon at 0x271f70558b0>,
#  'CAPE WOOLAMAI': <matplotlib.patches.Polygon at 0x271f7055910>,
#  'BITTERN': <matplotlib.patches.Polygon at 0x271f7055970>,
#  'HAMLYN HEIGHTS': <matplotlib.patches.Polygon at 0x271f70559d0>,
#  'WILLIAMS LANDING': <matplotlib.patches.Polygon at 0x271f7055a30>,
#  'DARRIMAN': <matplotlib.patches.Polygon at 0x271f7055a90>,
#  'VICTORIA VALLEY': <matplotlib.patches.Polygon at 0x271f7055af0>,
#  'LESLIE MANOR': <matplotlib.patches.Polygon at 0x271f7055b50>,
#  'CROOKED RIVER': <matplotlib.patches.Polygon at 0x271f7055bb0>,
#  'CURYO': <matplotlib.patches.Polygon at 0x271f7055c10>,
#  'ABBOTSFORD': <matplotlib.patches.Polygon at 0x271f7055c70>,
#  'SILVERLEAVES': <matplotlib.patches.Polygon at 0x271f7055cd0>,
#  'SUMMERLANDS': <matplotlib.patches.Polygon at 0x271f7055d30>,
#  'PARKDALE': <matplotlib.patches.Polygon at 0x271f7055d90>,
#  'CLEMATIS': <matplotlib.patches.Polygon at 0x271f7055df0>,
#  'TECOMA': <matplotlib.patches.Polygon at 0x271f7055e50>,
#  'WATSONS CREEK': <matplotlib.patches.Polygon at 0x271f7055eb0>,
#  'WILLIAMSTOWN NORTH': <matplotlib.patches.Polygon at 0x271f7055f10>,
#  'WARRANWOOD': <matplotlib.patches.Polygon at 0x271f7055f70>,
#  'COOLAROO': <matplotlib.patches.Polygon at 0x271f7055fd0>,
#  'ASPENDALE': <matplotlib.patches.Polygon at 0x271e5eb8f10>,
#  'WOODEND': <matplotlib.patches.Polygon at 0x271f70460a0>,
#  'CHAPEL FLAT': <matplotlib.patches.Polygon at 0x271f7046100>,
#  'SAMARIA': <matplotlib.patches.Polygon at 0x271f7046160>,
#  'FRENCH ISLAND': <matplotlib.patches.Polygon at 0x271f70461c0>,
#  'CHUTE': <matplotlib.patches.Polygon at 0x271f7046220>,
#  'MOUNT LONARCH': <matplotlib.patches.Polygon at 0x271f7046280>,
#  'GLENLOGIE': <matplotlib.patches.Polygon at 0x271f70462e0>,
#  'RAGLAN': <matplotlib.patches.Polygon at 0x271f7046340>,
#  'WERRIBEE SOUTH': <matplotlib.patches.Polygon at 0x271f70463a0>,
#  'POINT COOK': <matplotlib.patches.Polygon at 0x271f7046400>,
#  'SIMPSON': <matplotlib.patches.Polygon at 0x271f7046460>,
#  'IRREWILLIPE': <matplotlib.patches.Polygon at 0x271f70464c0>,
#  'CARLISLE RIVER': <matplotlib.patches.Polygon at 0x271f7046520>,
#  'ARCHERTON': <matplotlib.patches.Polygon at 0x271f7046580>,
#  'TATONG': <matplotlib.patches.Polygon at 0x271f70465e0>,
#  'AIRE VALLEY': <matplotlib.patches.Polygon at 0x271f7046640>,
#  'APOLLO BAY': <matplotlib.patches.Polygon at 0x271f70466a0>,
#  'BEECH FOREST': <matplotlib.patches.Polygon at 0x271f7046700>,
#  'SPOTSWOOD': <matplotlib.patches.Polygon at 0x271f7046760>,
#  'NEWPORT': <matplotlib.patches.Polygon at 0x271f70467c0>,
#  'MOUNT MORIAC': <matplotlib.patches.Polygon at 0x271f7046820>,
#  'CARINA': <matplotlib.patches.Polygon at 0x271f7046880>,
#  'BESSIEBELLE': <matplotlib.patches.Polygon at 0x271f70468e0>,
#  'NUMURKAH': <matplotlib.patches.Polygon at 0x271f7046940>,
#  'BLACK HILL': <matplotlib.patches.Polygon at 0x271f70469a0>,
#  'DRUMCONDRA': <matplotlib.patches.Polygon at 0x271f7046a00>,
#  'BENNISON': <matplotlib.patches.Polygon at 0x271f7046a60>,
#  'BOX HILL': <matplotlib.patches.Polygon at 0x271f7046ac0>,
#  'TOOTGAROOK': <matplotlib.patches.Polygon at 0x271f7046b20>,
#  'FRANKSTON NORTH': <matplotlib.patches.Polygon at 0x271f7046b80>,
#  'LILLICO': <matplotlib.patches.Polygon at 0x271f7046be0>,
#  'NUNAWADING': <matplotlib.patches.Polygon at 0x271f7046c40>,
#  'MOUNT SABINE': <matplotlib.patches.Polygon at 0x271f7046ca0>,
#  'BLAIRGOWRIE': <matplotlib.patches.Polygon at 0x271f7046d00>,
#  'NORLANE': <matplotlib.patches.Polygon at 0x271f7046d60>,
#  'FITZROY NORTH': <matplotlib.patches.Polygon at 0x271f7046dc0>,
#  'ALBION': <matplotlib.patches.Polygon at 0x271f7046e20>,
#  'EPSOM': <matplotlib.patches.Polygon at 0x271f7046e80>,
#  'MANIFOLD HEIGHTS': <matplotlib.patches.Polygon at 0x271f7046ee0>,
#  'GLEN HUNTLY': <matplotlib.patches.Polygon at 0x271f7046f40>,
#  'BELGRAVE HEIGHTS': <matplotlib.patches.Polygon at 0x271f7046fa0>,
#  'GEELONG WEST': <matplotlib.patches.Polygon at 0x271f7054040>,
#  'CROYDON HILLS': <matplotlib.patches.Polygon at 0x271f70540a0>,
#  'NOORAT EAST': <matplotlib.patches.Polygon at 0x271f7054100>,
#  'MEADOW HEIGHTS': <matplotlib.patches.Polygon at 0x271f7054160>,
#  'COBAINS': <matplotlib.patches.Polygon at 0x271f70541c0>,
#  'ATTWOOD': <matplotlib.patches.Polygon at 0x271f7054220>,
#  'BUCKLEY': <matplotlib.patches.Polygon at 0x271f7054280>,
#  'MARCUS HILL': <matplotlib.patches.Polygon at 0x271f70542e0>,
#  'MIDDLE PARK': <matplotlib.patches.Polygon at 0x271f7054340>,
#  'BRAVINGTON': <matplotlib.patches.Polygon at 0x271f70543a0>,
#  'CARDIGAN VILLAGE': <matplotlib.patches.Polygon at 0x271f7054400>,
#  'HUNTINGDALE': <matplotlib.patches.Polygon at 0x271f7054460>,
#  'KINGSVILLE': <matplotlib.patches.Polygon at 0x271f70544c0>,
#  'BALACLAVA': <matplotlib.patches.Polygon at 0x271f7054520>,
#  'SOUTH KINGSVILLE': <matplotlib.patches.Polygon at 0x271f7054580>,
#  'SURF BEACH': <matplotlib.patches.Polygon at 0x271f70545e0>,
#  'ALBERT PARK': <matplotlib.patches.Polygon at 0x271f6d93f70>,
#  'YALLAMBIE': <matplotlib.patches.Polygon at 0x271f6fbfaf0>,
#  'ALPHINGTON': <matplotlib.patches.Polygon at 0x271f7054640>,
#  'BONBEACH': <matplotlib.patches.Polygon at 0x271f70546a0>,
#  'BELL PARK': <matplotlib.patches.Polygon at 0x271f7054700>,
#  'PORTARLINGTON': <matplotlib.patches.Polygon at 0x271f7054760>,
#  'MURRUMBEENA': <matplotlib.patches.Polygon at 0x271f70547c0>,
#  'CHELSEA': <matplotlib.patches.Polygon at 0x271f7054820>,
#  'BALLARAT NORTH': <matplotlib.patches.Polygon at 0x271f7054880>,
#  'STANHOPE SOUTH': <matplotlib.patches.Polygon at 0x271f70548e0>,
#  'ELWOOD': <matplotlib.patches.Polygon at 0x271f7054940>,
#  'ELSTERNWICK': <matplotlib.patches.Polygon at 0x271f70549a0>,
#  'SASSAFRAS': <matplotlib.patches.Polygon at 0x271f7054a00>,
#  'LAKE WENDOUREE': <matplotlib.patches.Polygon at 0x271f7054a60>,
#  'MOORABBIN': <matplotlib.patches.Polygon at 0x271f7054ac0>,
#  'SPRINGVALE SOUTH': <matplotlib.patches.Polygon at 0x271f7054b20>,
#  'KOO WEE RUP NORTH': <matplotlib.patches.Polygon at 0x271f7054b80>,
#  'YARRABERB': <matplotlib.patches.Polygon at 0x271f7054be0>,
#  'BARWIDGEE': <matplotlib.patches.Polygon at 0x271f7054c40>,
#  'CHOCOLYN': <matplotlib.patches.Polygon at 0x271f7054ca0>,
#  'GLENORMISTON SOUTH': <matplotlib.patches.Polygon at 0x271f7054d00>,
#  'NORTH WANGARATTA': <matplotlib.patches.Polygon at 0x271f7054d60>,
#  'BRIMBOAL': <matplotlib.patches.Polygon at 0x271f7054dc0>,
#  'RHYLL': <matplotlib.patches.Polygon at 0x271f7054e20>,
#  'NALANGIL': <matplotlib.patches.Polygon at 0x271f7054e80>,
#  'CARALULUP': <matplotlib.patches.Polygon at 0x271f7054ee0>,
#  'TAROON': <matplotlib.patches.Polygon at 0x271f7054f40>,
#  'WOODEND NORTH': <matplotlib.patches.Polygon at 0x271f7054fa0>,
#  'ARTHURS SEAT': <matplotlib.patches.Polygon at 0x271f7089040>,
#  'FLYNNS CREEK': <matplotlib.patches.Polygon at 0x271f70890a0>,
#  'BIG HILL': <matplotlib.patches.Polygon at 0x271f70ac5b0>,
#  'FRYERSTOWN': <matplotlib.patches.Polygon at 0x271f7089160>,
#  'KORWEINGUBOORA': <matplotlib.patches.Polygon at 0x271f70891c0>,
#  'BUNDALONG SOUTH': <matplotlib.patches.Polygon at 0x271f7089220>,
#  'FRAMLINGHAM EAST': <matplotlib.patches.Polygon at 0x271f7089280>,
#  'MURRINDAL': <matplotlib.patches.Polygon at 0x271f70892e0>,
#  'KARDELLA': <matplotlib.patches.Polygon at 0x271f7089340>,
#  'SPRINGDALLAH': <matplotlib.patches.Polygon at 0x271f70893a0>,
#  'HOWQUA INLET': <matplotlib.patches.Polygon at 0x271f7089400>,
#  'SAWMILL SETTLEMENT': <matplotlib.patches.Polygon at 0x271f7089460>,
#  'BROOKLYN': <matplotlib.patches.Polygon at 0x271f70894c0>,
#  'TREMONT': <matplotlib.patches.Polygon at 0x271f7089520>,
#  'BELLELLEN': <matplotlib.patches.Polygon at 0x271f7089580>,
#  'CARRAJUNG SOUTH': <matplotlib.patches.Polygon at 0x271f70895e0>,
#  'RED HILL SOUTH': <matplotlib.patches.Polygon at 0x271f7089640>,
#  'RUNNING CREEK': <matplotlib.patches.Polygon at 0x271f70896a0>,
#  'PHEASANT CREEK': <matplotlib.patches.Polygon at 0x271f7089700>,
#  'NULLAWARRE NORTH': <matplotlib.patches.Polygon at 0x271f7089760>,
#  'HAWTHORN': <matplotlib.patches.Polygon at 0x271f70897c0>,
#  'MOUNT FRANKLIN': <matplotlib.patches.Polygon at 0x271f7089820>,
#  'GLENLEE': <matplotlib.patches.Polygon at 0x271f7089880>,
#  'TANWOOD': <matplotlib.patches.Polygon at 0x271f70898e0>,
#  'LEMNOS': <matplotlib.patches.Polygon at 0x271f7089940>,
#  'MILNES BRIDGE': <matplotlib.patches.Polygon at 0x271f70899a0>,
#  'AYRFORD': <matplotlib.patches.Polygon at 0x271f7089a00>,
#  'MAILORS FLAT': <matplotlib.patches.Polygon at 0x271f7089a60>,
#  'WESTBY': <matplotlib.patches.Polygon at 0x271f7089ac0>,
#  'BULN BULN': <matplotlib.patches.Polygon at 0x271f7089b20>,
#  'YANNATHAN': <matplotlib.patches.Polygon at 0x271f7089b80>,
#  'GLENPATRICK': <matplotlib.patches.Polygon at 0x271f7089be0>,
#  'AVONSLEIGH': <matplotlib.patches.Polygon at 0x271f7089c40>,
#  'MENZIES CREEK': <matplotlib.patches.Polygon at 0x271f7089ca0>,
#  'THE COVE': <matplotlib.patches.Polygon at 0x271f7089d00>,
#  'SPRINGMOUNT': <matplotlib.patches.Polygon at 0x271f7089d60>,
#  'TARILTA': <matplotlib.patches.Polygon at 0x271f7089dc0>,
#  'MOE SOUTH': <matplotlib.patches.Polygon at 0x271f7089e20>,
#  'MOUNT EVELYN': <matplotlib.patches.Polygon at 0x271f7089e80>,
#  'NOWHERE CREEK': <matplotlib.patches.Polygon at 0x271f7089ee0>,
#  'KYABRAM SOUTH': <matplotlib.patches.Polygon at 0x271f7089f40>,
#  'BULLARTO': <matplotlib.patches.Polygon at 0x271f7089fa0>,
#  'HILLCREST': <matplotlib.patches.Polygon at 0x271f707a040>,
#  'PIGGOREET': <matplotlib.patches.Polygon at 0x271f707a0a0>,
#  'NEWLYN NORTH': <matplotlib.patches.Polygon at 0x271f707a100>,
#  'MERBEIN SOUTH': <matplotlib.patches.Polygon at 0x271f707a160>,
#  'ROSEBERY': <matplotlib.patches.Polygon at 0x271f707a1c0>,
#  'TABBERABBERA': <matplotlib.patches.Polygon at 0x271f707a220>,
#  'DOOKIE COLLEGE': <matplotlib.patches.Polygon at 0x271f707a280>,
#  'BALLENDELLA': <matplotlib.patches.Polygon at 0x271f707a2e0>,
#  'MOUNT WAVERLEY': <matplotlib.patches.Polygon at 0x271f707a340>,
#  'GREEN GULLY': <matplotlib.patches.Polygon at 0x271f707a3a0>,
#  'BULLAHARRE': <matplotlib.patches.Polygon at 0x271f707a400>,
#  'NUGGETTY': <matplotlib.patches.Polygon at 0x271f707a460>,
#  'ROSES GAP': <matplotlib.patches.Polygon at 0x271f707a4c0>,
#  'LAKE CONDAH': <matplotlib.patches.Polygon at 0x271f707a520>,
#  'STAFFORDSHIRE REEF': <matplotlib.patches.Polygon at 0x271f707a580>,
#  'KOOROOMAN': <matplotlib.patches.Polygon at 0x271f707a5e0>,
#  'NERRING': <matplotlib.patches.Polygon at 0x271f707a640>,
#  'TRESCO WEST': <matplotlib.patches.Polygon at 0x271f707a6a0>,
#  'PIPERS CREEK': <matplotlib.patches.Polygon at 0x271f707a700>,
#  'GLENBRAE': <matplotlib.patches.Polygon at 0x271f707a760>,
#  'RIVERSIDE': <matplotlib.patches.Polygon at 0x271f707a7c0>,
#  'CARRUM': <matplotlib.patches.Polygon at 0x271f707a820>,
#  'KOROOP': <matplotlib.patches.Polygon at 0x271f707a880>,
#  'RAINBOW': <matplotlib.patches.Polygon at 0x271f707a8e0>,
#  'JEPARIT': <matplotlib.patches.Polygon at 0x271f707a940>,
#  'WHEELERS HILL': <matplotlib.patches.Polygon at 0x271f707a9a0>,
#  'SOUTH WHARF': <matplotlib.patches.Polygon at 0x271f707aa00>,
#  'BENDIGO': <matplotlib.patches.Polygon at 0x271f707aa60>,
#  'ASHBURTON': <matplotlib.patches.Polygon at 0x271f707aac0>,
#  'MALVERN EAST': <matplotlib.patches.Polygon at 0x271f707ab20>,
#  'CANTERBURY': <matplotlib.patches.Polygon at 0x271f707ab80>,
#  'BLACKBURN NORTH': <matplotlib.patches.Polygon at 0x271f707abe0>,
#  'PARK ORCHARDS': <matplotlib.patches.Polygon at 0x271f707ac40>,
#  'LAKE GARDENS': <matplotlib.patches.Polygon at 0x271f707aca0>,
#  'HERNE HILL': <matplotlib.patches.Polygon at 0x271f707ad00>,
#  'ARMADALE': <matplotlib.patches.Polygon at 0x271f707ad60>,
#  'MALVERN': <matplotlib.patches.Polygon at 0x271f707adc0>,
#  'COONOOER WEST': <matplotlib.patches.Polygon at 0x271f707ae20>,
#  'MONGANS BRIDGE': <matplotlib.patches.Polygon at 0x271f707ae80>,
#  'BUCKLEY SWAMP': <matplotlib.patches.Polygon at 0x271f707aee0>,
#  'TARNAGULLA': <matplotlib.patches.Polygon at 0x271f707af40>,
#  'LOCH VALLEY': <matplotlib.patches.Polygon at 0x271f707afa0>,
#  'CUNDARE': <matplotlib.patches.Polygon at 0x271f7073040>,
#  'ELINGAMITE': <matplotlib.patches.Polygon at 0x271f70730a0>,
#  'WEE WEE RUP': <matplotlib.patches.Polygon at 0x271f7073100>,
#  'GLEN WAVERLEY': <matplotlib.patches.Polygon at 0x271f6fbfac0>,
#  'EAST SALE': <matplotlib.patches.Polygon at 0x271f70731c0>,
#  'DALTONS BRIDGE': <matplotlib.patches.Polygon at 0x271f7073220>,
#  'LOVELY BANKS': <matplotlib.patches.Polygon at 0x271f7073280>,
#  'BELL POST HILL': <matplotlib.patches.Polygon at 0x271f70732e0>,
#  'CLARENDON': <matplotlib.patches.Polygon at 0x271f7073340>,
#  'THOMASTOWN': <matplotlib.patches.Polygon at 0x271f70733a0>,
#  'BELGRAVE SOUTH': <matplotlib.patches.Polygon at 0x271f7073400>,
#  'MEPUNGA': <matplotlib.patches.Polygon at 0x271f7073460>,
#  'SMITHS GULLY': <matplotlib.patches.Polygon at 0x271f70734c0>,
#  'SHEANS CREEK': <matplotlib.patches.Polygon at 0x271f7073520>,
#  'HURSTBRIDGE': <matplotlib.patches.Polygon at 0x271f7073580>,
#  'FRANKSTON SOUTH': <matplotlib.patches.Polygon at 0x271f70735e0>,
#  'BRANDY CREEK': <matplotlib.patches.Polygon at 0x271f7073640>,
#  'EMU': <matplotlib.patches.Polygon at 0x271f70736a0>,
#  'KARDELLA SOUTH': <matplotlib.patches.Polygon at 0x271f7073700>,
#  'BETLEY': <matplotlib.patches.Polygon at 0x271f7073760>,
#  'CABBAGE TREE': <matplotlib.patches.Polygon at 0x271f70737c0>,
#  'COOPERS CREEK': <matplotlib.patches.Polygon at 0x271f7073820>,
#  'WHOROULY EAST': <matplotlib.patches.Polygon at 0x271f7073880>,
#  'BUNGADOR': <matplotlib.patches.Polygon at 0x271f70738e0>,
#  'JOYCES CREEK': <matplotlib.patches.Polygon at 0x271f7073940>,
#  'SYLVATERRE': <matplotlib.patches.Polygon at 0x271f70739a0>,
#  'KERRISDALE': <matplotlib.patches.Polygon at 0x271f7073a00>,
#  'HUMEVALE': <matplotlib.patches.Polygon at 0x271f7073a60>,
#  'NAROGHID': <matplotlib.patches.Polygon at 0x271f7073ac0>,
#  'HAZEL PARK': <matplotlib.patches.Polygon at 0x271f7073b20>,
#  'FERGUSON': <matplotlib.patches.Polygon at 0x271f7073b80>,
#  'MILLOO': <matplotlib.patches.Polygon at 0x271f7073be0>,
#  'NEERIM JUNCTION': <matplotlib.patches.Polygon at 0x271f7073c40>,
#  'GLENHOPE EAST': <matplotlib.patches.Polygon at 0x271f7073ca0>,
#  'BRIGHTON EAST': <matplotlib.patches.Polygon at 0x271f7073d00>,
#  'SANDON': <matplotlib.patches.Polygon at 0x271f7073d60>,
#  'BORONIA': <matplotlib.patches.Polygon at 0x271f7073dc0>,
#  'WENTWORTH': <matplotlib.patches.Polygon at 0x271f7073e20>,
#  'LANGDONS HILL': <matplotlib.patches.Polygon at 0x271f7073e80>,
#  'WISELEIGH': <matplotlib.patches.Polygon at 0x271f7073ee0>,
#  'ALLENDALE': <matplotlib.patches.Polygon at 0x271f7073f40>,
#  'TYAAK': <matplotlib.patches.Polygon at 0x271f7073fa0>,
#  'GIPSY POINT': <matplotlib.patches.Polygon at 0x271f708d040>,
#  'HOMERTON': <matplotlib.patches.Polygon at 0x271f708d0a0>,
#  'ARGYLE': <matplotlib.patches.Polygon at 0x271f708d100>,
#  'DOLLAR': <matplotlib.patches.Polygon at 0x271f708d160>,
#  'CLARKES HILL': <matplotlib.patches.Polygon at 0x271f708d1c0>,
#  'OSBORNES FLAT': <matplotlib.patches.Polygon at 0x271f708d220>,
#  'CASSILIS': <matplotlib.patches.Polygon at 0x271f708d280>,
#  'KALLISTA': <matplotlib.patches.Polygon at 0x271f708d2e0>,
#  'BIRDWOODTON': <matplotlib.patches.Polygon at 0x271f7073160>,
#  'SPARGO CREEK': <matplotlib.patches.Polygon at 0x271f708d3a0>,
#  'DENNINGTON': <matplotlib.patches.Polygon at 0x271f708d400>,
#  'KOROBEIT': <matplotlib.patches.Polygon at 0x271f708d460>,
#  'CABARITA': <matplotlib.patches.Polygon at 0x271f708d4c0>,
#  'KANYA': <matplotlib.patches.Polygon at 0x271f708d520>,
#  'MOUNT DORAN': <matplotlib.patches.Polygon at 0x271f708d580>,
#  'AVONDALE HEIGHTS': <matplotlib.patches.Polygon at 0x271f708d5e0>,
#  'SOMERTON': <matplotlib.patches.Polygon at 0x271f708d640>,
#  'CLARETOWN': <matplotlib.patches.Polygon at 0x271f708d6a0>,
#  'MOKEPILLY': <matplotlib.patches.Polygon at 0x271f708d700>,
#  'NEWHAVEN': <matplotlib.patches.Polygon at 0x271f708d760>,
#  'OAKLEIGH SOUTH': <matplotlib.patches.Polygon at 0x271f708d7c0>,
#  'SHERBROOKE': <matplotlib.patches.Polygon at 0x271f708d820>,
#  'HEATHCOTE JUNCTION': <matplotlib.patches.Polygon at 0x271f708d340>,
#  'ROBERTSONS BEACH': <matplotlib.patches.Polygon at 0x271f708d8b0>,
#  'ENDEAVOUR HILLS': <matplotlib.patches.Polygon at 0x271f708d910>,
#  'GREENHILL': <matplotlib.patches.Polygon at 0x271f708d970>,
#  'SKINNERS FLAT': <matplotlib.patches.Polygon at 0x271f708d9d0>,
#  'LLOWALONG': <matplotlib.patches.Polygon at 0x271f708da30>,
#  'MUSK': <matplotlib.patches.Polygon at 0x271f70626a0>,
#  'WOODSIDE NORTH': <matplotlib.patches.Polygon at 0x271f708daf0>,
#  'LANGSBOROUGH': <matplotlib.patches.Polygon at 0x271f708db50>,
#  'STRATHMORE HEIGHTS': <matplotlib.patches.Polygon at 0x271f708dbb0>,
#  'PIEDMONT': <matplotlib.patches.Polygon at 0x271f708dc10>,
#  'MEAD': <matplotlib.patches.Polygon at 0x271f708dc70>,
#  'BEACONSFIELD UPPER': <matplotlib.patches.Polygon at 0x271f708dcd0>,
#  'ST LEONARDS': <matplotlib.patches.Polygon at 0x271f708dd30>,
#  'PASCHENDALE': <matplotlib.patches.Polygon at 0x271f708dd90>,
#  'HAVILAH': <matplotlib.patches.Polygon at 0x271f708ddf0>,
#  'BIG PATS CREEK': <matplotlib.patches.Polygon at 0x271f708de50>,
#  'SUNDAY CREEK': <matplotlib.patches.Polygon at 0x271f708deb0>,
#  'LITTLE HAMPTON': <matplotlib.patches.Polygon at 0x271f708df10>,
#  'LAWRENCE': <matplotlib.patches.Polygon at 0x271f708df70>,
#  'EDGECOMBE': <matplotlib.patches.Polygon at 0x271f708dfd0>,
#  'GELLIONDALE': <matplotlib.patches.Polygon at 0x271f70a9070>,
#  'GILLIESTON': <matplotlib.patches.Polygon at 0x271f70a90d0>,
#  'COWES': <matplotlib.patches.Polygon at 0x271f70a9130>,
#  'AVON PLAINS': <matplotlib.patches.Polygon at 0x271f70a9190>,
#  'CAPE CONRAN': <matplotlib.patches.Polygon at 0x271f70a91f0>,
#  'INKERMAN': <matplotlib.patches.Polygon at 0x271f70a9250>,
#  'BOWSER': <matplotlib.patches.Polygon at 0x271f70a92b0>,
#  'LUCKNOW': <matplotlib.patches.Polygon at 0x271f70a9310>,
#  'BAXTER': <matplotlib.patches.Polygon at 0x271f70a9370>,
#  'SAILORS FALLS': <matplotlib.patches.Polygon at 0x271f70a93d0>,
#  'WALDARA': <matplotlib.patches.Polygon at 0x271f70a9430>,
#  'ORRVALE': <matplotlib.patches.Polygon at 0x271f70a9490>,
#  'YANGERY': <matplotlib.patches.Polygon at 0x271f70a94f0>,
#  'ERICA': <matplotlib.patches.Polygon at 0x271f70a9550>,
#  'OXLEY FLATS': <matplotlib.patches.Polygon at 0x271f70a95b0>,
#  'HAZELWOOD SOUTH': <matplotlib.patches.Polygon at 0x271f70a9610>,
#  'WONGA': <matplotlib.patches.Polygon at 0x271f70a9670>,
#  'CRANBOURNE WEST': <matplotlib.patches.Polygon at 0x271f70a96d0>,
#  'COBAW': <matplotlib.patches.Polygon at 0x271f70a9730>,
#  'MEPUNGA EAST': <matplotlib.patches.Polygon at 0x271f70a9790>,
#  'DON VALLEY': <matplotlib.patches.Polygon at 0x271f70a97f0>,
#  'GLENDARUEL': <matplotlib.patches.Polygon at 0x271f70a9850>,
#  'CHEROKEE': <matplotlib.patches.Polygon at 0x271f70a98b0>,
#  'MERRIANG': <matplotlib.patches.Polygon at 0x271f70a9910>,
#  'MERBEIN WEST': <matplotlib.patches.Polygon at 0x271f70a9970>,
#  'MILLGROVE': <matplotlib.patches.Polygon at 0x271f70a99d0>,
#  'DOCTORS FLAT': <matplotlib.patches.Polygon at 0x271f70a9a30>,
#  'WARATAH BAY': <matplotlib.patches.Polygon at 0x271f70a9a90>,
#  'WOODFORD': <matplotlib.patches.Polygon at 0x271f70a9af0>,
#  'CROSSOVER': <matplotlib.patches.Polygon at 0x271f70a9b50>,
#  'TOOLAMBA WEST': <matplotlib.patches.Polygon at 0x271f70a9bb0>,
#  'ROSEBUD': <matplotlib.patches.Polygon at 0x271f70a9c10>,
#  'WOORINEN NORTH': <matplotlib.patches.Polygon at 0x271f70a9c70>,
#  'VENUS BAY': <matplotlib.patches.Polygon at 0x271f70a9cd0>,
#  'GRAHAMVALE': <matplotlib.patches.Polygon at 0x271f70a9d30>,
#  'THORPDALE SOUTH': <matplotlib.patches.Polygon at 0x271f70a9d90>,
#  'THE HONEYSUCKLES': <matplotlib.patches.Polygon at 0x271f70a9df0>,
#  'JEERALANG JUNCTION': <matplotlib.patches.Polygon at 0x271f70a9e50>,
#  'HINNOMUNJIE': <matplotlib.patches.Polygon at 0x271f70a9eb0>,
#  'TULKARA': <matplotlib.patches.Polygon at 0x271f70a9f10>,
#  'TEESDALE': <matplotlib.patches.Polygon at 0x271f70a9f70>,
#  'CLAYTON SOUTH': <matplotlib.patches.Polygon at 0x271f70a9fd0>,
#  'SHANNONVALE': <matplotlib.patches.Polygon at 0x271f709f070>,
#  'HALLAM': <matplotlib.patches.Polygon at 0x271f709f0d0>,
#  'YARPTURK': <matplotlib.patches.Polygon at 0x271f709f130>,
#  'RAVENHALL': <matplotlib.patches.Polygon at 0x271f709f190>,
#  'BLACKBURN': <matplotlib.patches.Polygon at 0x271f709f1f0>,
#  'SELBY': <matplotlib.patches.Polygon at 0x271f709f250>,
#  'CRIB POINT': <matplotlib.patches.Polygon at 0x271f709f2b0>,
#  'BULLEEN': <matplotlib.patches.Polygon at 0x271f709f310>,
#  'LAKE TYERS BEACH': <matplotlib.patches.Polygon at 0x271f709f370>,
#  'AMOR': <matplotlib.patches.Polygon at 0x271f709f3d0>,
#  'WEST MELBOURNE': <matplotlib.patches.Polygon at 0x271f709f430>,
#  'YARRAGON': <matplotlib.patches.Polygon at 0x271f709f490>,
#  'GLENMAGGIE': <matplotlib.patches.Polygon at 0x271f709f4f0>,
#  'TAHARA': <matplotlib.patches.Polygon at 0x271f709f550>,
#  'MORGIANA': <matplotlib.patches.Polygon at 0x271f709f5b0>,
#  'TARRENLEA': <matplotlib.patches.Polygon at 0x271f709f610>,
#  'KINGSTON': <matplotlib.patches.Polygon at 0x271f709f670>,
#  'MOUNT MAJOR': <matplotlib.patches.Polygon at 0x271f709f6d0>,
#  'ZEERUST': <matplotlib.patches.Polygon at 0x271f709f730>,
#  'CASTLE CREEK': <matplotlib.patches.Polygon at 0x271f709f790>,
#  'BROMLEY': <matplotlib.patches.Polygon at 0x271f709f7f0>,
#  'OLINDA': <matplotlib.patches.Polygon at 0x271f709f850>,
#  'SIMSON': <matplotlib.patches.Polygon at 0x271f709f8b0>,
#  'MOUNT PROSPECT': <matplotlib.patches.Polygon at 0x271f7050c40>,
#  'TARRAWARRA': <matplotlib.patches.Polygon at 0x271f709f970>,
#  'TOWANINNY SOUTH': <matplotlib.patches.Polygon at 0x271f709f9d0>,
#  'VIEWBANK': <matplotlib.patches.Polygon at 0x271f709fa30>,
#  'NARRE WARREN EAST': <matplotlib.patches.Polygon at 0x271f709fa90>,
#  'THE BASIN': <matplotlib.patches.Polygon at 0x271f709faf0>,
#  'VITE VITE NORTH': <matplotlib.patches.Polygon at 0x271f709fb50>,
#  'BURNSIDE': <matplotlib.patches.Polygon at 0x271f709fbb0>,
#  'MURNUNGIN': <matplotlib.patches.Polygon at 0x271f709fc10>,
#  'MEATIAN': <matplotlib.patches.Polygon at 0x271f709fc70>,
#  'NINYEUNOOK': <matplotlib.patches.Polygon at 0x271f709fcd0>,
#  'NORONG': <matplotlib.patches.Polygon at 0x271f709fd30>,
#  'UNDERA': <matplotlib.patches.Polygon at 0x271f709fd90>,
#  'TOWONG UPPER': <matplotlib.patches.Polygon at 0x271f709fdf0>,
#  'SOUTHERN CROSS': <matplotlib.patches.Polygon at 0x271f709fe50>,
#  'WATTLE FLAT': <matplotlib.patches.Polygon at 0x271f709feb0>,
#  'PLENTY': <matplotlib.patches.Polygon at 0x271f709ff10>,
#  'DALMORE': <matplotlib.patches.Polygon at 0x271f709ff70>,
#  'DURDIDWARRAH': <matplotlib.patches.Polygon at 0x271f709ffd0>,
#  'WANDIN EAST': <matplotlib.patches.Polygon at 0x271f70ac070>,
#  'WARRANDYTE': <matplotlib.patches.Polygon at 0x271f70ac0d0>,
#  'WANDIN NORTH': <matplotlib.patches.Polygon at 0x271f70ac130>,
#  'CANNONS CREEK': <matplotlib.patches.Polygon at 0x271f70ac190>,
#  'GNOTUK': <matplotlib.patches.Polygon at 0x271f70ac1f0>,
#  'MOUNT DANDENONG': <matplotlib.patches.Polygon at 0x271f70ac250>,
#  'DINGLEY VILLAGE': <matplotlib.patches.Polygon at 0x271f70ac2b0>,
#  'MOUNT TOOLEBEWONG': <matplotlib.patches.Polygon at 0x271f70ac310>,
#  'BOOLARONG': <matplotlib.patches.Polygon at 0x271f70ac370>,
#  'LORQUON': <matplotlib.patches.Polygon at 0x271f70ac3d0>,
#  'NORTH WARRANDYTE': <matplotlib.patches.Polygon at 0x271f70ac430>,
#  'BATHUMI': <matplotlib.patches.Polygon at 0x271f70ac490>,
#  'GAFFNEYS CREEK': <matplotlib.patches.Polygon at 0x271f70ac4f0>,
#  'MICKLEHAM': <matplotlib.patches.Polygon at 0x271f70ac550>,
#  'MOSSIFACE': <matplotlib.patches.Polygon at 0x271f7089100>,
#  'AGNES': <matplotlib.patches.Polygon at 0x271f70ac610>,
#  'BELLS BEACH': <matplotlib.patches.Polygon at 0x271f70ac670>,
#  'ALTONA NORTH': <matplotlib.patches.Polygon at 0x271f70ac6d0>,
#  'BADGER CREEK': <matplotlib.patches.Polygon at 0x271f70ac730>,
#  'ST ALBANS': <matplotlib.patches.Polygon at 0x271f70ac790>,
#  'EAST BAIRNSDALE': <matplotlib.patches.Polygon at 0x271f70ac7f0>,
#  'KALORAMA': <matplotlib.patches.Polygon at 0x271f70ac850>,
#  'WOORARRA WEST': <matplotlib.patches.Polygon at 0x271f70ac8b0>,
#  'COWLEYS CREEK': <matplotlib.patches.Polygon at 0x271f70ac910>,
#  'PENNYROYAL': <matplotlib.patches.Polygon at 0x271f70ac970>,
#  'WANNON': <matplotlib.patches.Polygon at 0x271f70ac9d0>,
#  'BROOMFIELD': <matplotlib.patches.Polygon at 0x271f70aca30>,
#  'YANDOIT HILLS': <matplotlib.patches.Polygon at 0x271f70aca90>,
#  'JANCOURT': <matplotlib.patches.Polygon at 0x271f70acaf0>,
#  'BOCHARA': <matplotlib.patches.Polygon at 0x271f70acb50>,
#  'MURROON': <matplotlib.patches.Polygon at 0x271f70acbb0>,
#  'SWAN HILL': <matplotlib.patches.Polygon at 0x271f70acc10>,
#  'LAKE LONSDALE': <matplotlib.patches.Polygon at 0x271f70acc70>,
#  'BERRINGA': <matplotlib.patches.Polygon at 0x271f70accd0>,
#  'ELINGAMITE NORTH': <matplotlib.patches.Polygon at 0x271f70acd30>,
#  'PELLUEBLA': <matplotlib.patches.Polygon at 0x271f70acd90>,
#  'NYAH WEST': <matplotlib.patches.Polygon at 0x271f70acdf0>,
#  'ARCHDALE JUNCTION': <matplotlib.patches.Polygon at 0x271f70ace50>,
#  'APPIN': <matplotlib.patches.Polygon at 0x271f70aceb0>,
#  'MOUNT BOLTON': <matplotlib.patches.Polygon at 0x271f70acf10>,
#  'OMEO VALLEY': <matplotlib.patches.Polygon at 0x271f70acf70>,
#  'TRARALGON SOUTH': <matplotlib.patches.Polygon at 0x271f70acfd0>,
#  'MANDURANG': <matplotlib.patches.Polygon at 0x271f70d5070>,
#  'MOUNT BECKWORTH': <matplotlib.patches.Polygon at 0x271f70d50d0>,
#  'MOLOGA': <matplotlib.patches.Polygon at 0x271f70d5130>,
#  'FLAMINGO BEACH': <matplotlib.patches.Polygon at 0x271f70d5190>,
#  'DOOKIE': <matplotlib.patches.Polygon at 0x271f70d51f0>,
#  'ROKEBY': <matplotlib.patches.Polygon at 0x271f70d5250>,
#  'PURNIM WEST': <matplotlib.patches.Polygon at 0x271f70d52b0>,
#  'CLOVER FLAT': <matplotlib.patches.Polygon at 0x271f70d5310>,
#  'GRANITE ROCK': <matplotlib.patches.Polygon at 0x271f70d5370>,
#  'NICHOLSON': <matplotlib.patches.Polygon at 0x271f70d53d0>,
#  'SARSFIELD': <matplotlib.patches.Polygon at 0x271f70d5430>,
#  'LENEVA': <matplotlib.patches.Polygon at 0x271f70d5490>,
#  'BUNGAREE': <matplotlib.patches.Polygon at 0x271f70d54f0>,
#  'YERING': <matplotlib.patches.Polygon at 0x271f70d5550>,
#  'NIRRANDA': <matplotlib.patches.Polygon at 0x271f70d55b0>,
#  'HEATHCOTE SOUTH': <matplotlib.patches.Polygon at 0x271f70d5610>,
#  'YUNDOOL': <matplotlib.patches.Polygon at 0x271f70d5670>,
#  'WINLATON': <matplotlib.patches.Polygon at 0x271f70d56d0>,
#  'MINMINDIE': <matplotlib.patches.Polygon at 0x271f70d5730>,
#  'LAKE EPPALOCK': <matplotlib.patches.Polygon at 0x271f70d5790>,
#  'CAPE SCHANCK': <matplotlib.patches.Polygon at 0x271f70d57f0>,
#  'BORALMA': <matplotlib.patches.Polygon at 0x271f70d5850>,
#  'MOOROOPNA': <matplotlib.patches.Polygon at 0x271f70d58b0>,
#  'WAYGARA': <matplotlib.patches.Polygon at 0x271f70d5910>,
#  'KORIELLA': <matplotlib.patches.Polygon at 0x271f70d5970>,
#  'DHURRINGILE': <matplotlib.patches.Polygon at 0x271f70d59d0>,
#  'ELLASWOOD': <matplotlib.patches.Polygon at 0x271f70d5a30>,
#  'EAST WANGARATTA': <matplotlib.patches.Polygon at 0x271f70d5a90>,
#  'KYNETON SOUTH': <matplotlib.patches.Polygon at 0x271f70d5af0>,
#  'STACEYS BRIDGE': <matplotlib.patches.Polygon at 0x271f70d5b50>,
#  'MORANDING': <matplotlib.patches.Polygon at 0x271f70d5bb0>,
#  'YEO': <matplotlib.patches.Polygon at 0x271f70d5c10>,
#  'WELSHMANS REEF': <matplotlib.patches.Polygon at 0x271f70d5c70>,
#  'GOWER': <matplotlib.patches.Polygon at 0x271f70d5cd0>,
#  'DROUIN': <matplotlib.patches.Polygon at 0x271f70d5d30>,
#  'BERRIMAL': <matplotlib.patches.Polygon at 0x271f70d5d90>,
#  'WAAIA': <matplotlib.patches.Polygon at 0x271f70d5df0>,
#  'MIA MIA': <matplotlib.patches.Polygon at 0x271f70d5e50>,
#  'YARCK': <matplotlib.patches.Polygon at 0x271f70d5eb0>,
#  'WYUNA': <matplotlib.patches.Polygon at 0x271f70d5f10>,
#  'TARRONE': <matplotlib.patches.Polygon at 0x271f70d5f70>,
#  'TOOLONG': <matplotlib.patches.Polygon at 0x271f70d5fd0>,
#  'MITCHELL PARK': <matplotlib.patches.Polygon at 0x271f70e4070>,
#  'PASTORIA EAST': <matplotlib.patches.Polygon at 0x271f70e40d0>,
#  'CUDGEE': <matplotlib.patches.Polygon at 0x271f70e4130>,
#  'HOMEBUSH': <matplotlib.patches.Polygon at 0x271f70e4190>,
#  'MARSHALL': <matplotlib.patches.Polygon at 0x271f70e41f0>,
#  'HAVEN': <matplotlib.patches.Polygon at 0x271f70e4250>,
#  'LOWER NORTON': <matplotlib.patches.Polygon at 0x271f70e42b0>,
#  'TURTONS CREEK': <matplotlib.patches.Polygon at 0x271f70e4310>,
#  'NUG NUG': <matplotlib.patches.Polygon at 0x271f70e4370>,
#  'GOWANFORD': <matplotlib.patches.Polygon at 0x271f70e43d0>,
#  'LONGWARRY': <matplotlib.patches.Polygon at 0x271f70e4430>,
#  'TARRENGOWER': <matplotlib.patches.Polygon at 0x271f70e4490>,
#  'ALTONA': <matplotlib.patches.Polygon at 0x271f70e4520>,
#  'BUSHFIELD': <matplotlib.patches.Polygon at 0x271f70e4580>,
#  ...}

# %% [markdown]
# A function called `loc_sub` will be defined where a longitude and latitude will be checked against the polygons in `subs_bounds`, and returns the suburb name that holds the specified longitude and latitude using the `contains_point` function. The function will take a row as an argument. This function will then be applied to `prop_df` to create the `suburb` column

# %%
def loc_sub(row):
    # retrieve row latitude
    lat = row["lat"]    
    # retrieve row longitude
    lng = row["lng"]
    
    # check if any suburb contains the point
    for sub, poly in subs_bounds.items():
        if poly.contains_point((lng, lat)):
            return sub  
        
    # if no suburb contains the point    
    return "not available"

# %%
# create suburb column by applying loc_sub
prop_df["suburb"] = prop_df.apply(loc_sub, axis = 1)
prop_df.head()
# Out:
#   property_id        lat         lng          addr_street      suburb
# 0        2645 -37.815113  144.891492   10 Goulburn Street  YARRAVILLE
# 1       51985 -37.799076  145.174236      7 Belmont Court     DONVALE
# 2       76137 -37.909505  145.094192     38 Andrew Street    OAKLEIGH
# 3       96049 -37.912178  145.051455  6 Shanahan Crescent    MCKINNON
# 4       47173 -37.719559  145.160461  40 Malabar Crescent      ELTHAM

# %% [markdown]
# The following addresses do not contain a suburb name

# %%
prop_df[prop_df["suburb"] == "not available"]
# Out:
#      property_id        lat         lng            addr_street         suburb
# 164        39132 -37.753029  145.035002    14 Carlyle Crescent  not available
# 1036       39128 -37.750405  145.033371     129 Liberty Parade  not available
# 1470       39182 -37.751263  145.036484     27 davidson street  not available
# 1987       39202 -37.749694  145.038141  32 Skeffington Street  not available

# %% [markdown]
# ### 3.2 LGA
#
# The next column to be integrated is the `lga` column. Each `lga` contains multiple suburbs, therefore the `lga` to be returned for each row will be the `lga` that holds the specified property's `suburb`.
#
# The list of LGA's and their corresponding suburbs is held in a pdf file `lga_to_suburb`. `pdf_miner` will be used to convert the pdf file into a text file

# %%
# convert pdf to text file using pdf_miner
# !pdf2txt.py -o lga_to_suburb.txt data/lga_to_suburb.pdf

# %%
# read in the text file
with open("lga_to_suburb.txt", "r") as infile:
    lga_text = infile.readlines()

# %% [markdown]
# Examine the first and last five lines in the text file

# %%
# first lines
lga_text[:5]
# Out:
# ["BANYULE : ['Abbotsford', 'Airport West', 'Albert Park', 'Alphington'] \n",
#  '\n',
#  "BRIMBANK : ['Altona', 'Altona North', 'Armadale', 'Ascot Vale'] \n",
#  '\n',
#  "DAREBIN : ['Ashburton', 'Ashwood', 'Avondale Heights', 'Balaclava'] \n"]

# %%
# last lines
lga_text[-5:]
# Out:
# ["MOYNE : ['Burnside', 'Attwood', 'Wallan', 'New Gisborne', 'St Kilda East'] \n",
#  '\n',
#  "WARRNAMBOOL : ['Plumpton', 'Monbulk', 'Manor Lakes', 'Harkness', 'Fraser Rise'] \n",
#  '\n',
#  '\x0c']

# %% [markdown]
# The last two lines in the file will be removed

# %%
lga_text = lga_text[:-2]

# %% [markdown]
# A dictionary `lga_dict` will be created where the keys are the names of the LGA's and the values are the list of the suburbs that LGA holds. These items will be extracted from the `lga_text` file. The LGA and the list of suburbs it contains are separated by ":", which will be used to split them apart

# %%
lga_dict = {}

for line in lga_text:
    if line != "\n":
        # extract LGA and suburb from each line
        lga, suburbs = line.strip().split(" : ")
        # convert string that holds the list of suburbs to a pure list using literal_eval from the ast package
        suburbs = literal_eval(suburbs)
        # convert suburbs to all capital letters to match suburb name in prop_df
        suburbs = [suburb.upper() for suburb in suburbs]
        lga_dict[lga] = suburbs
        
lga_dict
# Out:
# {'BANYULE': ['ABBOTSFORD', 'AIRPORT WEST', 'ALBERT PARK', 'ALPHINGTON'],
#  'BRIMBANK': ['ALTONA', 'ALTONA NORTH', 'ARMADALE', 'ASCOT VALE'],
#  'DAREBIN': ['ASHBURTON', 'ASHWOOD', 'AVONDALE HEIGHTS', 'BALACLAVA'],
#  'HOBSONS BAY': ['BALWYN', 'BALWYN NORTH', 'BENTLEIGH', 'BENTLEIGH EAST'],
#  'HUME': ['BOX HILL', 'BRAYBROOK', 'BRIGHTON', 'BRIGHTON EAST'],
#  'MARIBYRNONG': ['BRUNSWICK', 'BRUNSWICK WEST', 'BULLEEN', 'BURWOOD'],
#  'MELBOURNE': ['CAMBERWELL', 'CANTERBURY', 'CARLTON NORTH', 'CARNEGIE'],
#  'MELTON': ['CAULFIELD', 'CAULFIELD NORTH', 'CAULFIELD SOUTH', 'CHADSTONE'],
#  'MOONEE VALLEY': ['CLIFTON HILL', 'COBURG', 'COBURG NORTH', 'COLLINGWOOD'],
#  'MORELAND': ['DONCASTER', 'EAGLEMONT', 'ELSTERNWICK', 'ELWOOD'],
#  'NILLUMBIK': ['ESSENDON', 'ESSENDON NORTH', 'FAIRFIELD', 'FITZROY', 'PLENTY'],
#  'WHITTLESEA': ['FITZROY NORTH', 'FLEMINGTON', 'FOOTSCRAY', 'GLEN IRIS'],
#  'WYNDHAM': ['GLENROY', 'GOWANBRAE', 'HADFIELD', 'HAMPTON'],
#  'YARRA': ['HAMPTON EAST',
#   'HAWTHORN',
#   'HEIDELBERG HEIGHTS',
#   'HEIDELBERG WEST'],
#  'BASS COAST': ['HUGHESDALE', 'IVANHOE', 'KEALBA', 'KEILOR EAST'],
#  'SOUTH GIPPSLAND': ['KENSINGTON', 'KEW', 'KEW EAST', 'KOOYONG', 'HEATHERTON'],
#  'BAW BAW': ['MAIDSTONE', 'MALVERN', 'MALVERN EAST', 'MARIBYRNONG'],
#  'BENALLA': ['MELBOURNE', 'MIDDLE PARK', 'MONT ALBERT', 'MOONEE PONDS'],
#  'MANSFIELD': ['MOORABBIN', 'NEWPORT', 'NIDDRIE', 'NORTH MELBOURNE'],
#  'MURRINDINDI': ['NORTHCOTE',
#   'OAK PARK',
#   'OAKLEIGH SOUTH',
#   'PARKVILLE',
#   'LAVERTON'],
#  'BOROONDARA': ['PASCOE VALE', 'PORT MELBOURNE', 'PRAHRAN', 'PRESTON'],
#  'EAST GIPPSLAND': ['RESERVOIR', 'RICHMOND', 'ROSANNA', 'SEDDON'],
#  'GREATER SHEPPARTON': ['SOUTH MELBOURNE',
#   'SOUTH YARRA',
#   'SOUTHBANK',
#   'SPOTSWOOD'],
#  'KNOX': ['ST KILDA', 'STRATHMORE', 'SUNSHINE', 'SUNSHINE NORTH'],
#  'LATROBE': ['SUNSHINE WEST',
#   'SURREY HILLS',
#   'TEMPLESTOWE LOWER',
#   'THORNBURY'],
#  'MANNINGHAM': ['TOORAK', 'VIEWBANK', 'WATSONIA', 'WEST MELBOURNE'],
#  'MAROONDAH': ['WILLIAMSTOWN', 'WILLIAMSTOWN NORTH', 'WINDSOR', 'YALLAMBIE'],
#  'MITCHELL': ['YARRAVILLE', 'ABERFELDIE', 'BELLFIELD', 'BRUNSWICK EAST'],
#  'STRATHBOGIE': ['BURNLEY', 'CAMPBELLFIELD', 'CARLTON', 'EAST MELBOURNE'],
#  'MONASH': ['ESSENDON WEST', 'FAWKNER', 'HAWTHORN EAST', 'HEIDELBERG'],
#  'ALPINE': ['IVANHOE EAST', 'JACANA', 'KINGSBURY', 'KINGSVILLE'],
#  'MOIRA': ['MURRUMBEENA', 'ORMOND', 'WEST FOOTSCRAY', 'ALBION'],
#  'WANGARATTA': ['BROOKLYN', 'GLEN HUNTLY', 'OAKLEIGH', 'RIPPONLEA', 'MACLEOD'],
#  'WELLINGTON': ['CREMORNE',
#   'DOCKLANDS',
#   'SOUTH KINGSVILLE',
#   'STRATHMORE HEIGHTS'],
#  'WHITEHORSE': ['TRAVANCORE', 'CAULFIELD EAST', 'SEAHOLME', 'KEILOR PARK'],
#  'INDIGO': ['GARDENVALE', 'PRINCES HILL', 'BAYSWATER', 'BAYSWATER NORTH'],
#  'TOWONG': ['BEAUMARIS', 'BERWICK', 'BORONIA', 'BRIAR HILL'],
#  'WODONGA': ['BROADMEADOWS', 'BUNDOORA', 'BURNSIDE HEIGHTS', 'BURWOOD EAST'],
#  'YARRA RANGES': ['CAIRNLEA', 'CAROLINE SPRINGS', 'CHELTENHAM', 'CRAIGIEBURN'],
#  'CARDINIA': ['CRANBOURNE', 'CROYDON', 'DANDENONG', 'DANDENONG NORTH'],
#  'CASEY': ['DIAMOND CREEK', 'DINGLEY VILLAGE', 'DONCASTER EAST', 'DONVALE'],
#  'FRANKSTON': ['DOREEN', 'ELTHAM', 'EPPING', 'FOREST HILL', 'LILYDALE'],
#  'BAYSIDE': ['FRANKSTON', 'FRANKSTON NORTH', 'FRANKSTON SOUTH', 'GISBORNE'],
#  'GLEN EIRA': ['GLADSTONE PARK', 'GREENSBOROUGH', 'HALLAM', 'HEALESVILLE'],
#  'GREATER DANDENONG': ['HIGHETT', 'HILLSIDE', 'HUNTINGDALE', 'KEILOR DOWNS'],
#  'KINGSTON': ['KEILOR LODGE',
#   'KEYSBOROUGH',
#   'KINGS PARK',
#   'LALOR',
#   'LAVERTON NORTH'],
#  'MORNINGTON PENINSULA': ['LOWER PLENTY', 'MELTON', 'MERNDA', 'MILL PARK'],
#  'PORT PHILLIP': ['MITCHAM', 'MONTMORENCY', 'MORDIALLOC', 'MOUNT WAVERLEY'],
#  'STONNINGTON': ['NARRE WARREN', 'NUNAWADING', 'OAKLEIGH EAST', 'PARKDALE'],
#  'BALLARAT': ['POINT COOK',
#   'RINGWOOD EAST',
#   'ROCKBANK',
#   'ROWVILLE',
#   'LYSTERFIELD'],
#  'PYRENEES': ['SANDRINGHAM',
#   'SEAFORD',
#   'SKYE',
#   'SOUTH MORANG',
#   'EUMEMMERRING'],
#  'GREATER BENDIGO': ['SPRINGVALE', 'ST ALBANS', 'SUNBURY', 'TARNEIT'],
#  'CAMPASPE': ['TAYLORS HILL',
#   'TAYLORS LAKES',
#   'THE BASIN',
#   'THOMASTOWN',
#   'WATTLE GLEN'],
#  'CENTRAL GOLDFIELDS': ['TRUGANINA', 'TULLAMARINE', 'VERMONT', 'WANTIRNA'],
#  'LODDON': ['WANTIRNA SOUTH', 'WERRIBEE', 'WESTMEADOWS', 'WILLIAMS LANDING'],
#  'GREATER GEELONG': ['WOLLERT', 'WYNDHAM VALE', 'BLACK ROCK', 'BLACKBURN'],
#  'QUEENSCLIFFE': ['BLACKBURN NORTH',
#   'BONBEACH',
#   'CARRUM',
#   'CHELSEA',
#   'GRAESIDE'],
#  'HINDMARSH': ['CLAYTON',
#   'DOVETON',
#   'FERNTREE GULLY',
#   'GLEN WAVERLEY',
#   'YARRAMBAT'],
#  'HORSHAM': ['GREENVALE',
#   'HEATHMONT',
#   'HOPPERS CROSSING',
#   'MCKINNON',
#   'BRAESIDE'],
#  'WEST WIMMERA': ['MELTON SOUTH', 'MELTON WEST', 'MENTONE', 'MOOROOLBARK'],
#  'MACEDON RANGES': ['MULGRAVE',
#   'RINGWOOD',
#   'ROXBURGH PARK',
#   'SEABROOK',
#   'WARRANWOOD'],
#  'MOUNT ALEXANDER': ['TEMPLESTOWE',
#   'VERMONT SOUTH',
#   'WARRANDYTE',
#   'WATSONIA NORTH'],
#  'MILDURA': ['WHEELERS HILL',
#   'ALTONA MEADOWS',
#   'BLACKBURN SOUTH',
#   'CARRUM DOWNS'],
#  'GOLDEN PLAINS': ['CLAYTON SOUTH',
#   'CROYDON NORTH',
#   'LANGWARRIN',
#   'NOBLE PARK'],
#  'HEPBURN': ['NOTTING HILL',
#   'RINGWOOD NORTH',
#   'SYDENHAM',
#   'ALBANVALE',
#   'UPPER FERNTREE GULLY'],
#  'MOORABOOL': ['BEACONSFIELD UPPER',
#   'CHELSEA HEIGHTS',
#   'DALLAS',
#   'DEER PARK',
#   'RESEARCH'],
#  'ARARAT': ['ELTHAM NORTH', 'KEILOR', 'MEADOW HEIGHTS', 'MOUNT EVELYN'],
#  'NORTHERN GRAMPIANS': ['NORTH WARRANDYTE',
#   'PAKENHAM',
#   'RIDDELLS CREEK',
#   'SANDHURST'],
#  'YARRIAMBIACK': ['SCORESBY', 'SILVAN', 'ASPENDALE', 'CHIRNSIDE PARK'],
#  'GLENELG': ['CROYDON HILLS', 'CROYDON SOUTH', 'DERRIMUT', 'DIGGERS REST'],
#  'SOUTHERN GRAMPIANS': ['EDITHVALE', 'HAMPTON PARK', 'KNOXFIELD', 'ST HELENA'],
#  'COLAC-OTWAY': ['UPWEY', 'BACCHUS MARSH', 'COOLAROO', 'CRANBOURNE NORTH'],
#  'SURF COAST': ['KILSYTH',
#   'MONTROSE',
#   'ASPENDALE GARDENS',
#   'BULLENGAROOK',
#   'DANDENONG SOUTH'],
#  'BULOKE': ['CLARINDA', 'DEEPDENE', 'DELAHEY', 'HURSTBRIDGE'],
#  'GANNAWARRA': ['KURUNJANG', 'WONGA PARK', 'ENDEAVOUR HILLS', 'OFFICER'],
#  'SWAN HILL': ['WATERWAYS', 'ARDEER', 'BEACONSFIELD', 'SPRINGVALE SOUTH'],
#  'CORANGAMITE': ['YARRA GLEN',
#   'BROOKFIELD',
#   'EMERALD',
#   'WHITTLESEA',
#   'KILSYTH SOUTH'],
#  'MOYNE': ['BURNSIDE', 'ATTWOOD', 'WALLAN', 'NEW GISBORNE', 'ST KILDA EAST'],
#  'WARRNAMBOOL': ['PLUMPTON',
#   'MONBULK',
#   'MANOR LAKES',
#   'HARKNESS',
#   'FRASER RISE']}

# %% [markdown]
# A function `find_lga` will be defined where a given suburb will be checked against the suburbs in `lga_dict` and returns the name of the `lga` that suburb is in. The function will then be applied to the `suburb` column in `prop_df` to create the `lga` column

# %%
def find_lga(suburb):
    for lga, suburbs in lga_dict.items():
        if suburb in suburbs:
            return lga
        
    return "not available"

# %%
# apply find_lga
prop_df["lga"] = prop_df["suburb"].apply(find_lga)
prop_df.head()
# Out:
#   property_id        lat         lng          addr_street      suburb  \
# 0        2645 -37.815113  144.891492   10 Goulburn Street  YARRAVILLE
# 1       51985 -37.799076  145.174236      7 Belmont Court     DONVALE
# 2       76137 -37.909505  145.094192     38 Andrew Street    OAKLEIGH
# 3       96049 -37.912178  145.051455  6 Shanahan Crescent    MCKINNON
# 4       47173 -37.719559  145.160461  40 Malabar Crescent      ELTHAM
#
#           lga
# 0    MITCHELL
# 1       CASEY
# 2  WANGARATTA
# 3     HORSHAM
# 4   FRANKSTON

# %% [markdown]
# The following properties do not contain a `lga` name

# %%
prop_df[prop_df["lga"] == "not available"]
# Out:
#      property_id        lat         lng            addr_street         suburb  \
# 164        39132 -37.753029  145.035002    14 Carlyle Crescent  not available
# 1036       39128 -37.750405  145.033371     129 Liberty Parade  not available
# 1470       39182 -37.751263  145.036484     27 davidson street  not available
# 1987       39202 -37.749694  145.038141  32 Skeffington Street  not available
#
#                 lga
# 164   not available
# 1036  not available
# 1470  not available
# 1987  not available

# %% [markdown]
# ### 3.3 closest_train_station_id and distance_to_closest_train_station
#
# The next columns to be added are `closest_train_station_id` and `distance_to_closest_train_station`.
#
# The file containing the stop id's and their coordinates will be read in. In order to maximise the accuracy of the desired columns, the file will be read as a text file rather than as a csv to maintain the maximum possible decimal points for each stop's latitude and longitude.

# %%
with open("data/Vic_GTFS_data/metropolitan/stops.txt", "r") as infile:
    stops = infile.readlines()

# %% [markdown]
# The first five lines of the file will be examined

# %%
stops[:5]
# Out:
# ['ï»¿stop_id,stop_name,stop_short_name,stop_lat,stop_lon\n',
#  '"15351","Sunbury Railway Station","Sunbury","-37.5790909705787","144.727318781329"\n',
#  '"15353","Diggers Rest Railway Station","Diggers Rest","-37.6270165149357","144.719922441113"\n',
#  '"19827","Stony Point Railway Station","Crib Point","-38.3742345364937","145.221837462187"\n',
#  '"19828","Crib Point Railway Station","Crib Point","-38.3661233827862","145.204043321601"\n']

# %%
# remove top row containing field names
stops = stops[1:]
stops[:5]
# Out:
# ['"15351","Sunbury Railway Station","Sunbury","-37.5790909705787","144.727318781329"\n',
#  '"15353","Diggers Rest Railway Station","Diggers Rest","-37.6270165149357","144.719922441113"\n',
#  '"19827","Stony Point Railway Station","Crib Point","-38.3742345364937","145.221837462187"\n',
#  '"19828","Crib Point Railway Station","Crib Point","-38.3661233827862","145.204043321601"\n',
#  '"19829","Morradoo Railway Station","Crib Point","-38.3540333365844","145.189602487712"\n']

# %% [markdown]
# A dictionary `stop_dict` will be created where the keys will be the station id and the values will be the latitude and longitude coordinates of that stop.
#
# Each line in `stops` will be split on ",". The stop id is the 1st element of the resulting list, while the latitude and longitude are the 4th and 5th elements of the list respectively

# %%
stops_dict = {}

for stop in stops:
    stop_info = stop.split(",")
    stop_id = int(literal_eval(stop_info[0]))
    stop_lat = float(literal_eval(stop_info[3]))
    stop_lng = float(literal_eval(stop_info[4]))
    
    stops_dict[stop_id] = (stop_lat, stop_lng)
    
stops_dict
# Out:
# {15351: (-37.5790909705787, 144.727318781329),
#  15353: (-37.6270165149357, 144.719922441113),
#  19827: (-38.3742345364937, 145.221837462187),
#  19828: (-38.3661233827862, 145.204043321601),
#  19829: (-38.3540333365844, 145.189602487712),
#  19830: (-38.3373903202406, 145.178026527511),
#  19831: (-38.3056585273722, 145.185979882012),
#  19832: (-38.2598150046916, 145.186400708984),
#  19833: (-38.2253419593114, 145.1762449189),
#  19834: (-38.1940430573051, 145.160526087615),
#  19835: (-37.8593084165858, 145.058224898221),
#  19836: (-38.1520339975222, 145.139533963382),
#  19837: (-37.8689568446092, 145.062950826245),
#  19838: (-37.8769300156728, 145.0693930023),
#  19839: (-37.8744022200498, 145.090662027436),
#  19840: (-37.8736033933188, 145.112090156436),
#  19841: (-37.8119813073807, 144.955653760429),
#  19842: (-37.8099387667386, 144.962593535096),
#  19843: (-37.8110540555305, 144.972910916416),
#  19844: (-37.9091020974712, 145.355291282858),
#  19845: (-37.9081184864021, 145.342994577662),
#  19846: (-37.9036909717454, 145.331333355214),
#  19847: (-37.8683203919866, 145.079655668512),
#  19848: (-37.8619675331692, 145.081343759057),
#  19849: (-37.8515632823172, 145.080511068965),
#  19850: (-37.8439845657174, 145.075559591232),
#  19851: (-37.8357156505359, 145.070297555357),
#  19852: (-37.8315054341723, 145.069645982205),
#  19853: (-37.8265671441669, 145.058697177155),
#  19854: (-37.8183051340585, 144.966964346166),
#  19855: (-38.1429900671654, 145.126162282251),
#  19856: (-38.121742033539, 145.13529534058),
#  19857: (-38.104021039668, 145.128230402217),
#  19858: (-38.0748929182559, 145.122418267271),
#  19859: (-38.0629447836562, 145.119680438871),
#  19860: (-38.0519553837882, 145.116041326748),
#  19861: (-38.0380560155673, 145.108535545056),
#  19862: (-38.0272201944523, 145.102149616841),
#  19863: (-38.0065829507618, 145.08765935746),
#  19864: (-37.9930788207759, 145.076326823728),
#  19865: (-37.9818654019494, 145.065165898742),
#  19866: (-37.9666498944342, 145.054557933026),
#  19867: (-37.8926717009388, 145.307530188155),
#  19868: (-37.8816979923577, 145.295251256598),
#  19869: (-37.8604517998444, 145.28438514597),
#  19870: (-37.8417300410993, 145.268136389217),
#  19871: (-37.8283222725383, 145.244555375848),
#  19872: (-37.9484250041841, 145.041871797791),
#  19873: (-37.8795040720089, 145.162057549621),
#  19874: (-37.8762296254895, 145.149780487778),
#  19875: (-37.8752552557019, 145.128055695744),
#  19876: (-37.7555177718931, 145.347710240852),
#  19877: (-37.7847488250808, 145.312402399118),
#  19878: (-37.7954369700624, 145.280597770769),
#  19879: (-37.811968042776, 145.250190905264),
#  19880: (-38.0806139738066, 145.486379074704),
#  19881: (-38.0661457168648, 145.41098723091),
#  19882: (-38.0508313517826, 145.366073739227),
#  19883: (-38.0404082904993, 145.345726085505),
#  19884: (-38.0278093151679, 145.303969385674),
#  19885: (-38.0177403817805, 145.269776796453),
#  19886: (-38.0995373065849, 145.280598975647),
#  19887: (-38.0790004761497, 145.263511372935),
#  19888: (-37.9899679153812, 145.209725368166),
#  19889: (-37.9782545359253, 145.191600276299),
#  19890: (-37.9672319330584, 145.176935735141),
#  19891: (-37.9565045698556, 145.162825890396),
#  19892: (-37.8258941905331, 145.06819024741),
#  19893: (-37.8244851789179, 145.081224242904),
#  19894: (-37.8242995185069, 145.088647930425),
#  19895: (-37.8241480549092, 145.098774680388),
#  19896: (-37.8194265458808, 145.105530369113),
#  19897: (-37.8207802338117, 145.140702708531),
#  19898: (-37.8200707463673, 145.150013542281),
#  19899: (-37.8206031722516, 145.174891721882),
#  19900: (-37.8180098744252, 145.191973500271),
#  19901: (-37.8188953729427, 145.212787203183),
#  19902: (-37.8158864821449, 145.228968460052),
#  19903: (-37.8223983064618, 145.04584365713),
#  19904: (-37.8214668222115, 145.036438832309),
#  19905: (-37.8218260089713, 145.022898658759),
#  19906: (-37.8275602161665, 145.007555147088),
#  19907: (-37.8263999511153, 144.997065693883),
#  19908: (-37.8240744554248, 144.990164256273),
#  19909: (-37.8346724432589, 145.022635270015),
#  19910: (-37.8399289425903, 145.033551606384),
#  19911: (-37.8493655341752, 145.041733743833),
#  19912: (-37.8532790774224, 145.051654659477),
#  19913: (-37.949508781663, 145.153451830727),
#  19914: (-37.938491213899, 145.13883262698),
#  19915: (-37.9246825520153, 145.120534360257),
#  19916: (-37.9110173407217, 145.102364317185),
#  19917: (-37.900372141144, 145.08830786927),
#  19918: (-37.8948812946199, 145.077635086297),
#  19919: (-37.8901983179693, 145.067374870414),
#  19920: (-37.8862414786323, 145.058575063543),
#  19921: (-37.8993780465601, 144.661118011171),
#  19922: (-37.8832761791168, 144.700954931478),
#  19923: (-37.8636940413851, 144.772616667956),
#  19924: (-37.8666059462953, 144.760809437357),
#  19925: (-37.8651634836576, 144.813493563455),
#  19926: (-37.8671475960047, 144.829644740664),
#  19927: (-37.8678423061915, 144.840957728627),
#  19928: (-37.7806206974559, 144.999233186635),
#  19929: (-37.779187287481, 145.008241630012),
#  19930: (-37.7791712565636, 145.016905299916),
#  19931: (-37.7783936317016, 145.031254932307),
#  19932: (-37.7749634109414, 145.038475977422),
#  19933: (-37.7688967438294, 145.045425188311),
#  19934: (-37.7635855335936, 145.053942691014),
#  19935: (-37.7570729333161, 145.060685522992),
#  19936: (-37.7428786002719, 145.066140290226),
#  19937: (-37.9343532865884, 145.036738286425),
#  19938: (-37.925149188298, 145.035470026499),
#  19939: (-37.9174245729258, 145.036995134208),
#  19940: (-37.9103090338988, 145.038298971504),
#  19941: (-37.9032116703047, 145.039613418163),
#  19942: (-37.8897194619673, 145.042222854186),
#  19943: (-37.8774594614914, 145.042524781036),
#  19944: (-37.8662532993077, 145.029293938791),
#  19945: (-37.8564523828025, 145.019325537875),
#  19946: (-37.8507738052708, 145.013908582451),
#  19947: (-37.8445908738041, 145.002142057363),
#  19948: (-37.9503301772263, 145.004561358882),
#  19949: (-37.9379768129133, 145.00147057003),
#  19950: (-37.9264843202728, 144.989153550272),
#  19951: (-37.9151344061991, 144.996299088376),
#  19952: (-37.9048872134148, 145.00260503336),
#  19953: (-37.8966950752374, 145.004168434303),
#  19954: (-37.8847531121206, 145.000897873416),
#  19955: (-37.8759064268322, 144.995236558908),
#  19956: (-37.8694877274449, 144.993512099451),
#  19957: (-37.8560530796968, 144.992035170295),
#  19958: (-37.8495184845853, 144.989859924303),
#  19959: (-37.8384493490771, 144.992342213835),
#  19960: (-37.6660777887279, 144.946739938663),
#  19961: (-37.7006779971249, 144.958874324034),
#  19962: (-37.7146212867289, 144.960545025448),
#  19963: (-37.7209338911812, 144.961313546073),
#  19964: (-37.7335228508837, 144.962840551625),
#  19965: (-37.7423450211381, 144.963336336826),
#  19966: (-37.7544848430078, 144.961823032047),
#  19967: (-37.7612420288492, 144.960684043548),
#  19968: (-37.7677205467189, 144.959586536251),
#  19969: (-37.7749870223388, 144.958716910938),
#  19970: (-37.7811929299072, 144.952301268806),
#  19971: (-37.7881399497849, 144.939323282774),
#  19972: (-37.7942667317326, 144.936166325307),
#  19973: (-37.8063098353473, 144.94151017321),
#  19974: (-37.7886574531492, 144.995416701875),
#  19975: (-37.7991578245232, 144.994451425812),
#  19976: (-37.8045259264571, 144.993749666428),
#  19977: (-37.810398356473, 144.992500261754),
#  19978: (-37.8149489647723, 144.991422784198),
#  19979: (-37.8165270224388, 144.984098336822),
#  19983: (-37.7260123045348, 145.069143320058),
#  19984: (-37.7109579769573, 145.083793381187),
#  19985: (-37.7039540802734, 145.108247408528),
#  19986: (-37.7152962435564, 145.121515737914),
#  19987: (-37.7135496724624, 145.147822019567),
#  19988: (-37.6732974392921, 145.15850619152),
#  19989: (-37.6639679229939, 145.181614533441),
#  19990: (-37.6393981687758, 145.192016891245),
#  19991: (-37.8677529166559, 144.905323308917),
#  19992: (-37.8639818878493, 144.894483676562),
#  19993: (-37.857333476648, 144.889069465486),
#  19994: (-37.8427175700734, 144.883599911799),
#  19995: (-37.8306388752155, 144.885933453191),
#  19996: (-37.8158504436292, 144.889933707057),
#  19997: (-37.8090051386731, 144.895671569116),
#  20000: (-37.7011287184526, 144.77418045437),
#  20001: (-37.7292793433497, 144.793738065375),
#  20002: (-37.7448613127395, 144.800050450996),
#  20003: (-37.7575108313314, 144.809573352298),
#  20004: (-37.7776528079371, 144.824703607774),
#  20005: (-37.6523871461158, 145.030121682956),
#  20006: (-37.6658507466575, 145.017193167351),
#  20007: (-37.680338088895, 145.01427887056),
#  20008: (-37.6948701213679, 145.011883817693),
#  20009: (-37.7078975350625, 145.0095166168),
#  20010: (-37.7168849163482, 145.006995821329),
#  20011: (-37.728402771293, 145.002772560524),
#  20012: (-37.7386742406, 145.000521982623),
#  20013: (-37.745562121809, 145.000155033588),
#  20014: (-37.7550517929283, 144.998571518715),
#  20015: (-37.7641010022199, 144.997056186716),
#  20016: (-37.7698653716401, 144.995277209924),
#  20017: (-37.7778466758725, 144.992972480498),
#  20019: (-37.7832171114697, 144.992407080112),
#  20021: (-37.7885363319246, 144.832878204953),
#  20022: (-37.7992508990822, 144.862944937737),
#  20023: (-37.8018087041252, 144.885324794446),
#  20024: (-37.8025046951241, 144.891472083864),
#  20025: (-37.8010829790878, 144.90319921519),
#  20026: (-37.7995308742589, 144.925469007521),
#  20027: (-37.787201923265, 144.907588697812),
#  20028: (-37.7834721968038, 144.914256890322),
#  20030: (-37.6830492642064, 144.919613216031),
#  20031: (-37.69513078513, 144.915850518758),
#  20032: (-37.7045363302301, 144.917220403897),
#  20033: (-37.7179497287183, 144.921518773078),
#  20034: (-37.7307559550065, 144.928195624317),
#  20035: (-37.7435913223491, 144.927315711579),
#  20036: (-37.7472098464194, 144.920938683118),
#  20037: (-37.7560116950847, 144.916197501013),
#  20038: (-37.7657066626859, 144.919160695911),
#  20039: (-37.7753060851406, 144.921820740203),
#  20040: (-37.7873276708958, 144.928978466737),
#  20041: (-37.793780219493, 144.930524437443),
#  20042: (-37.8192216542506, 145.121428934402),
#  22180: (-37.8179364275294, 144.951411219785),
#  40220: (-37.6382312060577, 144.935403682146),
#  40221: (-37.6018169039432, 144.943320312888),
#  44817: (-37.6610025309683, 144.92605556678),
#  45793: (-38.0573411764351, 145.249275114245),
#  45794: (-38.0712904706636, 145.437791007046),
#  45795: (-37.6491587964667, 145.067032423831),
#  46468: (-37.8698653272894, 144.747444719947)}

# %% [markdown]
# To find the closest train station, a function `closest_station` will be defined that accepts a row as input, it then calculates the haversine distance using the `haversine` package between each property and all the stops, and returns the stop with the shortest distance.
#
# Similarly, `closest_distance` will be defined that peforms the same function as `closest_station` but it returns the distance in KM instead.
#
# The functions will be applied to `prop_df` to generate the desired columns

# %%
def closest_station(row):
    # property coordinates
    prop_coords = (row["lat"], row["lng"])
    dist_dict = {}    
    
     # calculate haversine distance for each stop
    for stop, coords in stops_dict.items():
        dist_dict[stop] = haversine(prop_coords, coords)
        
    # extract stop with the shortest distance    
    for sub_stop, dist in dist_dict.items():
        if dist == min(dist_dict.values()):
            return sub_stop
        
def closest_distance(row):
    # property coordinates
    prop_coords = (row["lat"], row["lng"])
    dist_dict = {}    
    
     # calculate haversine distance for each stop
    for stop, coords in stops_dict.items():
        dist_dict[stop] = haversine(prop_coords, coords)
        
    # extract stop with the shortest distance    
    for sub_stop, dist in dist_dict.items():
        if dist == min(dist_dict.values()):
            return round(dist, 3)

# %%
prop_df["closest_train_station_id"] = prop_df.apply(closest_station, axis = 1)
prop_df["distance_to_closest_train_station"] = prop_df.apply(closest_distance, axis = 1)
prop_df.head()
# Out:
#   property_id        lat         lng          addr_street      suburb  \
# 0        2645 -37.815113  144.891492   10 Goulburn Street  YARRAVILLE
# 1       51985 -37.799076  145.174236      7 Belmont Court     DONVALE
# 2       76137 -37.909505  145.094192     38 Andrew Street    OAKLEIGH
# 3       96049 -37.912178  145.051455  6 Shanahan Crescent    MCKINNON
# 4       47173 -37.719559  145.160461  40 Malabar Crescent      ELTHAM
#
#           lga  closest_train_station_id  distance_to_closest_train_station
# 0    MITCHELL                     19996                              0.160
# 1       CASEY                     19899                              2.394
# 2  WANGARATTA                     19916                              0.736
# 3     HORSHAM                     19940                              1.173
# 4   FRANKSTON                     19987                              1.297

# %% [markdown]
# ### 3.4 travel_min_to_MC
#
# The next column to be integrated is the `travel_min_to_MC`. For each property, this column holds the rounded average travel time (minutes) of the direct journeys from the closest train station to the Melbourne Central station on weekdays (i.e. Monday-Friday) departing between 7 to 9am. If there are no direct journeys between the closest station and Melbourne Central station, the value will be set to "not available". If the closest station to a property is Melbourne Central station itself, then the value will be set to 0.
#
# Direct journey means that you can reach the Melbourne Central station without changing your train at any point in the journey. So, when you board the train on the closest station, you can directly go to the Melbourne Central station.
#
# To generate the travel times, three data files will be used:
# 1. `calendar`
# 2. `trips`
# 3. `stop_times`
#
# The dataframe `calendar` displays the operating days for each `service_id`. This dataframe will be filtered to only include `service_id`(s) that run on all the weekdays

# %%
# read in calendar
calendar = pd.read_csv("data/Vic_GTFS_data/metropolitan/calendar.txt")
calendar
# Out:
#    service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0          T2       0        0          0         0       0         1       0
# 1          UJ       0        0          0         0       0         0       1
# 2          T6       0        0          0         0       1         0       0
# 3          T5       1        1          1         1       0         0       0
# 4        T2_1       0        0          0         0       0         1       0
# 5        UJ_1       0        0          0         0       0         0       1
# 6        T6_1       0        0          0         0       1         0       0
# 7        T5_1       1        1          1         1       0         0       0
# 8          T0       1        1          1         1       1         0       0
# 9        T2_2       0        0          0         0       0         1       0
# 10       UJ_2       0        0          0         0       0         0       1
# 11      T0+a6       0        0          0         0       1         0       0
# 12      T0+a5       1        1          1         1       0         0       0
# 13      T5+tg       1        1          0         0       0         0       0
# 14      T5+ph       0        0          1         1       0         0       0
# 15    T5+tg_1       1        1          0         0       0         0       0
# 16    T5+ph_1       0        0          1         1       0         0       0
# 17      T5+ao       1        0          0         0       0         0       0
# 18      T5+ta       0        1          1         1       0         0       0
#
#     start_date  end_date
# 0     20151009  20151011
# 1     20151009  20151011
# 2     20151009  20151011
# 3     20151012  20151015
# 4     20151016  20151018
# 5     20151016  20151018
# 6     20151016  20151018
# 7     20151019  20151022
# 8     20151023  20151122
# 9     20151023  20151122
# 10    20151023  20151122
# 11    20151023  20151122
# 12    20151023  20151122
# 13    20151012  20151015
# 14    20151012  20151015
# 15    20151019  20151022
# 16    20151019  20151022
# 17    20151012  20151015
# 18    20151012  20151015

# %%
# filter services_id's to include those that run on all weekdays
calendar = calendar[((calendar["monday"] == 1) & (calendar["tuesday"] == 1) & (calendar["wednesday"] == 1) & (calendar["thursday"] == 1) & (calendar["friday"] == 1))]
calendar
# Out:
#   service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 8         T0       1        1          1         1       1         0       0
#
#    start_date  end_date
# 8    20151023  20151122

# %% [markdown]
# The `trips` dataframe displays the `trip_id` for each `service_id` in `calendar`. We will filter `trips` to only include `service_id`'s that exist in `calendar`

# %%
# read in trips
trips = pd.read_csv("data/Vic_GTFS_data/metropolitan/trips.txt")
trips.head()
# Out:
#         route_id service_id                        trip_id           shape_id  \
# 0  2-ALM-F-mjp-1         T0  17067982.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 1  2-ALM-F-mjp-1         T0  17067988.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 2  2-ALM-F-mjp-1         T0  17067992.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 3  2-ALM-F-mjp-1         T0  17067999.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 4  2-ALM-F-mjp-1         T0  17068003.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
#
#             trip_headsign  direction_id
# 0  City (Flinders Street)             0
# 1  City (Flinders Street)             0
# 2  City (Flinders Street)             0
# 3  City (Flinders Street)             0
# 4  City (Flinders Street)             0

# %%
# filter to only include service_id's in calendar
trips = trips[trips["service_id"].isin(calendar["service_id"])]
trips.head()
# Out:
#         route_id service_id                        trip_id           shape_id  \
# 0  2-ALM-F-mjp-1         T0  17067982.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 1  2-ALM-F-mjp-1         T0  17067988.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 2  2-ALM-F-mjp-1         T0  17067992.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 3  2-ALM-F-mjp-1         T0  17067999.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
# 4  2-ALM-F-mjp-1         T0  17068003.T0.2-ALM-F-mjp-1.1.H  2-ALM-F-mjp-1.1.H
#
#             trip_headsign  direction_id
# 0  City (Flinders Street)             0
# 1  City (Flinders Street)             0
# 2  City (Flinders Street)             0
# 3  City (Flinders Street)             0
# 4  City (Flinders Street)             0

# %% [markdown]
# The `stop_times` dataframe displays the `arrival_time`, `departure_time` and `stop_id` for each `trip_id`. `stop_times` will be filtered to only contain the `trip_id`'s contained in `trips`.

# %%
# read in stop_times
stop_times = pd.read_csv("data/Vic_GTFS_data/metropolitan/stop_times.txt")
stop_times.head()
# Out:
#                          trip_id arrival_time departure_time  stop_id  \
# 0  17182517.T2.2-ALM-B-mjp-1.1.H     04:57:00       04:57:00    19847
# 1  17182517.T2.2-ALM-B-mjp-1.1.H     04:58:00       04:58:00    19848
# 2  17182517.T2.2-ALM-B-mjp-1.1.H     05:00:00       05:00:00    19849
# 3  17182517.T2.2-ALM-B-mjp-1.1.H     05:02:00       05:02:00    19850
# 4  17182517.T2.2-ALM-B-mjp-1.1.H     05:04:00       05:04:00    19851
#
#    stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0              1            NaN            0              0
# 1              2            NaN            0              0
# 2              3            NaN            0              0
# 3              4            NaN            0              0
# 4              5            NaN            0              0
#
#    shape_dist_traveled
# 0             0.000000
# 1           723.017818
# 2          1951.735072
# 3          2899.073349
# 4          3927.090952

# %%
# filter to only include trip_id's present in trips
stop_times = stop_times[stop_times["trip_id"].isin(trips["trip_id"])]
stop_times.head()
# Out:
#                             trip_id arrival_time departure_time  stop_id  \
# 8568  17067982.T0.2-ALM-F-mjp-1.1.H     05:01:00       05:01:00    19847
# 8569  17067982.T0.2-ALM-F-mjp-1.1.H     05:02:00       05:02:00    19848
# 8570  17067982.T0.2-ALM-F-mjp-1.1.H     05:04:00       05:04:00    19849
# 8571  17067982.T0.2-ALM-F-mjp-1.1.H     05:06:00       05:06:00    19850
# 8572  17067982.T0.2-ALM-F-mjp-1.1.H     05:08:00       05:08:00    19851
#
#       stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 8568              1            NaN            0              0
# 8569              2            NaN            0              0
# 8570              3            NaN            0              0
# 8571              4            NaN            0              0
# 8572              5            NaN            0              0
#
#       shape_dist_traveled
# 8568             0.000000
# 8569           723.017818
# 8570          1951.735072
# 8571          2899.073349
# 8572          3927.090952

# %% [markdown]
# The `departure_time` column will be filtered to only contain times between 7:00:00 and 23:59:59

# %%
stop_times = stop_times[((stop_times["departure_time"] >= "07:00:00") & (stop_times["departure_time"] < "24:00:00")) & (stop_times["arrival_time"] < "24:00:00")]
stop_times.head()
# Out:
#                             trip_id arrival_time departure_time  stop_id  \
# 8911  17067988.T0.2-ALM-F-mjp-1.1.H     09:38:00       09:38:00    19847
# 8912  17067988.T0.2-ALM-F-mjp-1.1.H     09:39:00       09:39:00    19848
# 8913  17067988.T0.2-ALM-F-mjp-1.1.H     09:41:00       09:41:00    19849
# 8914  17067988.T0.2-ALM-F-mjp-1.1.H     09:43:00       09:43:00    19850
# 8915  17067988.T0.2-ALM-F-mjp-1.1.H     09:44:00       09:44:00    19851
#
#       stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 8911              1            NaN            0              0
# 8912              2            NaN            0              0
# 8913              3            NaN            0              0
# 8914              4            NaN            0              0
# 8915              5            NaN            0              0
#
#       shape_dist_traveled
# 8911             0.000000
# 8912           723.017818
# 8913          1951.735072
# 8914          2899.073349
# 8915          3927.090952

# %% [markdown]
# The `arrival_time` and `departure_time` columns will be converted to datetime

# %%
stop_times.loc[:, 'arrival_time'] = pd.to_datetime(stop_times['arrival_time'],format= '%H:%M:%S')
stop_times.loc[:, 'departure_time'] = pd.to_datetime(stop_times['departure_time'],format= '%H:%M:%S')
stop_times.head()
# Out:
#                             trip_id        arrival_time      departure_time  \
# 8911  17067988.T0.2-ALM-F-mjp-1.1.H 1900-01-01 09:38:00 1900-01-01 09:38:00
# 8912  17067988.T0.2-ALM-F-mjp-1.1.H 1900-01-01 09:39:00 1900-01-01 09:39:00
# 8913  17067988.T0.2-ALM-F-mjp-1.1.H 1900-01-01 09:41:00 1900-01-01 09:41:00
# 8914  17067988.T0.2-ALM-F-mjp-1.1.H 1900-01-01 09:43:00 1900-01-01 09:43:00
# 8915  17067988.T0.2-ALM-F-mjp-1.1.H 1900-01-01 09:44:00 1900-01-01 09:44:00
#
#       stop_id  stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 8911    19847              1            NaN            0              0
# 8912    19848              2            NaN            0              0
# 8913    19849              3            NaN            0              0
# 8914    19850              4            NaN            0              0
# 8915    19851              5            NaN            0              0
#
#       shape_dist_traveled
# 8911             0.000000
# 8912           723.017818
# 8913          1951.735072
# 8914          2899.073349
# 8915          3927.090952

# %% [markdown]
# We can see that `arrival_time` and `departure_time` now contain dates, but for our purposes it is of no concern. Only the time matters.
#
# We can now calculate the time difference in minutes between two times like so [(source)](https://www.datasciencemadesimple.com/difference-two-timestamps-seconds-minutes-hours-pandas-python-2/):

# %%
depart_time = stop_times.loc[8911, "departure_time"]
arrive_time = stop_times.loc[8912, "arrival_time"]
(arrive_time - depart_time) / np.timedelta64(1,'m')
# Out:
# 1.0

# %% [markdown]
# A series containing the `trip_id`'s as index and that trip's stops as values will be created. This will be done by grouping `stop_times` by `trip_id` and retrieving the unique `stop_id`'s for that `trip_id`

# %%
trip_stops = stop_times.groupby("trip_id")["stop_id"].unique()
trip_stops
# Out:
# trip_id
# 17067064.T0.2-EPP-F-mjp-1.8.R                   [19854, 22180, 19841, 19842, 19843]
# 17067067.T0.2-EPP-F-mjp-1.8.R     [19976, 19977, 19978, 19979, 19854, 22180, 198...
# 17067069.T0.2-EPP-F-mjp-1.8.R     [20016, 20017, 20019, 19974, 19975, 19976, 199...
# 17067072.T0.2-EPP-F-mjp-1.9.R     [20011, 20012, 20013, 20014, 20015, 20016, 200...
# 17067074.T0.2-EPP-F-mjp-1.8.R     [20006, 20007, 20008, 20009, 20010, 20011, 200...
#                                                         ...
# 17072311.T0.2-WBE-F-mjp-1.6.H                   [19923, 19925, 19926, 19927, 19994]
# 17072312.T0.2-WBE-F-mjp-1.22.R                  [19994, 19927, 19926, 19925, 19923]
# 17072313.T0.2-WBE-F-mjp-1.6.H                   [19923, 19925, 19926, 19927, 19994]
# 17072314.T0.2-WBE-F-mjp-1.22.R                  [19994, 19927, 19926, 19925, 19923]
# 17072315.T0.2-WBE-F-mjp-1.22.R                  [19994, 19927, 19926, 19925, 19923]
# Name: stop_id, Length: 2149, dtype: object

# %% [markdown]
# `trips_stops` will be converted into a dictionary `trip_dict`

# %%
trip_dict = trip_stops.to_dict()
# convert series of stops into a list
trip_dict = {trip: list(stops) for trip, stops in trip_dict.items()}
trip_dict
# Out:
# {'17067064.T0.2-EPP-F-mjp-1.8.R': [19854, 22180, 19841, 19842, 19843],
#  '17067067.T0.2-EPP-F-mjp-1.8.R': [19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067069.T0.2-EPP-F-mjp-1.8.R': [20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067072.T0.2-EPP-F-mjp-1.9.R': [20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067074.T0.2-EPP-F-mjp-1.8.R': [20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067077.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067079.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067082.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067085.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067088.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067091.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067094.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067097.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067100.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067103.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067106.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067109.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067112.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067115.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067118.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067121.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067124.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067127.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067130.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067133.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067136.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067139.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067142.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067145.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067148.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067151.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067154.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067157.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067160.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067163.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067166.T0.2-EPP-F-mjp-1.10.R': [20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067169.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067172.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067175.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067178.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067183.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067186.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067189.T0.2-EPP-F-mjp-1.10.R': [20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067192.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067196.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067197.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067198.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067200.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067202.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067203.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067204.T0.2-EPP-F-mjp-1.11.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067205.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067206.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067207.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067208.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067209.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067210.T0.2-EPP-F-mjp-1.11.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067211.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067212.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067213.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067214.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067215.T0.2-EPP-F-mjp-1.9.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067216.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067217.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067218.T0.2-EPP-F-mjp-1.8.R': [45795,
#   20005,
#   20006,
#   20007,
#   20008,
#   20009,
#   20010,
#   20011,
#   20012,
#   20013,
#   20014,
#   20015,
#   20016,
#   20017,
#   20019,
#   19974,
#   19975],
#  '17067231.T0.2-HBG-F-mjp-1.2.H': [19842, 19843],
#  '17067234.T0.2-HBG-F-mjp-1.3.H': [19854, 22180, 19841, 19842, 19843],
#  '17067236.T0.2-HBG-F-mjp-1.4.H': [19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067239.T0.2-HBG-F-mjp-1.5.H': [19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067241.T0.2-HBG-F-mjp-1.3.H': [19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067244.T0.2-HBG-F-mjp-1.4.H': [19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067246.T0.2-HBG-F-mjp-1.6.H': [19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19933,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067249.T0.2-HBG-F-mjp-1.5.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067251.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067254.T0.2-HBG-F-mjp-1.5.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067257.T0.2-HBG-F-mjp-1.6.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19933,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067260.T0.2-HBG-F-mjp-1.4.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067263.T0.2-HBG-F-mjp-1.5.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067266.T0.2-HBG-F-mjp-1.6.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19933,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067269.T0.2-HBG-F-mjp-1.9.H': [19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067272.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067275.T0.2-HBG-F-mjp-1.4.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067278.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067281.T0.2-HBG-F-mjp-1.6.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19933,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067284.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067287.T0.2-HBG-F-mjp-1.5.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067290.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067293.T0.2-HBG-F-mjp-1.10.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067296.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067299.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067302.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067305.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067308.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067311.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067314.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067317.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067320.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067323.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067326.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067329.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067332.T0.2-HBG-F-mjp-1.10.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067335.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067338.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067343.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067348.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067351.T0.2-HBG-F-mjp-1.4.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067354.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067357.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067360.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067363.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067366.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067368.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067369.T0.2-HBG-F-mjp-1.11.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19933,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067370.T0.2-HBG-F-mjp-1.8.H': [19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067372.T0.2-HBG-F-mjp-1.12.H': [19987,
#   19986,
#   19985,
#   19935,
#   19933,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067374.T0.2-HBG-F-mjp-1.13.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067375.T0.2-HBG-F-mjp-1.6.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19933,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067376.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067377.T0.2-HBG-F-mjp-1.2.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067378.T0.2-HBG-F-mjp-1.14.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067379.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067380.T0.2-HBG-F-mjp-1.10.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067381.T0.2-HBG-F-mjp-1.13.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067382.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067383.T0.2-HBG-F-mjp-1.13.H': [19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067384.T0.2-HBG-F-mjp-1.10.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067385.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067386.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067387.T0.2-HBG-F-mjp-1.1.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067388.T0.2-HBG-F-mjp-1.7.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067389.T0.2-HBG-F-mjp-1.10.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067390.T0.2-HBG-F-mjp-1.14.H': [19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067391.T0.2-HBG-F-mjp-1.10.H': [19990,
#   19989,
#   19988,
#   19987,
#   19986,
#   19985,
#   19984,
#   19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19975,
#   19976,
#   19977,
#   19978,
#   19979,
#   19854],
#  '17067393.T0.2-HBG-F-mjp-1.8.H': [19983,
#   19936,
#   19935,
#   19934,
#   19933,
#   19932,
#   19931,
#   19930,
#   19929,
#   19928,
#   19974,
#   19979,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17067400.T0.2-EPP-F-mjp-1.1.H': [45795],
#  '17067402.T0.2-EPP-F-mjp-1.1.H': [20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067404.T0.2-EPP-F-mjp-1.1.H': [19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067406.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067409.T0.2-EPP-F-mjp-1.2.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067411.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067414.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067416.T0.2-EPP-F-mjp-1.3.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20012,
#   20010,
#   20007,
#   20006,
#   20005],
#  '17067419.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067421.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067424.T0.2-EPP-F-mjp-1.3.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20012,
#   20010,
#   20007,
#   20006,
#   20005],
#  '17067427.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067430.T0.2-EPP-F-mjp-1.4.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005],
#  '17067433.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067436.T0.2-EPP-F-mjp-1.3.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20012,
#   20010,
#   20007,
#   20006,
#   20005],
#  '17067439.T0.2-EPP-F-mjp-1.4.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005],
#  '17067442.T0.2-EPP-F-mjp-1.3.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20012,
#   20010,
#   20007,
#   20006,
#   20005],
#  '17067445.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067448.T0.2-EPP-F-mjp-1.5.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005],
#  '17067451.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067454.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067457.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067460.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067463.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067466.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067469.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067472.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067475.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067478.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067481.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067484.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067487.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067490.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067493.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067496.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067499.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067502.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067505.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067508.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067511.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067514.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067517.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067520.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067523.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067526.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067529.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067532.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067535.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067538.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067539.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067540.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067541.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067542.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067543.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067544.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067545.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067546.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067547.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067548.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067549.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067550.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067551.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
#   19841,
#   19842,
#   19843,
#   19979,
#   19978,
#   19977,
#   19976,
#   19975,
#   19974,
#   20019,
#   20017,
#   20016,
#   20015,
#   20014,
#   20013,
#   20012,
#   20011,
#   20010,
#   20009,
#   20008,
#   20007,
#   20006,
#   20005,
#   45795],
#  '17067552.T0.2-EPP-F-mjp-1.1.H': [19854,
#   22180,
# ...
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069365.T0.2-CRB-F-mjp-1.4.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854],
#  '17069367.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069370.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069373.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069374.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069377.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069378.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069381.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069382.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069385.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069386.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069389.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069390.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069393.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069394.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069397.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069398.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069401.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069402.T0.2-CRB-F-mjp-1.10.R': [19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069405.T0.2-CRB-F-mjp-1.5.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069406.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069409.T0.2-CRB-F-mjp-1.4.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854],
#  '17069410.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069413.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069414.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069417.T0.2-CRB-F-mjp-1.3.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854,
#   22180,
#   19841,
#   19842,
#   19843],
#  '17069419.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069422.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069424.T0.2-CRB-F-mjp-1.10.R': [19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069427.T0.2-CRB-F-mjp-1.4.H': [19886,
#   19887,
#   45793,
#   19888,
#   19889,
#   19890,
#   19891,
#   19913,
#   19914,
#   19915,
#   19916,
#   19917,
#   19918,
#   19919,
#   19920,
#   19943,
#   19959,
#   19908,
#   19854],
#  '17069429.T0.2-CRB-F-mjp-1.9.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19920,
#   19919,
#   19918,
#   19917,
#   19916,
#   19915,
#   19914,
#   19913,
#   19891,
#   19890,
#   19889,
#   19888,
#   45793,
#   19887,
#   19886],
#  '17069432.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069433.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069436.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069437.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069440.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069441.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069444.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069445.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069448.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069449.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069452.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069453.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069456.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069457.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069460.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069461.T0.2-CRB-F-mjp-1.8.R': [19888, 45793, 19887, 19886],
#  '17069464.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069467.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069468.T0.2-CRB-F-mjp-1.8.R': [19888],
#  '17069471.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069475.T0.2-CRB-F-mjp-1.1.H': [19886, 19887, 45793, 19888],
#  '17069479.T0.2-CRB-F-mjp-1.1.H': [19886],
#  '17069512.T0.2-FKN-F-mjp-1.1.H': [19854, 22180],
#  '17069515.T0.2-FKN-F-mjp-1.5.H': [19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069518.T0.2-FKN-F-mjp-1.5.H': [19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069522.T0.2-FKN-F-mjp-1.5.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069525.T0.2-FKN-F-mjp-1.8.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854],
#  '17069528.T0.2-FKN-F-mjp-1.8.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854],
#  '17069529.T0.2-FKN-F-mjp-1.14.R': [19855],
#  '17069532.T0.2-FKN-F-mjp-1.8.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854],
#  '17069533.T0.2-FKN-F-mjp-1.15.R': [19860, 19859, 19858, 19857, 19856, 19855],
#  '17069536.T0.2-FKN-F-mjp-1.5.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069537.T0.2-FKN-F-mjp-1.15.R': [19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069540.T0.2-FKN-F-mjp-1.8.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854],
#  '17069541.T0.2-FKN-F-mjp-1.15.R': [19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069544.T0.2-FKN-F-mjp-1.9.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854],
#  '17069545.T0.2-FKN-F-mjp-1.14.R': [19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069548.T0.2-FKN-F-mjp-1.9.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854],
#  '17069549.T0.2-FKN-F-mjp-1.15.R': [19947,
#   19946,
#   19945,
#   19944,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069552.T0.2-FKN-F-mjp-1.9.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19943,
#   19944,
#   19959,
#   19908,
#   19854],
#  '17069553.T0.2-FKN-F-mjp-1.15.R': [19854,
#   19908,
#   19959,
#   19947,
#   19946,
#   19945,
#   19944,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069556.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069557.T0.2-FKN-F-mjp-1.15.R': [22180,
#   19854,
#   19908,
#   19959,
#   19947,
#   19946,
#   19945,
#   19944,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069560.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069561.T0.2-FKN-F-mjp-1.17.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19947,
#   19946,
#   19945,
#   19944,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069564.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069565.T0.2-FKN-F-mjp-1.17.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19947,
#   19946,
#   19945,
#   19944,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069568.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069569.T0.2-FKN-F-mjp-1.17.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19947,
#   19946,
#   19945,
#   19944,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069572.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069575.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069576.T0.2-FKN-F-mjp-1.18.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  '17069579.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069580.T0.2-FKN-F-mjp-1.19.R': [22180,
#   19854,
#   19908,
#   19959,
#   19947,
#   19946,
#   19945,
#   19944,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937],
#  '17069583.T0.2-FKN-F-mjp-1.1.H': [19855,
#   19856,
#   19857,
#   19858,
#   19859,
#   19860,
#   19861,
#   19862,
#   19863,
#   19864,
#   19865,
#   19866,
#   19872,
#   19937,
#   19938,
#   19939,
#   19940,
#   19941,
#   19942,
#   19943,
#   19944,
#   19945,
#   19946,
#   19947,
#   19959,
#   19908,
#   19854,
#   22180],
#  '17069584.T0.2-FKN-F-mjp-1.18.R': [19843,
#   19842,
#   19841,
#   22180,
#   19854,
#   19908,
#   19959,
#   19943,
#   19942,
#   19941,
#   19940,
#   19939,
#   19938,
#   19937,
#   19872,
#   19866,
#   19865,
#   19864,
#   19863,
#   19862,
#   19861,
#   19860,
#   19859,
#   19858,
#   19857,
#   19856,
#   19855],
#  ...}

# %% [markdown]
# A function `melb_cen_time` will be defined that accepts a stop as input, and returns one of:
# 1. **0** if the stop is Melbourne Central
# 2. **average journey time** if Melbourne Central can be reached in a single trip and the departure time is between 7am and 9am
# 3. **not available** if neither of the above are satisfied
#
# First we need the `stop_id` for Melbourne Central. Using the `stops` file in the previous sections, we can retrieve the `stop_id` corresponding to Melbourne Central:

# %%
for line in stops:
    if "Melbourne Central" in line:
        print(line.split(",")[0])
# Out:
# "19842"

# %% [markdown]
# Melbourne Central's stop is **19842**

# %%
def melb_cen_time(stop):
    times = []
    routes = []
    
    # closest station is Melbourne Central
    if stop == 19842:
        return 0
    
    for route, stops_list in trip_dict.items():
        # check both stops in the route and Melbourne Central's stop comes after the closest station stop
        if (stop in stops_list) and (19842 in stops_list) and (stops_list.index(stop) < stops_list.index(19842)):
            routes.append(route)

    # if no routes contain both stops, or if Melbourne Central comes before our stop, then there are no direct journeys
    if len(routes) == 0:
        return "not available"
    
    for r in routes:
        # check departure time from the stop is between 7am and 9am  
        if stop_times.loc[(stop_times["trip_id"] == r) & (stop_times["stop_id"] == stop), "departure_time"].dt.hour.values[0] <= 9:                       
            depart_time = stop_times.loc[(stop_times["trip_id"] == r) & (stop_times["stop_id"] == stop), "departure_time"].values[0]
            arrive_time = stop_times.loc[(stop_times["trip_id"] == r) & (stop_times["stop_id"] == 19842), "arrival_time"].values[0]
            time = (arrive_time - depart_time) / np.timedelta64(1,'m')
            times.append((time))
    
    # none of the potential routes satisfy the conditions
    if len(times) == 0:
        return "not available"
    
    else:
        return round(np.mean(times))

# %% [markdown]
# Instead of applying the function to each row in `prop_df`, to save time, we will create a dictionary `stop_to_MC_times` that will contain the time according to each stop by applying `melb_cen_time` to the unique values of `closest_train_station_id` in `prop_df`

# %%
stop_to_MC_times = {stop: melb_cen_time(stop) for stop in prop_df["closest_train_station_id"].unique()}

# %% [markdown]
# Using a lambda a function, the `travel_min_to_MC` will be created by extracting the time that matches the `closest_train_station_id` in `stop_to_MC_times`

# %%
prop_df["travel_min_to_MC"] = prop_df["closest_train_station_id"].apply(lambda x: stop_to_MC_times[x])
prop_df.head()
# Out:
#   property_id        lat         lng          addr_street      suburb  \
# 0        2645 -37.815113  144.891492   10 Goulburn Street  YARRAVILLE
# 1       51985 -37.799076  145.174236      7 Belmont Court     DONVALE
# 2       76137 -37.909505  145.094192     38 Andrew Street    OAKLEIGH
# 3       96049 -37.912178  145.051455  6 Shanahan Crescent    MCKINNON
# 4       47173 -37.719559  145.160461  40 Malabar Crescent      ELTHAM
#
#           lga  closest_train_station_id  distance_to_closest_train_station  \
# 0    MITCHELL                     19996                              0.160
# 1       CASEY                     19899                              2.394
# 2  WANGARATTA                     19916                              0.736
# 3     HORSHAM                     19940                              1.173
# 4   FRANKSTON                     19987                              1.297
#
#   travel_min_to_MC
# 0    not available
# 1               28
# 2               27
# 3               28
# 4               52

# %% [markdown]
# ### 3.5 direct_journey_flag
#
# This column indicates whether there is a direct journey to the Melbourne Central station from the closest station between 7-9am on the weekdays. The value is 1 if there is a direct trip (i.e. no transfer between trains is required to get from the closest train station to the Melbourne Central station) and 0 otherwise.
#
# To generate the values in the column, a lambda function will be applied where if `travel_min_to_MC` is equal to **not available** then 0 is returned, otherwise it will return 1

# %%
prop_df["direct_journey_flag"] = prop_df["travel_min_to_MC"].apply(lambda x: 0 if x == "not available" else 1)
prop_df.head()
# Out:
#   property_id        lat         lng          addr_street      suburb  \
# 0        2645 -37.815113  144.891492   10 Goulburn Street  YARRAVILLE
# 1       51985 -37.799076  145.174236      7 Belmont Court     DONVALE
# 2       76137 -37.909505  145.094192     38 Andrew Street    OAKLEIGH
# 3       96049 -37.912178  145.051455  6 Shanahan Crescent    MCKINNON
# 4       47173 -37.719559  145.160461  40 Malabar Crescent      ELTHAM
#
#           lga  closest_train_station_id  distance_to_closest_train_station  \
# 0    MITCHELL                     19996                              0.160
# 1       CASEY                     19899                              2.394
# 2  WANGARATTA                     19916                              0.736
# 3     HORSHAM                     19940                              1.173
# 4   FRANKSTON                     19987                              1.297
#
#   travel_min_to_MC  direct_journey_flag
# 0    not available                    0
# 1               28                    1
# 2               27                    1
# 3               28                    1
# 4               52                    1

# %% [markdown]
# ### 3.6 COVID Cases Columns
#
# The final columns to be integrated are the COVID cases columns. The columns will hold the following values for each property according to its `lga`:
# - `30_sep_cases`: The number of Covid-19 positive cases on the 30th of September
# - `last_14_days_cases`: The rounded average of Covid-19 cases for the last 14 days starting from 29th of September backward
# -`last_30_days_cases`: The rounded average of Covid-19 cases for the last 30 days starting from 29th of September backward
# - `last_60_days_cases`: The rounded average of Covid-19 cases for the last 60 days starting from 29th of September backward
#
# The COVID figures will be retrieved from the website [covidlive.com.au](https://covidlive.com.au/).
#
# The figures for a given `lga` can be accessed using the following URL:
#
# **https://covidlive.com.au/vic/** followed by the name of the `lga`
#
# The URL will be opened using `urlopen` from the `urllib` package. The HTML object will then be parsed using `BeautifulSoup` from the `bs4` package. To retrieve the dates, all the **td** tags with the class attribute **COL1 DATE** will be found. Similarly, to retrieve the cases, all the **td** tags with the class attribute **COL4 CASES** will be found. The dates and cases will then be joined together into a dataframe.
#
# The cases in the URL are presented in a cumulative manner from day to day. Therefore the cases from two dates will be differenced to calculate each figure. The dates needed to calculate the desired values for the columns are:
# - August 01: to calculate 60 day average
# - August 31: to calculate 30 day average
# - September 16: to calculate 14 day average
# - September 29: to calculate all
# - September 30: to calculate September 30 cases
#
# To illustrate, the process described will be implemented on the `lga` **Maribyrnong**

# %%
html = urlopen("https://covidlive.com.au/vic/maribyrnong")
bsObj = BeautifulSoup(html, "html.parser")

dates_tags = bsObj.find_all("td", "COL1 DATE")
dates_tags
# Out:
# [<td class="COL1 DATE">31 Oct</td>,
#  <td class="COL1 DATE">30 Oct</td>,
#  <td class="COL1 DATE">29 Oct</td>,
#  <td class="COL1 DATE">28 Oct</td>,
#  <td class="COL1 DATE">27 Oct</td>,
#  <td class="COL1 DATE">26 Oct</td>,
#  <td class="COL1 DATE">25 Oct</td>,
#  <td class="COL1 DATE">24 Oct</td>,
#  <td class="COL1 DATE">23 Oct</td>,
#  <td class="COL1 DATE">22 Oct</td>,
#  <td class="COL1 DATE">21 Oct</td>,
#  <td class="COL1 DATE">20 Oct</td>,
#  <td class="COL1 DATE">19 Oct</td>,
#  <td class="COL1 DATE">18 Oct</td>,
#  <td class="COL1 DATE">17 Oct</td>,
#  <td class="COL1 DATE">16 Oct</td>,
#  <td class="COL1 DATE">15 Oct</td>,
#  <td class="COL1 DATE">14 Oct</td>,
#  <td class="COL1 DATE">13 Oct</td>,
#  <td class="COL1 DATE">12 Oct</td>,
#  <td class="COL1 DATE">11 Oct</td>,
#  <td class="COL1 DATE">10 Oct</td>,
#  <td class="COL1 DATE">09 Oct</td>,
#  <td class="COL1 DATE">08 Oct</td>,
#  <td class="COL1 DATE">07 Oct</td>,
#  <td class="COL1 DATE">06 Oct</td>,
#  <td class="COL1 DATE">05 Oct</td>,
#  <td class="COL1 DATE">04 Oct</td>,
#  <td class="COL1 DATE">03 Oct</td>,
#  <td class="COL1 DATE">02 Oct</td>,
#  <td class="COL1 DATE">01 Oct</td>,
#  <td class="COL1 DATE">30 Sep</td>,
#  <td class="COL1 DATE">29 Sep</td>,
#  <td class="COL1 DATE">28 Sep</td>,
#  <td class="COL1 DATE">27 Sep</td>,
#  <td class="COL1 DATE">26 Sep</td>,
#  <td class="COL1 DATE">25 Sep</td>,
#  <td class="COL1 DATE">24 Sep</td>,
#  <td class="COL1 DATE">23 Sep</td>,
#  <td class="COL1 DATE">22 Sep</td>,
#  <td class="COL1 DATE">21 Sep</td>,
#  <td class="COL1 DATE">20 Sep</td>,
#  <td class="COL1 DATE">19 Sep</td>,
#  <td class="COL1 DATE">18 Sep</td>,
#  <td class="COL1 DATE">17 Sep</td>,
#  <td class="COL1 DATE">16 Sep</td>,
#  <td class="COL1 DATE">15 Sep</td>,
#  <td class="COL1 DATE">14 Sep</td>,
#  <td class="COL1 DATE">13 Sep</td>,
#  <td class="COL1 DATE">12 Sep</td>,
#  <td class="COL1 DATE">11 Sep</td>,
#  <td class="COL1 DATE">10 Sep</td>,
#  <td class="COL1 DATE">09 Sep</td>,
#  <td class="COL1 DATE">08 Sep</td>,
#  <td class="COL1 DATE">07 Sep</td>,
#  <td class="COL1 DATE">06 Sep</td>,
#  <td class="COL1 DATE">05 Sep</td>,
#  <td class="COL1 DATE">04 Sep</td>,
#  <td class="COL1 DATE">03 Sep</td>,
#  <td class="COL1 DATE">02 Sep</td>,
#  <td class="COL1 DATE">01 Sep</td>,
#  <td class="COL1 DATE">31 Aug</td>,
#  <td class="COL1 DATE">30 Aug</td>,
#  <td class="COL1 DATE">29 Aug</td>,
#  <td class="COL1 DATE">28 Aug</td>,
#  <td class="COL1 DATE">27 Aug</td>,
#  <td class="COL1 DATE">26 Aug</td>,
#  <td class="COL1 DATE">25 Aug</td>,
#  <td class="COL1 DATE">24 Aug</td>,
#  <td class="COL1 DATE">23 Aug</td>,
#  <td class="COL1 DATE">22 Aug</td>,
#  <td class="COL1 DATE">21 Aug</td>,
#  <td class="COL1 DATE">20 Aug</td>,
#  <td class="COL1 DATE">19 Aug</td>,
#  <td class="COL1 DATE">18 Aug</td>,
#  <td class="COL1 DATE">17 Aug</td>,
#  <td class="COL1 DATE">16 Aug</td>,
#  <td class="COL1 DATE">15 Aug</td>,
#  <td class="COL1 DATE">14 Aug</td>,
#  <td class="COL1 DATE">13 Aug</td>,
#  <td class="COL1 DATE">12 Aug</td>,
#  <td class="COL1 DATE">11 Aug</td>,
#  <td class="COL1 DATE">10 Aug</td>,
#  <td class="COL1 DATE">09 Aug</td>,
#  <td class="COL1 DATE">08 Aug</td>,
#  <td class="COL1 DATE">07 Aug</td>,
#  <td class="COL1 DATE">06 Aug</td>,
#  <td class="COL1 DATE">05 Aug</td>,
#  <td class="COL1 DATE">04 Aug</td>,
#  <td class="COL1 DATE">03 Aug</td>,
#  <td class="COL1 DATE">02 Aug</td>,
#  <td class="COL1 DATE">01 Aug</td>,
#  <td class="COL1 DATE">31 Jul</td>,
#  <td class="COL1 DATE">30 Jul</td>,
#  <td class="COL1 DATE">29 Jul</td>,
#  <td class="COL1 DATE">28 Jul</td>,
#  <td class="COL1 DATE">27 Jul</td>,
#  <td class="COL1 DATE">26 Jul</td>,
#  <td class="COL1 DATE">25 Jul</td>,
#  <td class="COL1 DATE">24 Jul</td>,
#  <td class="COL1 DATE">23 Jul</td>,
#  <td class="COL1 DATE">22 Jul</td>,
#  <td class="COL1 DATE">21 Jul</td>,
#  <td class="COL1 DATE">20 Jul</td>,
#  <td class="COL1 DATE">19 Jul</td>,
#  <td class="COL1 DATE">18 Jul</td>,
#  <td class="COL1 DATE">17 Jul</td>,
#  <td class="COL1 DATE">16 Jul</td>,
#  <td class="COL1 DATE">15 Jul</td>,
#  <td class="COL1 DATE">14 Jul</td>,
#  <td class="COL1 DATE">13 Jul</td>,
#  <td class="COL1 DATE">12 Jul</td>,
#  <td class="COL1 DATE">11 Jul</td>,
#  <td class="COL1 DATE">10 Jul</td>,
#  <td class="COL1 DATE">09 Jul</td>,
#  <td class="COL1 DATE">08 Jul</td>,
#  <td class="COL1 DATE">07 Jul</td>,
#  <td class="COL1 DATE">06 Jul</td>,
#  <td class="COL1 DATE">05 Jul</td>,
#  <td class="COL1 DATE">04 Jul</td>,
#  <td class="COL1 DATE">03 Jul</td>,
#  <td class="COL1 DATE">02 Jul</td>,
#  <td class="COL1 DATE">01 Jul</td>,
#  <td class="COL1 DATE">30 Jun</td>,
#  <td class="COL1 DATE">29 Jun</td>,
#  <td class="COL1 DATE">28 Jun</td>,
#  <td class="COL1 DATE">27 Jun</td>,
#  <td class="COL1 DATE">26 Jun</td>,
#  <td class="COL1 DATE">25 Jun</td>,
#  <td class="COL1 DATE">24 Jun</td>,
#  <td class="COL1 DATE">23 Jun</td>,
#  <td class="COL1 DATE">22 Jun</td>,
#  <td class="COL1 DATE">21 Jun</td>,
#  <td class="COL1 DATE">20 Jun</td>,
#  <td class="COL1 DATE">19 Jun</td>,
#  <td class="COL1 DATE">18 Jun</td>,
#  <td class="COL1 DATE">17 Jun</td>,
#  <td class="COL1 DATE">16 Jun</td>,
#  <td class="COL1 DATE">15 Jun</td>,
#  <td class="COL1 DATE">14 Jun</td>,
#  <td class="COL1 DATE">13 Jun</td>,
#  <td class="COL1 DATE">12 Jun</td>,
#  <td class="COL1 DATE">11 Jun</td>,
#  <td class="COL1 DATE">10 Jun</td>,
#  <td class="COL1 DATE">09 Jun</td>,
#  <td class="COL1 DATE">08 Jun</td>,
#  <td class="COL1 DATE">07 Jun</td>,
#  <td class="COL1 DATE">06 Jun</td>,
#  <td class="COL1 DATE">05 Jun</td>,
#  <td class="COL1 DATE">04 Jun</td>,
#  <td class="COL1 DATE">03 Jun</td>,
#  <td class="COL1 DATE">02 Jun</td>,
#  <td class="COL1 DATE">01 Jun</td>,
#  <td class="COL1 DATE">31 May</td>,
#  <td class="COL1 DATE">30 May</td>,
#  <td class="COL1 DATE">29 May</td>,
#  <td class="COL1 DATE">28 May</td>,
#  <td class="COL1 DATE">27 May</td>,
#  <td class="COL1 DATE">26 May</td>,
#  <td class="COL1 DATE">25 May</td>,
#  <td class="COL1 DATE">24 May</td>,
#  <td class="COL1 DATE">23 May</td>,
#  <td class="COL1 DATE">22 May</td>,
#  <td class="COL1 DATE">21 May</td>,
#  <td class="COL1 DATE">20 May</td>,
#  <td class="COL1 DATE">19 May</td>,
#  <td class="COL1 DATE">18 May</td>,
#  <td class="COL1 DATE">17 May</td>,
#  <td class="COL1 DATE">16 May</td>,
#  <td class="COL1 DATE">15 May</td>,
#  <td class="COL1 DATE">14 May</td>,
#  <td class="COL1 DATE">13 May</td>,
#  <td class="COL1 DATE">12 May</td>,
#  <td class="COL1 DATE">11 May</td>,
#  <td class="COL1 DATE">10 May</td>,
#  <td class="COL1 DATE">09 May</td>,
#  <td class="COL1 DATE">08 May</td>,
#  <td class="COL1 DATE">07 May</td>,
#  <td class="COL1 DATE">06 May</td>,
#  <td class="COL1 DATE">05 May</td>,
#  <td class="COL1 DATE">04 May</td>,
#  <td class="COL1 DATE">03 May</td>,
#  <td class="COL1 DATE">02 May</td>,
#  <td class="COL1 DATE">01 May</td>,
#  <td class="COL1 DATE">30 Apr</td>,
#  <td class="COL1 DATE">29 Apr</td>,
#  <td class="COL1 DATE">28 Apr</td>,
#  <td class="COL1 DATE">27 Apr</td>,
#  <td class="COL1 DATE">26 Apr</td>,
#  <td class="COL1 DATE">25 Apr</td>,
#  <td class="COL1 DATE">24 Apr</td>,
#  <td class="COL1 DATE">23 Apr</td>,
#  <td class="COL1 DATE">22 Apr</td>,
#  <td class="COL1 DATE">21 Apr</td>,
#  <td class="COL1 DATE">20 Apr</td>,
#  <td class="COL1 DATE">19 Apr</td>,
#  <td class="COL1 DATE">18 Apr</td>,
#  <td class="COL1 DATE">17 Apr</td>,
#  <td class="COL1 DATE">16 Apr</td>,
#  <td class="COL1 DATE">15 Apr</td>,
#  <td class="COL1 DATE">14 Apr</td>,
#  <td class="COL1 DATE">31 Jan</td>,
#  <td class="COL1 DATE">30 Jan</td>,
#  <td class="COL1 DATE">29 Jan</td>,
#  <td class="COL1 DATE">28 Jan</td>,
#  <td class="COL1 DATE">27 Jan</td>,
#  <td class="COL1 DATE">26 Jan</td>,
#  <td class="COL1 DATE">25 Jan</td>,
#  <td class="COL1 DATE">24 Jan</td>,
#  <td class="COL1 DATE">23 Jan</td>,
#  <td class="COL1 DATE">22 Jan</td>,
#  <td class="COL1 DATE">21 Jan</td>,
#  <td class="COL1 DATE">20 Jan</td>,
#  <td class="COL1 DATE">19 Jan</td>,
#  <td class="COL1 DATE">18 Jan</td>,
#  <td class="COL1 DATE">17 Jan</td>,
#  <td class="COL1 DATE">16 Jan</td>,
#  <td class="COL1 DATE">15 Jan</td>,
#  <td class="COL1 DATE">14 Jan</td>,
#  <td class="COL1 DATE">13 Jan</td>,
#  <td class="COL1 DATE">12 Jan</td>,
#  <td class="COL1 DATE">11 Jan</td>,
#  <td class="COL1 DATE">10 Jan</td>,
#  <td class="COL1 DATE">09 Jan</td>,
#  <td class="COL1 DATE">08 Jan</td>,
#  <td class="COL1 DATE">07 Jan</td>,
#  <td class="COL1 DATE">06 Jan</td>,
#  <td class="COL1 DATE">05 Jan</td>,
#  <td class="COL1 DATE">04 Jan</td>,
#  <td class="COL1 DATE">03 Jan</td>,
#  <td class="COL1 DATE">02 Jan</td>,
#  <td class="COL1 DATE">01 Jan</td>]

# %% [markdown]
# To retrieve the text from each tag, `get_text` will be used on each tag

# %%
dates = [date.get_text() for date in dates_tags]
dates
# Out:
# ['31 Oct',
#  '30 Oct',
#  '29 Oct',
#  '28 Oct',
#  '27 Oct',
#  '26 Oct',
#  '25 Oct',
#  '24 Oct',
#  '23 Oct',
#  '22 Oct',
#  '21 Oct',
#  '20 Oct',
#  '19 Oct',
#  '18 Oct',
#  '17 Oct',
#  '16 Oct',
#  '15 Oct',
#  '14 Oct',
#  '13 Oct',
#  '12 Oct',
#  '11 Oct',
#  '10 Oct',
#  '09 Oct',
#  '08 Oct',
#  '07 Oct',
#  '06 Oct',
#  '05 Oct',
#  '04 Oct',
#  '03 Oct',
#  '02 Oct',
#  '01 Oct',
#  '30 Sep',
#  '29 Sep',
#  '28 Sep',
#  '27 Sep',
#  '26 Sep',
#  '25 Sep',
#  '24 Sep',
#  '23 Sep',
#  '22 Sep',
#  '21 Sep',
#  '20 Sep',
#  '19 Sep',
#  '18 Sep',
#  '17 Sep',
#  '16 Sep',
#  '15 Sep',
#  '14 Sep',
#  '13 Sep',
#  '12 Sep',
#  '11 Sep',
#  '10 Sep',
#  '09 Sep',
#  '08 Sep',
#  '07 Sep',
#  '06 Sep',
#  '05 Sep',
#  '04 Sep',
#  '03 Sep',
#  '02 Sep',
#  '01 Sep',
#  '31 Aug',
#  '30 Aug',
#  '29 Aug',
#  '28 Aug',
#  '27 Aug',
#  '26 Aug',
#  '25 Aug',
#  '24 Aug',
#  '23 Aug',
#  '22 Aug',
#  '21 Aug',
#  '20 Aug',
#  '19 Aug',
#  '18 Aug',
#  '17 Aug',
#  '16 Aug',
#  '15 Aug',
#  '14 Aug',
#  '13 Aug',
#  '12 Aug',
#  '11 Aug',
#  '10 Aug',
#  '09 Aug',
#  '08 Aug',
#  '07 Aug',
#  '06 Aug',
#  '05 Aug',
#  '04 Aug',
#  '03 Aug',
#  '02 Aug',
#  '01 Aug',
#  '31 Jul',
#  '30 Jul',
#  '29 Jul',
#  '28 Jul',
#  '27 Jul',
#  '26 Jul',
#  '25 Jul',
#  '24 Jul',
#  '23 Jul',
#  '22 Jul',
#  '21 Jul',
#  '20 Jul',
#  '19 Jul',
#  '18 Jul',
#  '17 Jul',
#  '16 Jul',
#  '15 Jul',
#  '14 Jul',
#  '13 Jul',
#  '12 Jul',
#  '11 Jul',
#  '10 Jul',
#  '09 Jul',
#  '08 Jul',
#  '07 Jul',
#  '06 Jul',
#  '05 Jul',
#  '04 Jul',
#  '03 Jul',
#  '02 Jul',
#  '01 Jul',
#  '30 Jun',
#  '29 Jun',
#  '28 Jun',
#  '27 Jun',
#  '26 Jun',
#  '25 Jun',
#  '24 Jun',
#  '23 Jun',
#  '22 Jun',
#  '21 Jun',
#  '20 Jun',
#  '19 Jun',
#  '18 Jun',
#  '17 Jun',
#  '16 Jun',
#  '15 Jun',
#  '14 Jun',
#  '13 Jun',
#  '12 Jun',
#  '11 Jun',
#  '10 Jun',
#  '09 Jun',
#  '08 Jun',
#  '07 Jun',
#  '06 Jun',
#  '05 Jun',
#  '04 Jun',
#  '03 Jun',
#  '02 Jun',
#  '01 Jun',
#  '31 May',
#  '30 May',
#  '29 May',
#  '28 May',
#  '27 May',
#  '26 May',
#  '25 May',
#  '24 May',
#  '23 May',
#  '22 May',
#  '21 May',
#  '20 May',
#  '19 May',
#  '18 May',
#  '17 May',
#  '16 May',
#  '15 May',
#  '14 May',
#  '13 May',
#  '12 May',
#  '11 May',
#  '10 May',
#  '09 May',
#  '08 May',
#  '07 May',
#  '06 May',
#  '05 May',
#  '04 May',
#  '03 May',
#  '02 May',
#  '01 May',
#  '30 Apr',
#  '29 Apr',
#  '28 Apr',
#  '27 Apr',
#  '26 Apr',
#  '25 Apr',
#  '24 Apr',
#  '23 Apr',
#  '22 Apr',
#  '21 Apr',
#  '20 Apr',
#  '19 Apr',
#  '18 Apr',
#  '17 Apr',
#  '16 Apr',
#  '15 Apr',
#  '14 Apr',
#  '31 Jan',
#  '30 Jan',
#  '29 Jan',
#  '28 Jan',
#  '27 Jan',
#  '26 Jan',
#  '25 Jan',
#  '24 Jan',
#  '23 Jan',
#  '22 Jan',
#  '21 Jan',
#  '20 Jan',
#  '19 Jan',
#  '18 Jan',
#  '17 Jan',
#  '16 Jan',
#  '15 Jan',
#  '14 Jan',
#  '13 Jan',
#  '12 Jan',
#  '11 Jan',
#  '10 Jan',
#  '09 Jan',
#  '08 Jan',
#  '07 Jan',
#  '06 Jan',
#  '05 Jan',
#  '04 Jan',
#  '03 Jan',
#  '02 Jan',
#  '01 Jan']

# %%
cases_tags = bsObj.find_all("td", "COL4 CASES")
cases = [case.get_text() for case in cases_tags]
cases
# Out:
# ['1,658',
#  '1,641',
#  '1,629',
#  '1,599',
#  '1,571',
#  '1,550',
#  '1,541',
#  '1,519',
#  '1,494',
#  '1,469',
#  '1,437',
#  '1,401',
#  '1,379',
#  '1,336',
#  '1,311',
#  '1,292',
#  '1,269',
#  '1,214',
#  '1,169',
#  '1,147',
#  '1,118',
#  '1,087',
#  '1,043',
#  '996',
#  '966',
#  '942',
#  '921',
#  '873',
#  '851',
#  '825',
#  '796',
#  '788',
#  '766',
#  '744',
#  '726',
#  '714',
#  '704',
#  '702',
#  '697',
#  '692',
#  '687',
#  '683',
#  '683',
#  '681',
#  '677',
#  '674',
#  '673',
#  '670',
#  '665',
#  '658',
#  '653',
#  '648',
#  '645',
#  '641',
#  '638',
#  '638',
#  '633',
#  '632',
#  '628',
#  '625',
#  '616',
#  '612',
#  '610',
#  '611',
#  '608',
#  '607',
#  '602',
#  '601',
#  '600',
#  '599',
#  '597',
#  '597',
#  '595',
#  '595',
#  '594',
#  '595',
#  '595',
#  '595',
#  '594',
#  '595',
#  '595',
#  '597',
#  '598',
#  '599',
#  '599',
#  '596',
#  '594',
#  '592',
#  '589',
#  '589',
#  '589',
#  '589',
#  '588',
#  '588',
#  '588',
#  '589',
#  '589',
#  '589',
#  '589',
#  '589',
#  '588',
#  '590',
#  '590',
#  '590',
#  '590',
#  '590',
#  '590',
#  '590',
#  '586',
#  '587',
#  '587',
#  '587',
#  '586',
#  '587',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '588',
#  '589',
#  '591',
#  '590',
#  '590',
#  '590',
#  '588',
#  '589',
#  '587',
#  '586',
#  '590',
#  '586',
#  '586',
#  '586',
#  '584',
#  '585',
#  '583',
#  '585',
#  '584',
#  '581',
#  '581',
#  '581',
#  '582',
#  '582',
#  '581',
#  '582',
#  '581',
#  '581',
#  '580',
#  '580',
#  '580',
#  '580',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '579',
#  '581',
#  '580',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '581',
#  '582',
#  '582',
#  '583',
#  '583',
#  '583',
#  '583',
#  '582',
#  '582',
#  '582',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '596',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598',
#  '598']

# %% [markdown]
# The string case numbers will be converted to integers

# %%
numbers = [int(num.replace(",", "")) for num in cases]
numbers
# Out:
# [1658,
#  1641,
#  1629,
#  1599,
#  1571,
#  1550,
#  1541,
#  1519,
#  1494,
#  1469,
#  1437,
#  1401,
#  1379,
#  1336,
#  1311,
#  1292,
#  1269,
#  1214,
#  1169,
#  1147,
#  1118,
#  1087,
#  1043,
#  996,
#  966,
#  942,
#  921,
#  873,
#  851,
#  825,
#  796,
#  788,
#  766,
#  744,
#  726,
#  714,
#  704,
#  702,
#  697,
#  692,
#  687,
#  683,
#  683,
#  681,
#  677,
#  674,
#  673,
#  670,
#  665,
#  658,
#  653,
#  648,
#  645,
#  641,
#  638,
#  638,
#  633,
#  632,
#  628,
#  625,
#  616,
#  612,
#  610,
#  611,
#  608,
#  607,
#  602,
#  601,
#  600,
#  599,
#  597,
#  597,
#  595,
#  595,
#  594,
#  595,
#  595,
#  595,
#  594,
#  595,
#  595,
#  597,
#  598,
#  599,
#  599,
#  596,
#  594,
#  592,
#  589,
#  589,
#  589,
#  589,
#  588,
#  588,
#  588,
#  589,
#  589,
#  589,
#  589,
#  589,
#  588,
#  590,
#  590,
#  590,
#  590,
#  590,
#  590,
#  590,
#  586,
#  587,
#  587,
#  587,
#  586,
#  587,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  588,
#  589,
#  591,
#  590,
#  590,
#  590,
#  588,
#  589,
#  587,
#  586,
#  590,
#  586,
#  586,
#  586,
#  584,
#  585,
#  583,
#  585,
#  584,
#  581,
#  581,
#  581,
#  582,
#  582,
#  581,
#  582,
#  581,
#  581,
#  580,
#  580,
#  580,
#  580,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  579,
#  581,
#  580,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  581,
#  582,
#  582,
#  583,
#  583,
#  583,
#  583,
#  582,
#  582,
#  582,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  596,
#  598,
#  598,
#  598,
#  598,
#  598,
#  598,
#  598,
#  598,
#  598,
#  598,
#  598,
#  598]

# %% [markdown]
# The dates and case numbers will be placed in a dataframe, the case numbers for the required dates will then be retrieved

# %%
df = pd.DataFrame({"dates": dates, "cases": numbers})
    
sep_30 = df.loc[df["dates"] == "30 Sep", "cases"].values[0]
sep_29 = df.loc[df["dates"] == "29 Sep", "cases"].values[0]
sep_16 = df.loc[df["dates"] == "16 Sep", "cases"].values[0]
aug_31 = df.loc[df["dates"] == "31 Aug", "cases"].values[0]
aug_01 = df.loc[df["dates"] == "01 Aug", "cases"].values[0]

print("Sep 30:", sep_30)
print("Sep 29:", sep_29)
print("Sep 16:", sep_16)
print("Aug 31:", aug_31)
print("Aug 01:", aug_01)
# Out:
# Sep 30: 788
# Sep 29: 766
# Sep 16: 674
# Aug 31: 612
# Aug 01: 589

# %% [markdown]
# The average case numbers per period can now be calculated

# %%
print("Sep 30 cases:        ", sep_30 - sep_29)
print("14 days average cases:", round((sep_29 - sep_16) / 14))
print("30 days average cases:", round((sep_29 - aug_31) / 30))
print("60 days average cases:", round((sep_29 - aug_01) / 60))
# Out:
# Sep 30 cases:         22
# 14 days average cases: 7
# 30 days average cases: 5
# 60 days average cases: 3

# %% [markdown]
# The process described above will be implemented on all the LGA's. The results will be stored in a dictionary `cases_dict`

# %%
cases_dict = {}

for lga in prop_df["lga"].unique():
    # replace space in name with "-"
    if " " in lga:
        lga_clean = lga.replace(" ", "-")
    
    else:
        lga_clean = lga
        
    html = urlopen("https://covidlive.com.au/vic/" + lga_clean.lower())
    bsObj = BeautifulSoup(html, "html.parser")
    
    dates_tags = bsObj.find_all("td", "COL1 DATE")
    dates = [date.get_text() for date in dates_tags]
    
    cases_tags = bsObj.find_all("td", "COL4 CASES")
    cases = [case.get_text() for case in cases_tags]
    numbers = [int(num.replace(",", "")) for num in cases]
    
    if len(dates) > 0 and len(numbers) > 0:
        df = pd.DataFrame({"dates": dates, "cases": numbers})
    
        sep_30 = df.loc[df["dates"] == "30 Sep", "cases"].values[0]
        sep_29 = df.loc[df["dates"] == "29 Sep", "cases"].values[0]
        sep_16 = df.loc[df["dates"] == "16 Sep", "cases"].values[0]
        aug_31 = df.loc[df["dates"] == "31 Aug", "cases"].values[0]
        aug_01 = df.loc[df["dates"] == "01 Aug", "cases"].values[0]
    
        cases_dict[lga] = {"sep_30_cases": sep_30 - sep_29, "fortnight_avg": round((sep_29 - sep_16) / 14),
                          "month_avg": round((sep_29 - aug_31) / 30), "two_month_avg": round((sep_29 - aug_01) / 60)}
        
cases_dict
# Out:
# {'MITCHELL': {'sep_30_cases': 14,
#   'fortnight_avg': 5,
#   'month_avg': 3,
#   'two_month_avg': 1},
#  'CASEY': {'sep_30_cases': 69,
#   'fortnight_avg': 22,
#   'month_avg': 14,
#   'two_month_avg': 7},
#  'WANGARATTA': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'HORSHAM': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'FRANKSTON': {'sep_30_cases': 3,
#   'fortnight_avg': 3,
#   'month_avg': 2,
#   'two_month_avg': 1},
#  'BASS COAST': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'STRATHBOGIE': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'STONNINGTON': {'sep_30_cases': 19,
#   'fortnight_avg': 4,
#   'month_avg': 3,
#   'two_month_avg': 1},
#  'MOIRA': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'YARRA RANGES': {'sep_30_cases': 5,
#   'fortnight_avg': 3,
#   'month_avg': 2,
#   'two_month_avg': 1},
#  'PORT PHILLIP': {'sep_30_cases': 25,
#   'fortnight_avg': 8,
#   'month_avg': 5,
#   'two_month_avg': 3},
#  'SOUTH GIPPSLAND': {'sep_30_cases': 2,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'WYNDHAM': {'sep_30_cases': 99,
#   'fortnight_avg': 43,
#   'month_avg': 33,
#   'two_month_avg': 20},
#  'HUME': {'sep_30_cases': 332,
#   'fortnight_avg': 214,
#   'month_avg': 155,
#   'two_month_avg': 80},
#  'KINGSTON': {'sep_30_cases': 13,
#   'fortnight_avg': 4,
#   'month_avg': 2,
#   'two_month_avg': 1},
#  'MARIBYRNONG': {'sep_30_cases': 22,
#   'fortnight_avg': 7,
#   'month_avg': 5,
#   'two_month_avg': 3},
#  'MOYNE': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MACEDON RANGES': {'sep_30_cases': 1,
#   'fortnight_avg': 1,
#   'month_avg': 1,
#   'two_month_avg': 0},
#  'MANSFIELD': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MANNINGHAM': {'sep_30_cases': 11,
#   'fortnight_avg': 6,
#   'month_avg': 4,
#   'two_month_avg': 2},
#  'KNOX': {'sep_30_cases': 23,
#   'fortnight_avg': 5,
#   'month_avg': 3,
#   'two_month_avg': 2},
#  'WODONGA': {'sep_30_cases': 3,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'EAST GIPPSLAND': {'sep_30_cases': 1,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'BOROONDARA': {'sep_30_cases': 12,
#   'fortnight_avg': 3,
#   'month_avg': 2,
#   'two_month_avg': 1},
#  'WEST WIMMERA': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MELTON': {'sep_30_cases': 87,
#   'fortnight_avg': 28,
#   'month_avg': 19,
#   'two_month_avg': 10},
#  'WELLINGTON': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'HEPBURN': {'sep_30_cases': -1,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'GREATER DANDENONG': {'sep_30_cases': 36,
#   'fortnight_avg': 9,
#   'month_avg': 6,
#   'two_month_avg': 3},
#  'YARRA': {'sep_30_cases': 15,
#   'fortnight_avg': 7,
#   'month_avg': 5,
#   'two_month_avg': 3},
#  'DAREBIN': {'sep_30_cases': 41,
#   'fortnight_avg': 21,
#   'month_avg': 15,
#   'two_month_avg': 8},
#  'GLEN EIRA': {'sep_30_cases': 15,
#   'fortnight_avg': 4,
#   'month_avg': 2,
#   'two_month_avg': 1},
#  'WHITEHORSE': {'sep_30_cases': 12,
#   'fortnight_avg': 1,
#   'month_avg': 1,
#   'two_month_avg': 1},
#  'HOBSONS BAY': {'sep_30_cases': 20,
#   'fortnight_avg': 14,
#   'month_avg': 15,
#   'two_month_avg': 10},
#  'SOUTHERN GRAMPIANS': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'CENTRAL GOLDFIELDS': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'BULOKE': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'BAW BAW': {'sep_30_cases': 3,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'SWAN HILL': {'sep_30_cases': 1,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MONASH': {'sep_30_cases': 16,
#   'fortnight_avg': 4,
#   'month_avg': 3,
#   'two_month_avg': 2},
#  'MURRINDINDI': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'HINDMARSH': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MELBOURNE': {'sep_30_cases': 23,
#   'fortnight_avg': 11,
#   'month_avg': 8,
#   'two_month_avg': 5},
#  'BANYULE': {'sep_30_cases': 22,
#   'fortnight_avg': 12,
#   'month_avg': 7,
#   'two_month_avg': 4},
#  'TOWONG': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'BRIMBANK': {'sep_30_cases': 77,
#   'fortnight_avg': 34,
#   'month_avg': 21,
#   'two_month_avg': 12},
#  'CARDINIA': {'sep_30_cases': 25,
#   'fortnight_avg': 10,
#   'month_avg': 5,
#   'two_month_avg': 3},
#  'MORELAND': {'sep_30_cases': 111,
#   'fortnight_avg': 50,
#   'month_avg': 47,
#   'two_month_avg': 25},
#  'ALPINE': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MOUNT ALEXANDER': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MOONEE VALLEY': {'sep_30_cases': 41,
#   'fortnight_avg': 17,
#   'month_avg': 12,
#   'two_month_avg': 6},
#  'LATROBE': {'sep_30_cases': 2,
#   'fortnight_avg': 2,
#   'month_avg': 1,
#   'two_month_avg': 0},
#  'LODDON': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MOORABOOL': {'sep_30_cases': 7,
#   'fortnight_avg': 2,
#   'month_avg': 1,
#   'two_month_avg': 0},
#  'ARARAT': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'MAROONDAH': {'sep_30_cases': 23,
#   'fortnight_avg': 3,
#   'month_avg': 2,
#   'two_month_avg': 1},
#  'NILLUMBIK': {'sep_30_cases': 4,
#   'fortnight_avg': 1,
#   'month_avg': 1,
#   'two_month_avg': 1},
#  'WHITTLESEA': {'sep_30_cases': 152,
#   'fortnight_avg': 69,
#   'month_avg': 45,
#   'two_month_avg': 23},
#  'INDIGO': {'sep_30_cases': -1,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'GREATER GEELONG': {'sep_30_cases': 1,
#   'fortnight_avg': 2,
#   'month_avg': 2,
#   'two_month_avg': 1},
#  'YARRIAMBIACK': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'GREATER BENDIGO': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'PYRENEES': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'CAMPASPE': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'BENALLA': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'SURF COAST': {'sep_30_cases': 1,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'BALLARAT': {'sep_30_cases': 2,
#   'fortnight_avg': 1,
#   'month_avg': 1,
#   'two_month_avg': 0},
#  'COLAC-OTWAY': {'sep_30_cases': 1,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'QUEENSCLIFFE': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'GREATER SHEPPARTON': {'sep_30_cases': 5,
#   'fortnight_avg': 0,
#   'month_avg': 1,
#   'two_month_avg': 2},
#  'MILDURA': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'GOLDEN PLAINS': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0},
#  'GLENELG': {'sep_30_cases': 0,
#   'fortnight_avg': 0,
#   'month_avg': 0,
#   'two_month_avg': 0}}

# %% [markdown]
# For each COVID column, the value will be arrived at by applying a lambda function which retrieves the cases of the required period corresponding to the LGA in `cases_dict`, if the `lga` is not "not available"

# %%
prop_df["30_sep_cases"] = prop_df["lga"].apply(lambda x: cases_dict[x]["sep_30_cases"] if x != "not available" else "not available")
prop_df["last_14_days_cases"] = prop_df["lga"].apply(lambda x: cases_dict[x]["fortnight_avg"] if x != "not available" else "not available")
prop_df["last_30_days_cases"] = prop_df["lga"].apply(lambda x: cases_dict[x]["month_avg"] if x != "not available" else "not available")
prop_df["last_60_days_cases"] = prop_df["lga"].apply(lambda x: cases_dict[x]["two_month_avg"] if x != "not available" else "not available")
prop_df.head()
# Out:
#   property_id        lat         lng          addr_street      suburb  \
# 0        2645 -37.815113  144.891492   10 Goulburn Street  YARRAVILLE
# 1       51985 -37.799076  145.174236      7 Belmont Court     DONVALE
# 2       76137 -37.909505  145.094192     38 Andrew Street    OAKLEIGH
# 3       96049 -37.912178  145.051455  6 Shanahan Crescent    MCKINNON
# 4       47173 -37.719559  145.160461  40 Malabar Crescent      ELTHAM
#
#           lga  closest_train_station_id  distance_to_closest_train_station  \
# 0    MITCHELL                     19996                              0.160
# 1       CASEY                     19899                              2.394
# 2  WANGARATTA                     19916                              0.736
# 3     HORSHAM                     19940                              1.173
# 4   FRANKSTON                     19987                              1.297
#
#   travel_min_to_MC  direct_journey_flag 30_sep_cases last_14_days_cases  \
# 0    not available                    0           14                  5
# 1               28                    1           69                 22
# 2               27                    1            0                  0
# 3               28                    1            0                  0
# 4               52                    1            3                  3
#
#   last_30_days_cases last_60_days_cases
# 0                  3                  1
# 1                 14                  7
# 2                  0                  0
# 3                  0                  0
# 4                  2                  1

# %% [markdown]
# The property dataframe `prop_df` is now complete

# %%
# save prop_df as csv
#prop_df.to_csv("solution.csv", index = False)

# %% [markdown]
# ## 4. Data Reshaping
#
# In this section, the effect of different normalisation and transformation techniques on the COVID columns generated above will be examined, assuming that we want to develop a linear model to predict the `30_sep_cases` using `last_14_days_cases`, `last_30_days_cases`, and `last_60_days_cases` attributes. There are two aims: the first is that we want out features to be on the same scale and second, we want our features to have as much linear relationship as possible with the predicted variable (i.e., `30_sep_cases`). Furthermore, we will create and assess linear models along the way to ascertain if normalisation/transformation is required and if so, what type? This will be done by exploring the model diagnositcs. It is important to note that in this task all the explanatory variables will be used, in other words none of the variables will be removed in an attempt to enhance the linear model.
#
# ## 4.1 Data Cleaning and Exploration
#
# The data will be filtered to only contain the columns necessary. Furthermore, the data will undergo several cleaning steps to arrive at our final dataframe; these include removing rows with no COVID case figures availabe, removing duplicate `lga`s since each `lga` will have the same number of cases when the same `lga` is repeated in the dataframe, and removing rows where all the values are zero since they add no value to our analysis and might affect the models to be built

# %%
# select necessary columns
covid = prop_df.iloc[:, [5, 10, 11, 12, 13]].copy()
# remove rows with "not available"
covid = covid[covid["30_sep_cases"] != "not available"]
# drop duplicate LGA's
covid.drop_duplicates("lga", inplace = True)
covid.drop(columns = "lga", inplace = True)
# adjust type
covid = covid.astype("int64")
# drop rows with all zeros
covid = covid.loc[(covid!=0).any(axis=1)]
# reset index
covid.reset_index(drop = True, inplace = True)

covid.head()
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases
# 0            14                   5                   3                   1
# 1            69                  22                  14                   7
# 2             3                   3                   2                   1
# 3            19                   4                   3                   1
# 4             5                   3                   2                   1

# %%
covid.describe()
# Out:
#        30_sep_cases  last_14_days_cases  last_30_days_cases  \
# count      45.00000           45.000000           45.000000
# mean       31.00000           14.000000           10.088889
# std        56.67491           33.792818           24.631671
# min        -1.00000            0.000000            0.000000
# 25%         3.00000            1.000000            1.000000
# 50%        14.00000            4.000000            2.000000
# 75%        25.00000           11.000000            7.000000
# max       332.00000          214.000000          155.000000
#
#        last_60_days_cases
# count           45.000000
# mean             5.422222
# std             12.824850
# min              0.000000
# 25%              0.000000
# 50%              1.000000
# 75%              4.000000
# max             80.000000

# %% [markdown]
# We have 45 total observations. A histogram and a boxplot for each variable will be plotted to see the distribution of the data

# %%
covid.hist()
# Out:
# array([[<AxesSubplot:title={'center':'30_sep_cases'}>,
#         <AxesSubplot:title={'center':'last_14_days_cases'}>],
#        [<AxesSubplot:title={'center':'last_30_days_cases'}>,
#         <AxesSubplot:title={'center':'last_60_days_cases'}>]],
#       dtype=object)

# %%
covid.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see there is an outlier in each each variable. Let's pull out the outlier

# %%
covid[(covid["30_sep_cases"] > 200) & (covid["last_14_days_cases"] > 100) & (covid["last_30_days_cases"] > 100) & (covid["last_60_days_cases"] > 50)]
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases
# 8           332                 214                 155                  80

# %% [markdown]
# We will plot scatter plots of the `30_sep_cases` against each independent variable

# %%
covid.plot(x = "last_14_days_cases", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_14_days_cases', ylabel='30_sep_cases'>

# %%
covid.plot(x = "last_30_days_cases", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_30_days_cases', ylabel='30_sep_cases'>

# %%
covid.plot(x = "last_60_days_cases", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_60_days_cases', ylabel='30_sep_cases'>

# %% [markdown]
# We can see that for each plot, the outlier identified above creates a large gap in our plots, which nullifies our assumption of linearity since any possible shape can be present in the gap if more data is availabe. Therefore, it is clear that standardisation/normalistion is necessary.

# %% [markdown]
# ## 4.2 Initial Model
#
# To determine the best standardisation/transformation to apply, an initial linear model will be built using the variables as they are with no alterations, future models will then be compared against this model to determine improvements. The linear model will be built using the `sklearn` library. First we will examine the correlation between the variables

# %%
covid.corr()
# Out:
#                     30_sep_cases  last_14_days_cases  last_30_days_cases  \
# 30_sep_cases            1.000000            0.978343            0.973221
# last_14_days_cases      0.978343            1.000000            0.996247
# last_30_days_cases      0.973221            0.996247            1.000000
# last_60_days_cases      0.972475            0.993337            0.998620
#
#                     last_60_days_cases
# 30_sep_cases                  0.972475
# last_14_days_cases            0.993337
# last_30_days_cases            0.998620
# last_60_days_cases            1.000000

# %% [markdown]
# As expected there is very high correlation between the variables, since the figures for the longer time periods have the smaller time periods built into them. We can further explore the multicollinearity between the explanatory variables by calculating the variance inflation factor (VIF) of each variable [(source)](https://www.datasciencemadesimple.com/difference-two-timestamps-seconds-minutes-hours-pandas-python-2/). As a rule of thumb, a VIF greater than 5 is considered high and indicates multicollinearity. The VIF will be calculated using the `variance_inflation_factor` function from the `statsmodels` package

# %%
# build function to calculate VIF
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
# calculate VIF of covid dataframe explanatory variables
calc_vif(covid.iloc[:,1:])
# Out:
#             variables         VIF
# 0  last_14_days_cases  173.012009
# 1  last_30_days_cases  792.714928
# 2  last_60_days_cases  448.168733

# %% [markdown]
# As expected, the variables have very high VIF values since the variables are very related to each other.
#
# Finally, we will run the linear regression model on our unedited variables

# %%
# train, test split
X_train, X_test, y_train, y_test = train_test_split(covid.iloc[:,1:],covid.iloc[:,:1], random_state = 111)

# %%
# initialize model
lm = LinearRegression()
# fit the linear model using the training data
lm.fit(X_train, y_train)
# r-squared
print ('r-squared for this model = ', lm.score(X_test,y_test))
# Out:
# r-squared for this model =  0.7901212586313029

# %% [markdown]
# Various normalisation and transformation techniques will be now be examined and compared to the original plots, figures, and model.
#
# ### 4.3 Normalisation
#
# We will now explore whether the data should be normalised to give more accurate results
#
# #### 4.3.1 Standardization
#
# The first normalisation method to be trialled is standardisation where the values for each explanatory variable will be rescaled to have mean 0 and standard deviation 1, this will be done using the `StandardScaler` function from the `sklearn` package

# %%
# fit the standardisation
std_scale = preprocessing.StandardScaler().fit(covid[['last_14_days_cases', 'last_30_days_cases', 'last_60_days_cases']])
# transfrom the explanatory variables into the standardised values
covid_std = std_scale.transform(covid[['last_14_days_cases', 'last_30_days_cases', 'last_60_days_cases']])

covid_std[0:5]
# Out:
# array([[-0.26933824, -0.29104773, -0.34871305],
#        [ 0.23941177,  0.16057806,  0.12441521],
#        [-0.32919118, -0.33210462, -0.34871305],
#        [-0.29926471, -0.29104773, -0.34871305],
#        [-0.32919118, -0.33210462, -0.34871305]])

# %% [markdown]
# The standardised values will be added to the `covid` dataframe

# %%
covid['last_14_days_cases_std'] = covid_std[:,0]
covid['last_30_days_cases_std'] = covid_std[:,1]
covid['last_60_days_cases_std'] = covid_std[:,2]
covid.head()
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases  \
# 0            14                   5                   3                   1
# 1            69                  22                  14                   7
# 2             3                   3                   2                   1
# 3            19                   4                   3                   1
# 4             5                   3                   2                   1
#
#    last_14_days_cases_std  last_30_days_cases_std  last_60_days_cases_std
# 0               -0.269338               -0.291048               -0.348713
# 1                0.239412                0.160578                0.124415
# 2               -0.329191               -0.332105               -0.348713
# 3               -0.299265               -0.291048               -0.348713
# 4               -0.329191               -0.332105               -0.348713

# %%
covid.describe()
# Out:
#        30_sep_cases  last_14_days_cases  last_30_days_cases  \
# count      45.00000           45.000000           45.000000
# mean       31.00000           14.000000           10.088889
# std        56.67491           33.792818           24.631671
# min        -1.00000            0.000000            0.000000
# 25%         3.00000            1.000000            1.000000
# 50%        14.00000            4.000000            2.000000
# 75%        25.00000           11.000000            7.000000
# max       332.00000          214.000000          155.000000
#
#        last_60_days_cases  last_14_days_cases_std  last_30_days_cases_std  \
# count           45.000000            4.500000e+01            4.500000e+01
# mean             5.422222           -9.868649e-18            8.635068e-18
# std             12.824850            1.011300e+00            1.011300e+00
# min              0.000000           -4.189706e-01           -4.142184e-01
# 25%              0.000000           -3.890441e-01           -3.731615e-01
# 50%              1.000000           -2.992647e-01           -3.321046e-01
# 75%              4.000000           -8.977941e-02           -1.268202e-01
# max             80.000000            5.985294e+00            5.949600e+00
#
#        last_60_days_cases_std
# count            4.500000e+01
# mean            -4.934325e-18
# std              1.011300e+00
# min             -4.275678e-01
# 25%             -4.275678e-01
# 50%             -3.487130e-01
# 75%             -1.121489e-01
# max              5.880809e+00

# %% [markdown]
# We observe that mean and standard deviation for the standardised variables are approximately 0 and 1, respectively.
#
# We will plot the scatter plots , calculate the correlation coefficients and the VIF using the standardised variables

# %%
covid.plot(x = "last_14_days_cases_std", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_14_days_cases_std', ylabel='30_sep_cases'>

# %%
covid.plot(x = "last_30_days_cases_std", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_30_days_cases_std', ylabel='30_sep_cases'>

# %%
covid.plot(x = "last_60_days_cases_std", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_60_days_cases_std', ylabel='30_sep_cases'>

# %%
covid.corr()
# Out:
#                         30_sep_cases  last_14_days_cases  last_30_days_cases  \
# 30_sep_cases                1.000000            0.978343            0.973221
# last_14_days_cases          0.978343            1.000000            0.996247
# last_30_days_cases          0.973221            0.996247            1.000000
# last_60_days_cases          0.972475            0.993337            0.998620
# last_14_days_cases_std      0.978343            1.000000            0.996247
# last_30_days_cases_std      0.973221            0.996247            1.000000
# last_60_days_cases_std      0.972475            0.993337            0.998620
#
#                         last_60_days_cases  last_14_days_cases_std  \
# 30_sep_cases                      0.972475                0.978343
# last_14_days_cases                0.993337                1.000000
# last_30_days_cases                0.998620                0.996247
# last_60_days_cases                1.000000                0.993337
# last_14_days_cases_std            0.993337                1.000000
# last_30_days_cases_std            0.998620                0.996247
# last_60_days_cases_std            1.000000                0.993337
#
#                         last_30_days_cases_std  last_60_days_cases_std
# 30_sep_cases                          0.973221                0.972475
# last_14_days_cases                    0.996247                0.993337
# last_30_days_cases                    1.000000                0.998620
# last_60_days_cases                    0.998620                1.000000
# last_14_days_cases_std                0.996247                0.993337
# last_30_days_cases_std                1.000000                0.998620
# last_60_days_cases_std                0.998620                1.000000

# %%
# calculate VIF of covid dataframe explanatory variables
calc_vif(covid.iloc[:,4:])
# Out:
#                 variables         VIF
# 0  last_14_days_cases_std  150.708764
# 1  last_30_days_cases_std  725.915049
# 2  last_60_days_cases_std  409.410558

# %% [markdown]
# We can see that the standardisation did not alter any of the plots, correlation coefficients, or VIF values.
#
# Finally, we will run a linear regression using the standardised variables as explanatory variables

# %%
# train, test split
X_train, X_test, y_train, y_test = train_test_split(covid.iloc[:,4:],covid.iloc[:,:1], random_state = 111)

# %%
# initialize model
lm = LinearRegression()
# fit the linear model using the training data
lm.fit(X_train, y_train)
# r-squared
print ('r-squared for this model = ', lm.score(X_test,y_test))
# Out:
# r-squared for this model =  0.790121258631303

# %% [markdown]
# We can observe that standardisation does not have any effect and the r-squared is the same as the original model.
#
# Therefore we can conclude that the variables should not be standardised. The standardised variables will now be dropped

# %%
covid.drop(columns = ['last_14_days_cases_std', 'last_30_days_cases_std', 'last_60_days_cases_std'], inplace = True)

# %% [markdown]
# #### 4.3.2 Minmax Normalisation
#
# The second normalisation technique to be trialled is the Minmax technique where the values of the variables will be normalised to be in the range 0 to 1, this will be done using the `MinMaxScaler` function from the `sklearn` package

# %%
# fit the minmax normalisation
minmax_scale = preprocessing.MinMaxScaler().fit(covid[['last_14_days_cases', 'last_30_days_cases', 'last_60_days_cases']])
# transfrom the explanatory variables into the normalised values
covid_minmax = minmax_scale.transform(covid[['last_14_days_cases', 'last_30_days_cases', 'last_60_days_cases']])
covid_minmax[0:5]
# Out:
# array([[0.02336449, 0.01935484, 0.0125    ],
#        [0.10280374, 0.09032258, 0.0875    ],
#        [0.01401869, 0.01290323, 0.0125    ],
#        [0.01869159, 0.01935484, 0.0125    ],
#        [0.01401869, 0.01290323, 0.0125    ]])

# %% [markdown]
# The normalised values will be added to the `covid` dataframe

# %%
covid['last_14_days_cases_nrm'] = covid_minmax[:,0]
covid['last_30_days_cases_nrm'] = covid_minmax[:,1]
covid['last_60_days_cases_nrm'] = covid_minmax[:,2]
covid.head()
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases  \
# 0            14                   5                   3                   1
# 1            69                  22                  14                   7
# 2             3                   3                   2                   1
# 3            19                   4                   3                   1
# 4             5                   3                   2                   1
#
#    last_14_days_cases_nrm  last_30_days_cases_nrm  last_60_days_cases_nrm
# 0                0.023364                0.019355                  0.0125
# 1                0.102804                0.090323                  0.0875
# 2                0.014019                0.012903                  0.0125
# 3                0.018692                0.019355                  0.0125
# 4                0.014019                0.012903                  0.0125

# %%
covid.describe()
# Out:
#        30_sep_cases  last_14_days_cases  last_30_days_cases  \
# count      45.00000           45.000000           45.000000
# mean       31.00000           14.000000           10.088889
# std        56.67491           33.792818           24.631671
# min        -1.00000            0.000000            0.000000
# 25%         3.00000            1.000000            1.000000
# 50%        14.00000            4.000000            2.000000
# 75%        25.00000           11.000000            7.000000
# max       332.00000          214.000000          155.000000
#
#        last_60_days_cases  last_14_days_cases_nrm  last_30_days_cases_nrm  \
# count           45.000000               45.000000               45.000000
# mean             5.422222                0.065421                0.065090
# std             12.824850                0.157910                0.158914
# min              0.000000                0.000000                0.000000
# 25%              0.000000                0.004673                0.006452
# 50%              1.000000                0.018692                0.012903
# 75%              4.000000                0.051402                0.045161
# max             80.000000                1.000000                1.000000
#
#        last_60_days_cases_nrm
# count               45.000000
# mean                 0.067778
# std                  0.160311
# min                  0.000000
# 25%                  0.000000
# 50%                  0.012500
# 75%                  0.050000
# max                  1.000000

# %% [markdown]
# We observe that minimum and maximum for the normalised variables are 0 and 1, respectively.
#
# We will plot the scatter plots , calculate the correlation coefficients and the VIF using the standardised variables

# %%
covid.plot(x = "last_14_days_cases_nrm", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_14_days_cases_nrm', ylabel='30_sep_cases'>

# %%
covid.plot(x = "last_30_days_cases_nrm", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_30_days_cases_nrm', ylabel='30_sep_cases'>

# %%
covid.plot(x = "last_60_days_cases_nrm", y = "30_sep_cases", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_60_days_cases_nrm', ylabel='30_sep_cases'>

# %%
covid.corr()
# Out:
#                         30_sep_cases  last_14_days_cases  last_30_days_cases  \
# 30_sep_cases                1.000000            0.978343            0.973221
# last_14_days_cases          0.978343            1.000000            0.996247
# last_30_days_cases          0.973221            0.996247            1.000000
# last_60_days_cases          0.972475            0.993337            0.998620
# last_14_days_cases_nrm      0.978343            1.000000            0.996247
# last_30_days_cases_nrm      0.973221            0.996247            1.000000
# last_60_days_cases_nrm      0.972475            0.993337            0.998620
#
#                         last_60_days_cases  last_14_days_cases_nrm  \
# 30_sep_cases                      0.972475                0.978343
# last_14_days_cases                0.993337                1.000000
# last_30_days_cases                0.998620                0.996247
# last_60_days_cases                1.000000                0.993337
# last_14_days_cases_nrm            0.993337                1.000000
# last_30_days_cases_nrm            0.998620                0.996247
# last_60_days_cases_nrm            1.000000                0.993337
#
#                         last_30_days_cases_nrm  last_60_days_cases_nrm
# 30_sep_cases                          0.973221                0.972475
# last_14_days_cases                    0.996247                0.993337
# last_30_days_cases                    1.000000                0.998620
# last_60_days_cases                    0.998620                1.000000
# last_14_days_cases_nrm                0.996247                0.993337
# last_30_days_cases_nrm                1.000000                0.998620
# last_60_days_cases_nrm                0.998620                1.000000

# %%
# calculate VIF of covid dataframe explanatory variables
calc_vif(covid.iloc[:,4:])
# Out:
#                 variables         VIF
# 0  last_14_days_cases_nrm  173.012009
# 1  last_30_days_cases_nrm  792.714928
# 2  last_60_days_cases_nrm  448.168733

# %% [markdown]
# We can see that the normalisation did not alter any of the plots, correlation coefficients, or VIF values.
#
# Finally, we will run a linear regression using the normalised variables as explanatory variables

# %%
# train, test split
X_train, X_test, y_train, y_test = train_test_split(covid.iloc[:,4:],covid.iloc[:,:1], random_state = 111)

# %%
# initialize model
lm = LinearRegression()
# fit the linear model using the training data
lm.fit(X_train, y_train)
# r-squared
print ('r-squared for this model = ', lm.score(X_test,y_test))
# Out:
# r-squared for this model =  0.790121258631303

# %% [markdown]
# We can observe that normalisation does not have any effect and the r-squared is the same as the original model.
#
# Therefore we can conclude that the variables should not be normalised at all. This is due to the fact that the explanatory variables are all on the same scale already, namely they are all measurements of days.

# %%
# drop the normalised variables
covid.drop(columns = ['last_14_days_cases_nrm', 'last_30_days_cases_nrm', 'last_60_days_cases_nrm'], inplace = True)

# %% [markdown]
# ### 4.4 Transformation
#
# The effect of transformation on the explanatory variables will now be examined
#
# #### 4.4.1 Root Transformation
#
# For this transformation, each of the variables will be recalculated to its square root. We will first alter any negative values to 0

# %%
covid_root = covid.copy()
covid_root.loc[covid["30_sep_cases"] < 1, "30_sep_cases"] = 0

# %%
# generate square root columns

covid_root['30_sep_cases_sqrt'] = None
i = 0
for row in covid_root.iterrows():
    covid_root['30_sep_cases_sqrt'].at[i] = math.sqrt(covid_root["30_sep_cases"][i])
    i += 1

covid_root['last_14_days_cases_sqrt'] = None
i = 0
for row in covid_root.iterrows():
    covid_root['last_14_days_cases_sqrt'].at[i] = math.sqrt(covid_root["last_14_days_cases"][i])
    i += 1
    
covid_root['last_30_days_cases_sqrt'] = None
i = 0
for row in covid_root.iterrows():
    covid_root['last_30_days_cases_sqrt'].at[i] = math.sqrt(covid_root["last_30_days_cases"][i])
    i += 1

covid_root['last_60_days_cases_sqrt'] = None
i = 0
for row in covid_root.iterrows():
    covid_root['last_60_days_cases_sqrt'].at[i] = math.sqrt(covid_root["last_60_days_cases"][i])
    i += 1

covid_root = covid_root.astype({"30_sep_cases_sqrt": "float", "last_14_days_cases_sqrt": "float", "last_30_days_cases_sqrt": "float", "last_60_days_cases_sqrt": "float"})
covid_root.head()
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases  \
# 0            14                   5                   3                   1
# 1            69                  22                  14                   7
# 2             3                   3                   2                   1
# 3            19                   4                   3                   1
# 4             5                   3                   2                   1
#
#    30_sep_cases_sqrt  last_14_days_cases_sqrt  last_30_days_cases_sqrt  \
# 0           3.741657                 2.236068                 1.732051
# 1           8.306624                 4.690416                 3.741657
# 2           1.732051                 1.732051                 1.414214
# 3           4.358899                 2.000000                 1.732051
# 4           2.236068                 1.732051                 1.414214
#
#    last_60_days_cases_sqrt
# 0                 1.000000
# 1                 2.645751
# 2                 1.000000
# 3                 1.000000
# 4                 1.000000

# %%
covid_root.describe()
# Out:
#        30_sep_cases  last_14_days_cases  last_30_days_cases  \
# count     45.000000           45.000000           45.000000
# mean      31.044444           14.000000           10.088889
# std       56.649623           33.792818           24.631671
# min        0.000000            0.000000            0.000000
# 25%        3.000000            1.000000            1.000000
# 50%       14.000000            4.000000            2.000000
# 75%       25.000000           11.000000            7.000000
# max      332.000000          214.000000          155.000000
#
#        last_60_days_cases  30_sep_cases_sqrt  last_14_days_cases_sqrt  \
# count           45.000000          45.000000                45.000000
# mean             5.422222           4.283211                 2.577322
# std             12.824850           3.603769                 2.743105
# min              0.000000           0.000000                 0.000000
# 25%              0.000000           1.732051                 1.000000
# 50%              1.000000           3.741657                 2.000000
# 75%              4.000000           5.000000                 3.316625
# max             80.000000          18.220867                14.628739
#
#        last_30_days_cases_sqrt  last_60_days_cases_sqrt
# count                45.000000                45.000000
# mean                  2.185492                 1.566172
# std                   2.330933                 1.742645
# min                   0.000000                 0.000000
# 25%                   1.000000                 0.000000
# 50%                   1.414214                 1.000000
# 75%                   2.645751                 2.000000
# max                  12.449900                 8.944272

# %% [markdown]
# We will plot the scatter plots , calculate the correlation coefficients and the VIF using the standardised variables

# %%
covid_root.plot(x = "last_14_days_cases_sqrt", y = "30_sep_cases_sqrt", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_14_days_cases_sqrt', ylabel='30_sep_cases_sqrt'>

# %%
covid_root.plot(x = "last_30_days_cases_sqrt", y = "30_sep_cases_sqrt", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_30_days_cases_sqrt', ylabel='30_sep_cases_sqrt'>

# %%
covid_root.plot(x = "last_60_days_cases_sqrt", y = "30_sep_cases_sqrt", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_60_days_cases_sqrt', ylabel='30_sep_cases_sqrt'>

# %%
covid_root.corr()
# Out:
#                          30_sep_cases  last_14_days_cases  last_30_days_cases  \
# 30_sep_cases                 1.000000            0.978447            0.973326
# last_14_days_cases           0.978447            1.000000            0.996247
# last_30_days_cases           0.973326            0.996247            1.000000
# last_60_days_cases           0.972570            0.993337            0.998620
# 30_sep_cases_sqrt            0.927684            0.848754            0.843704
# last_14_days_cases_sqrt      0.946133            0.902866            0.899709
# last_30_days_cases_sqrt      0.944161            0.904099            0.909063
# last_60_days_cases_sqrt      0.925381            0.881577            0.888095
#
#                          last_60_days_cases  30_sep_cases_sqrt  \
# 30_sep_cases                       0.972570           0.927684
# last_14_days_cases                 0.993337           0.848754
# last_30_days_cases                 0.998620           0.843704
# last_60_days_cases                 1.000000           0.850224
# 30_sep_cases_sqrt                  0.850224           1.000000
# last_14_days_cases_sqrt            0.904559           0.969661
# last_30_days_cases_sqrt            0.916706           0.961791
# last_60_days_cases_sqrt            0.901271           0.956936
#
#                          last_14_days_cases_sqrt  last_30_days_cases_sqrt  \
# 30_sep_cases                            0.946133                 0.944161
# last_14_days_cases                      0.902866                 0.904099
# last_30_days_cases                      0.899709                 0.909063
# last_60_days_cases                      0.904559                 0.916706
# 30_sep_cases_sqrt                       0.969661                 0.961791
# last_14_days_cases_sqrt                 1.000000                 0.992977
# last_30_days_cases_sqrt                 0.992977                 1.000000
# last_60_days_cases_sqrt                 0.974976                 0.987917
#
#                          last_60_days_cases_sqrt
# 30_sep_cases                            0.925381
# last_14_days_cases                      0.881577
# last_30_days_cases                      0.888095
# last_60_days_cases                      0.901271
# 30_sep_cases_sqrt                       0.956936
# last_14_days_cases_sqrt                 0.974976
# last_30_days_cases_sqrt                 0.987917
# last_60_days_cases_sqrt                 1.000000

# %%
# calculate VIF of covid dataframe explanatory variables
calc_vif(covid_root.iloc[:,5:])
# Out:
#                  variables         VIF
# 0  last_14_days_cases_sqrt  152.243104
# 1  last_30_days_cases_sqrt  309.004050
# 2  last_60_days_cases_sqrt   83.947371

# %% [markdown]
# We can see that the root transformation improved the plots by making the points more spread out, however the gap still exists due to the outlier, high correlation still exists between the variables, and the VIF while extremely high, is lower than the original model
#
# Finally, we will run a linear regression using the transformed variables

# %%
# train, test split
X_train, X_test, y_train, y_test = train_test_split(covid_root.iloc[:,5:],covid_root.iloc[:,4:5], random_state = 111)

# %%
# initialize model
lm = LinearRegression()
# fit the linear model using the training data
lm.fit(X_train, y_train)
# r-squared
print ('r-squared for this model = ', lm.score(X_test,y_test))
# Out:
# r-squared for this model =  0.8963719563575945

# %% [markdown]
# The r-squared for this model is better than the original model

# %% [markdown]
# #### 4.4.2 Square Power Transformation
#
# The next type of transformation to be trialled is the square power transformation on each variable

# %%
# generate square power columns

covid['30_sep_cases_pow'] = None
i = 0
for row in covid.iterrows():
    covid['30_sep_cases_pow'].at[i] = math.pow(covid["30_sep_cases"][i], 2)
    i += 1

covid['last_14_days_cases_pow'] = None
i = 0
for row in covid.iterrows():
    covid['last_14_days_cases_pow'].at[i] = math.pow(covid["last_14_days_cases"][i], 2)
    i += 1
    
covid['last_30_days_cases_pow'] = None
i = 0
for row in covid.iterrows():
    covid['last_30_days_cases_pow'].at[i] = math.pow(covid["last_30_days_cases"][i], 2)
    i += 1

covid['last_60_days_cases_pow'] = None
i = 0
for row in covid.iterrows():
    covid['last_60_days_cases_pow'].at[i] = math.pow(covid["last_60_days_cases"][i], 2)
    i += 1

covid = covid.astype("int64")
covid.head()
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases  \
# 0            14                   5                   3                   1
# 1            69                  22                  14                   7
# 2             3                   3                   2                   1
# 3            19                   4                   3                   1
# 4             5                   3                   2                   1
#
#    30_sep_cases_pow  last_14_days_cases_pow  last_30_days_cases_pow  \
# 0               196                      25                       9
# 1              4761                     484                     196
# 2                 9                       9                       4
# 3               361                      16                       9
# 4                25                       9                       4
#
#    last_60_days_cases_pow
# 0                       1
# 1                      49
# 2                       1
# 3                       1
# 4                       1

# %%
covid.describe()
# Out:
#        30_sep_cases  last_14_days_cases  last_30_days_cases  \
# count      45.00000           45.000000           45.000000
# mean       31.00000           14.000000           10.088889
# std        56.67491           33.792818           24.631671
# min        -1.00000            0.000000            0.000000
# 25%         3.00000            1.000000            1.000000
# 50%        14.00000            4.000000            2.000000
# 75%        25.00000           11.000000            7.000000
# max       332.00000          214.000000          155.000000
#
#        last_60_days_cases  30_sep_cases_pow  last_14_days_cases_pow  \
# count           45.000000         45.000000               45.000000
# mean             5.422222       4101.666667             1312.577778
# std             12.824850      16718.961240             6833.485845
# min              0.000000          1.000000                0.000000
# 25%              0.000000          9.000000                1.000000
# 50%              1.000000        196.000000               16.000000
# 75%              4.000000        625.000000              121.000000
# max             80.000000     110224.000000            45796.000000
#
#        last_30_days_cases_pow  last_60_days_cases_pow
# count               45.000000               45.000000
# mean               695.022222              190.222222
# std               3586.988902              955.986565
# min                  0.000000                0.000000
# 25%                  1.000000                0.000000
# 50%                  4.000000                1.000000
# 75%                 49.000000               16.000000
# max              24025.000000             6400.000000

# %% [markdown]
# We will plot the scatter plots , calculate the correlation coefficients and the VIF using the standardised variables

# %%
covid.plot(x = "last_14_days_cases_pow", y = "30_sep_cases_pow", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_14_days_cases_pow', ylabel='30_sep_cases_pow'>

# %%
covid.plot(x = "last_30_days_cases_pow", y = "30_sep_cases_pow", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_30_days_cases_pow', ylabel='30_sep_cases_pow'>

# %%
covid.plot(x = "last_60_days_cases_pow", y = "30_sep_cases_pow", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_60_days_cases_pow', ylabel='30_sep_cases_pow'>

# %%
covid.corr()
# Out:
#                         30_sep_cases  last_14_days_cases  last_30_days_cases  \
# 30_sep_cases                1.000000            0.978343            0.973221
# last_14_days_cases          0.978343            1.000000            0.996247
# last_30_days_cases          0.973221            0.996247            1.000000
# last_60_days_cases          0.972475            0.993337            0.998620
# 30_sep_cases_pow            0.922852            0.976445            0.970385
# last_14_days_cases_pow      0.868481            0.945033            0.939568
# last_30_days_cases_pow      0.869017            0.945543            0.943618
# last_60_days_cases_pow      0.872701            0.948172            0.946956
#
#                         last_60_days_cases  30_sep_cases_pow  \
# 30_sep_cases                      0.972475          0.922852
# last_14_days_cases                0.993337          0.976445
# last_30_days_cases                0.998620          0.970385
# last_60_days_cases                1.000000          0.962253
# 30_sep_cases_pow                  0.962253          1.000000
# last_14_days_cases_pow            0.930267          0.990918
# last_30_days_cases_pow            0.934841          0.989758
# last_60_days_cases_pow            0.938988          0.990072
#
#                         last_14_days_cases_pow  last_30_days_cases_pow  \
# 30_sep_cases                          0.868481                0.869017
# last_14_days_cases                    0.945033                0.945543
# last_30_days_cases                    0.939568                0.943618
# last_60_days_cases                    0.930267                0.934841
# 30_sep_cases_pow                      0.990918                0.989758
# last_14_days_cases_pow                1.000000                0.999036
# last_30_days_cases_pow                0.999036                1.000000
# last_60_days_cases_pow                0.998523                0.999816
#
#                         last_60_days_cases_pow
# 30_sep_cases                          0.872701
# last_14_days_cases                    0.948172
# last_30_days_cases                    0.946956
# last_60_days_cases                    0.938988
# 30_sep_cases_pow                      0.990072
# last_14_days_cases_pow                0.998523
# last_30_days_cases_pow                0.999816
# last_60_days_cases_pow                1.000000

# %%
# calculate VIF of covid dataframe explanatory variables
calc_vif(covid.iloc[:,5:])
# Out:
#                 variables          VIF
# 0  last_14_days_cases_pow   631.573409
# 1  last_30_days_cases_pow  4789.028445
# 2  last_60_days_cases_pow  3084.645941

# %% [markdown]
# We can see that the square power transformation deteriorated the plots by making the points more compact, high correlation still exists between the variables, and the VIF is now much higher than the original model. All of which indicate the square power transformation is not suitable.
#
# Finally, we will run a linear regression using the transformed variables

# %%
# train, test split
X_train, X_test, y_train, y_test = train_test_split(covid.iloc[:,5:],covid.iloc[:,4:5], random_state = 111)

# %%
# initialize model
lm = LinearRegression()
# fit the linear model using the training data
lm.fit(X_train, y_train)
# r-squared
print ('r-squared for this model = ', lm.score(X_test,y_test))
# Out:
# r-squared for this model =  0.48433140423279786

# %% [markdown]
# The r-squared for this model is much worse than the original model

# %%
covid.drop(columns = ['30_sep_cases_pow', 'last_14_days_cases_pow', 'last_30_days_cases_pow', 'last_60_days_cases_pow'], inplace = True)

# %% [markdown]
# #### 4.4.3 Log Transformation
#
# In this type of transformation, the variables will be calculated to their log. First we will convert any non-positive values to 1

# %%
covid_log = covid.copy()
covid_log.loc[covid["30_sep_cases"] < 1, "30_sep_cases"] = 1
covid_log.loc[covid["last_14_days_cases"] < 1, "last_14_days_cases"] = 1
covid_log.loc[covid["last_30_days_cases"] < 1, "last_30_days_cases"] = 1
covid_log.loc[covid["last_60_days_cases"] < 1, "last_60_days_cases"] = 1

# %%
# generate log columns

covid_log['30_sep_cases_log'] = None
i = 0
for row in covid_log.iterrows():
    covid_log['30_sep_cases_log'].at[i] = math.log(covid_log["30_sep_cases"][i])
    i += 1

covid_log['last_14_days_cases_log'] = None
i = 0
for row in covid_log.iterrows():
    covid_log['last_14_days_cases_log'].at[i] = math.log(covid_log["last_14_days_cases"][i])
    i += 1
    
covid_log['last_30_days_cases_log'] = None
i = 0
for row in covid_log.iterrows():
    covid_log['last_30_days_cases_log'].at[i] = math.log(covid_log["last_30_days_cases"][i])
    i += 1

covid_log['last_60_days_cases_log'] = None
i = 0
for row in covid_log.iterrows():
    covid_log['last_60_days_cases_log'].at[i] = math.log(covid_log["last_60_days_cases"][i])
    i += 1

covid_log = covid_log.astype({"30_sep_cases_log": "float", "last_14_days_cases_log": "float", "last_30_days_cases_log": "float", "last_60_days_cases_log": "float"})
covid_log.head()
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases  \
# 0            14                   5                   3                   1
# 1            69                  22                  14                   7
# 2             3                   3                   2                   1
# 3            19                   4                   3                   1
# 4             5                   3                   2                   1
#
#    30_sep_cases_log  last_14_days_cases_log  last_30_days_cases_log  \
# 0          2.639057                1.609438                1.098612
# 1          4.234107                3.091042                2.639057
# 2          1.098612                1.098612                0.693147
# 3          2.944439                1.386294                1.098612
# 4          1.609438                1.098612                0.693147
#
#    last_60_days_cases_log
# 0                 0.00000
# 1                 1.94591
# 2                 0.00000
# 3                 0.00000
# 4                 0.00000

# %%
covid_log.describe()
# Out:
#        30_sep_cases  last_14_days_cases  last_30_days_cases  \
# count     45.000000           45.000000           45.000000
# mean      31.088889           14.222222           10.288889
# std       56.625092           33.701152           24.551081
# min        1.000000            1.000000            1.000000
# 25%        3.000000            1.000000            1.000000
# 50%       14.000000            4.000000            2.000000
# 75%       25.000000           11.000000            7.000000
# max      332.000000          214.000000          155.000000
#
#        last_60_days_cases  30_sep_cases_log  last_14_days_cases_log  \
# count           45.000000         45.000000               45.000000
# mean             5.711111          2.329809                1.513851
# std             12.707589          1.595839                1.403701
# min              1.000000          0.000000                0.000000
# 25%              1.000000          1.098612                0.000000
# 50%              1.000000          2.639057                1.386294
# 75%              4.000000          3.218876                2.397895
# max             80.000000          5.805135                5.365976
#
#        last_30_days_cases_log  last_60_days_cases_log
# count               45.000000               45.000000
# mean                 1.235853                0.842238
# std                  1.312408                1.138339
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.693147                0.000000
# 75%                  1.945910                1.386294
# max                  5.043425                4.382027

# %% [markdown]
# We will plot the scatter plots , calculate the correlation coefficients and the VIF using the standardised variables

# %%
covid_log.plot(x = "last_14_days_cases_log", y = "30_sep_cases_log", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_14_days_cases_log', ylabel='30_sep_cases_log'>

# %%
covid_log.plot(x = "last_30_days_cases_log", y = "30_sep_cases_log", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_30_days_cases_log', ylabel='30_sep_cases_log'>

# %%
covid_log.plot(x = "last_60_days_cases_log", y = "30_sep_cases_log", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_60_days_cases_log', ylabel='30_sep_cases_log'>

# %%
covid_log.corr()
# Out:
#                         30_sep_cases  last_14_days_cases  last_30_days_cases  \
# 30_sep_cases                1.000000            0.977724            0.972269
# last_14_days_cases          0.977724            1.000000            0.996224
# last_30_days_cases          0.972269            0.996224            1.000000
# last_60_days_cases          0.969683            0.993442            0.998792
# 30_sep_cases_log            0.708811            0.595334            0.587671
# last_14_days_cases_log      0.793041            0.705475            0.700766
# last_30_days_cases_log      0.818617            0.735880            0.738286
# last_60_days_cases_log      0.838622            0.766260            0.772290
#
#                         last_60_days_cases  30_sep_cases_log  \
# 30_sep_cases                      0.969683          0.708811
# last_14_days_cases                0.993442          0.595334
# last_30_days_cases                0.998792          0.587671
# last_60_days_cases                1.000000          0.587056
# 30_sep_cases_log                  0.587056          1.000000
# last_14_days_cases_log            0.701795          0.920244
# last_30_days_cases_log            0.742409          0.889878
# last_60_days_cases_log            0.784159          0.825582
#
#                         last_14_days_cases_log  last_30_days_cases_log  \
# 30_sep_cases                          0.793041                0.818617
# last_14_days_cases                    0.705475                0.735880
# last_30_days_cases                    0.700766                0.738286
# last_60_days_cases                    0.701795                0.742409
# 30_sep_cases_log                      0.920244                0.889878
# last_14_days_cases_log                1.000000                0.986074
# last_30_days_cases_log                0.986074                1.000000
# last_60_days_cases_log                0.929268                0.964990
#
#                         last_60_days_cases_log
# 30_sep_cases                          0.838622
# last_14_days_cases                    0.766260
# last_30_days_cases                    0.772290
# last_60_days_cases                    0.784159
# 30_sep_cases_log                      0.825582
# last_14_days_cases_log                0.929268
# last_30_days_cases_log                0.964990
# last_60_days_cases_log                1.000000

# %%
# calculate VIF of covid dataframe explanatory variables
calc_vif(covid_log.iloc[:,5:])
# Out:
#                 variables         VIF
# 0  last_14_days_cases_log   89.659363
# 1  last_30_days_cases_log  179.789255
# 2  last_60_days_cases_log   30.169917

# %% [markdown]
# We can see that the log transformation vastly improved the plots by making the points much more distributed and greatly reducing the gap, high correlation still exists between the variables, and the VIF while still high, is lower than the original model.
#
# Finally, we will run a linear regression using the transformed variables

# %%
# train, test split
X_train, X_test, y_train, y_test = train_test_split(covid_log.iloc[:,5:],covid_log.iloc[:,4:5], random_state = 111)

# %%
# initialize model
lm = LinearRegression()
# fit the linear model using the training data
lm.fit(X_train, y_train)
# r-squared
print ('r-squared for this model = ', lm.score(X_test,y_test))
# Out:
# r-squared for this model =  0.7942546539089334

# %% [markdown]
# The r-squared for this model is the same as the original model.

# %% [markdown]
# #### 4.4 Box Cox Transformation
#
# The final transformation method to be trialled is the box cox transformation. First we will convert any values less than or equal to zero to 1, this will be done using the `boxcox` function from the `scipy` package

# %%
box_cox = covid.copy()
box_cox.loc[box_cox["30_sep_cases"] <= 0, "30_sep_cases"] = 1
box_cox.loc[box_cox["last_14_days_cases"] <= 0, "last_14_days_cases"] = 1
box_cox.loc[box_cox["last_30_days_cases"] <= 0, "last_30_days_cases"] = 1
box_cox.loc[box_cox["last_60_days_cases"] <= 0, "last_60_days_cases"] = 1

# %%
# generate box cox columns
box_cox["30_sep_cases_box"],_ = stats.boxcox(box_cox["30_sep_cases"])
box_cox["last_14_days_cases_box"],_ = stats.boxcox(box_cox["last_14_days_cases"])
box_cox["last_30_days_cases_box"],_ = stats.boxcox(box_cox["last_30_days_cases"])
box_cox["last_60_days_cases_box"],_ = stats.boxcox(box_cox["last_60_days_cases"])
box_cox.head()
# Out:
#    30_sep_cases  last_14_days_cases  last_30_days_cases  last_60_days_cases  \
# 0            14                   5                   3                   1
# 1            69                  22                  14                   7
# 2             3                   3                   2                   1
# 3            19                   4                   3                   1
# 4             5                   3                   2                   1
#
#    30_sep_cases_box  last_14_days_cases_box  last_30_days_cases_box  \
# 0          2.627655                1.326920                0.885246
# 1          4.204807                2.158548                1.615301
# 2          1.096633                0.961609                0.603686
# 3          2.930250                1.173020                0.885246
# 4          1.605192                0.961609                0.603686
#
#    last_60_days_cases_box
# 0                0.000000
# 1                1.041106
# 2                0.000000
# 3                0.000000
# 4                0.000000

# %%
box_cox.describe()
# Out:
#        30_sep_cases  last_14_days_cases  last_30_days_cases  \
# count     45.000000           45.000000           45.000000
# mean      31.088889           14.222222           10.288889
# std       56.625092           33.701152           24.551081
# min        1.000000            1.000000            1.000000
# 25%        3.000000            1.000000            1.000000
# 50%       14.000000            4.000000            2.000000
# 75%       25.000000           11.000000            7.000000
# max      332.000000          214.000000          155.000000
#
#        last_60_days_cases  30_sep_cases_box  last_14_days_cases_box  \
# count           45.000000         45.000000               45.000000
# mean             5.711111          2.316862                1.106451
# std             12.707589          1.583655                0.913165
# min              1.000000          0.000000                0.000000
# 25%              1.000000          1.096633                0.000000
# 50%              1.000000          2.627655                1.173020
# 75%              4.000000          3.201924                1.807283
# max             80.000000          5.750154                2.965938
#
#        last_30_days_cases_box  last_60_days_cases_box
# count               45.000000               45.000000
# mean                 0.785277                0.428811
# std                  0.705759                0.495060
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.603686                0.000000
# 75%                  1.342582                0.873342
# max                  2.136597                1.318334

# %% [markdown]
# We will plot the scatter plots , calculate the correlation coefficients and the VIF using the standardised variables

# %%
box_cox.plot(x = "last_14_days_cases_box", y = "30_sep_cases_box", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_14_days_cases_box', ylabel='30_sep_cases_box'>

# %%
box_cox.plot(x = "last_30_days_cases_box", y = "30_sep_cases_box", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_30_days_cases_box', ylabel='30_sep_cases_box'>

# %%
box_cox.plot(x = "last_60_days_cases_box", y = "30_sep_cases_box", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='last_60_days_cases_box', ylabel='30_sep_cases_box'>

# %%
box_cox.corr()
# Out:
#                         30_sep_cases  last_14_days_cases  last_30_days_cases  \
# 30_sep_cases                1.000000            0.977724            0.972269
# last_14_days_cases          0.977724            1.000000            0.996224
# last_30_days_cases          0.972269            0.996224            1.000000
# last_60_days_cases          0.969683            0.993442            0.998792
# 30_sep_cases_box            0.707113            0.593584            0.585913
# last_14_days_cases_box      0.687238            0.591393            0.585485
# last_30_days_cases_box      0.677670            0.580872            0.579640
# last_60_days_cases_box      0.659173            0.567415            0.568774
#
#                         last_60_days_cases  30_sep_cases_box  \
# 30_sep_cases                      0.969683          0.707113
# last_14_days_cases                0.993442          0.593584
# last_30_days_cases                0.998792          0.585913
# last_60_days_cases                1.000000          0.585293
# 30_sep_cases_box                  0.585293          1.000000
# last_14_days_cases_box            0.585159          0.922707
# last_30_days_cases_box            0.581540          0.903092
# last_60_days_cases_box            0.581887          0.828908
#
#                         last_14_days_cases_box  last_30_days_cases_box  \
# 30_sep_cases                          0.687238                0.677670
# last_14_days_cases                    0.591393                0.580872
# last_30_days_cases                    0.585485                0.579640
# last_60_days_cases                    0.585159                0.581540
# 30_sep_cases_box                      0.922707                0.903092
# last_14_days_cases_box                1.000000                0.984180
# last_30_days_cases_box                0.984180                1.000000
# last_60_days_cases_box                0.880718                0.914086
#
#                         last_60_days_cases_box
# 30_sep_cases                          0.659173
# last_14_days_cases                    0.567415
# last_30_days_cases                    0.568774
# last_60_days_cases                    0.581887
# 30_sep_cases_box                      0.828908
# last_14_days_cases_box                0.880718
# last_30_days_cases_box                0.914086
# last_60_days_cases_box                1.000000

# %%
# calculate VIF of covid dataframe explanatory variables
calc_vif(box_cox.iloc[:,5:])
# Out:
#                 variables         VIF
# 0  last_14_days_cases_box   74.893793
# 1  last_30_days_cases_box  103.237916
# 2  last_60_days_cases_box   11.364376

# %% [markdown]
# We can see that the box cox transformation improved the original plots by making the points more distributed and eliminating the gap due to the outlier, however, we have many points accumulated at the zero point of the x-axis and a new gap is formed between those points and the remaining points, high correlation still exists between the variables, and the VIF while still high, is lower than the original model.
#
# Finally, we will run a linear regression using the transformed variables

# %%
# train, test split
X_train, X_test, y_train, y_test = train_test_split(box_cox.iloc[:,5:],box_cox.iloc[:,4:5], random_state = 111)

# %%
# initialize model
lm = LinearRegression()
# fit the linear model using the training data
lm.fit(X_train, y_train)
# r-squared
print ('r-squared for this model = ', lm.score(X_test,y_test))
# Out:
# r-squared for this model =  0.7953754040105987

# %% [markdown]
# We can observe that the r-squared for this model is the same as the original

# %% [markdown]
# ### 4.5 Final Model
#
# Based on the above experiments regarding normalisation and transformation, the final model will:
# - **Not be normalised**. The explanatory variables are already all on the same scale. Furthermore, normalising the variables does not enhance the linear regression model
# - **Log transformed**. The log transformation provides the most linear relationship between each of the independent variables and the dependent variable according to the scatter plots. The r-squared is high for the log transformed model at 79%

# %% [markdown]
# ## 5. Conclusion
#
# This assignment displayed various methods and techniques towards the integration of datasets from different sources. These methods included database merging, the use of shapefiles, connecting several datasets to each other to derive the requierd information, as well as webscraping. Integration issues such as the presence of duplicates were also examined and solved. Furthermore, normalisation and transformation techniques and their effect on linear model creation based on the COVID figures were also analysed, and an attempt was made to recommend the most appropriate transformation.
#
# ## 6. References
#
# - Bhandari, A. (2020, March 20). What is Multicollinearity? Here’s Everything You Need to Know. Retrieved from https://www.analyticsvidhya.com/blog/2020/03/what-is-multicollinearity/
# - Datascience Made Simple. (2021). Difference Between Two Timestamps in Seconds, Minutes, Hours in Pandas Python. Retrieved from
# https://www.datasciencemadesimple.com/difference-two-timestamps-seconds-minutes-hours-pandas-python-2/
# - Harris, C.R., Millman, K.J., van der Walt, S.J. et al. Array programming with NumPy. Nature 585, 357–362 (2020). DOI: 10.1038/s41586-020-2649-2. (Publisher link).
# - Pypi. (2021). Haversine 2.5.1. Retrieved from https://pypi.org/project/haversine/
# - J. D. Hunter, "Matplotlib: A 2D Graphics Environment", Computing in Science & Engineering, vol. 9, no. 3, pp. 90-95, 2007.
# - McKinney, W., & others. (2010). Data structures for statistical computing in python. In Proceedings of the 9th Python in Science Conference (Vol. 445, pp. 51–56)
# - Scikit-learn: Machine Learning in Python, Pedregosa et al., JMLR 12, pp. 2825-2830, 2011.
# - Seabold, S., & Perktold, J. (2010). statsmodels: Econometric and statistical modeling with python. In 9th Python in Science Conference.
# - Van Rossum, G. (2020). The Python Library Reference, release 3.8.2. Python Software Foundation.
# - Virtanen, P., Gommers, R., Oliphant, T. E., Haberland, M., Reddy, T., Cournapeau, D., … SciPy 1.0 Contributors. (2020). SciPy 1.0: Fundamental Algorithms for Scientific Computing in Python. Nature Methods, 17, 261–272. https://doi.org/10.1038/s41592-019-0686-2
